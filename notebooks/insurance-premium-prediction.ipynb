# %% [markdown]
# # 🏆 About Project

# %% [markdown]
# ## 🎯  Objective
#
# Insurance companies need to accurately predict the cost of health insurance for individuals to set premiums appropriately. However, traditional methods of cost prediction often rely on broad actuarial tables and historical averages, which may not account for the nuanced differences among individuals. By leveraging machine learning techniques, insurers can predict more accurately the insurance costs tailored to individual profiles, leading to more competitive pricing and better risk management.
#
# **Insurance Cost Prediction need**
# The primary need for this project arises from the challenges insurers face in pricing policies accurately while remaining competitive in the market. Inaccurate predictions can lead to losses for insurers and unfairly high premiums for policyholders. By implementing a machine learning model, insurers can:
# - Enhance Precision in Pricing: Use individual data points to determine premiums that reflect actual risk more closely than generic estimates.
# - Increase Competitiveness: Offer rates that are attractive to consumers while ensuring that the pricing is sustainable for the insurer.
# - Improve Customer Satisfaction: Fair and transparent pricing based on personal health data can increase trust and satisfaction among policyholders.
# - Enable Personalized Offerings: Create customized insurance packages based on predicted costs, which can cater more directly to the needs and preferences of individuals.
# - Risk Assessment: Insurers can use the model to refine their risk assessment processes, identifying key factors that influence costs most significantly.
# - Policy Development: The insights gained from the model can inform the development of new insurance products or adjustments to existing ones.
# - Strategic Decision Making: Predictive analytics can aid in broader strategic decisions, such as entering new markets or adjusting policy terms based on risk predictions.
# - Customer Engagement: Insights from the model can be used in customer engagement initiatives, such as personalized marketing and tailored advice for policyholders.

# %% [markdown]
# ## 📚 Data Description

# %% [markdown]
# The dataset comprises the following 11 attributes:
# 1. Age: Numeric, ranging from 18 to 66 years.
# 2. Diabetes: Binary (0 or 1), where 1 indicates the presence of diabetes.
# 3. BloodPressureProblems: Binary (0 or 1), indicating the presence of blood pressure-related issues.
# 4. AnyTransplants: Binary (0 or 1), where 1 indicates the person has had a transplant.
# 5. AnyChronicDiseases: Binary (0 or 1), indicating the presence of any chronic diseases.
# 6. Height: Numeric, measured in centimeters, ranging from 145 cm to 188 cm.
# 7. Weight: Numeric, measured in kilograms, ranging from 51 kg to 132 kg.
# 8. KnownAllergies: Binary (0 or 1), where 1 indicates known allergies.
# 9. HistoryOfCancerInFamily: Binary (0 or 1), indicating a family history of cancer.
# 10. NumberOfMajorSurgeries: Numeric, counting the number of major surgeries, ranging from 0 to 3 surgeries.
# 11. PremiumPrice: Numeric, representing the premium price in currency, ranging from 15,000 to 40,000.

# %% [markdown]
# # 🚀 Let's Get Started

# %% [markdown]
# ## 📚 Importing Libraries

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objs as go
import plotly.subplots as sp
from plotly.subplots import make_subplots
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
import plotly.express as px
import warnings
import time
import datetime as dt
warnings.filterwarnings("ignore")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.1.min"</script>

# %% [markdown]
# ## 📊 Importing Dataset

# %%
from pathlib import Path
DATA_PATH = Path("..") / "data" / "insurance.csv"
df = pd.read_csv(DATA_PATH)

# %% [markdown]
# ## 🎨 Custom Color Palette

# %%
def custom_palette(custom_colors):
    customPalette=sns.set_palette(sns.color_palette(custom_colors))
    sns.palplot(sns.color_palette(custom_colors),size=0.8)
    plt.tick_params(axis='both',labelsize=0,length=0)
    return

# %%
#defining colour palette
red = ["#4f000b","#720026","#ce4257","#ff7f51","#ff9b54"]
bo = ["#6930c3","#5e60ce","#0096c7","#48cae4","#ade8f4","#ff7f51","#ff9b54","#ffbf69"]
pink = ["#aa4465","#dd2d4a","#f26a8d","#f49cbb","#ffcbf2","#e2afff","#ff86c8","#ffa3a5","#ffbf81","#e9b827","#f9e576"]
custom_palette(pink)

# %% [markdown]
# ## 📉 Basic Analysis

# %% [markdown]
# **Shape of the data**

# %%
df.shape
# Out:
# (986, 11)

# %% [markdown]
# **Inference**
#
# - Shape of the data is 986 * 11
# - Number of rows: 986
# - Number of Columns: 11

# %% [markdown]
# **First Few Rows**

# %%
df.head()
# Out:
#    Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0   45         0                      0               0                   0
# 1   60         1                      0               0                   0
# 2   36         1                      1               0                   0
# 3   52         1                      1               0                   1
# 4   38         0                      0               0                   1
#
#    Height  Weight  KnownAllergies  HistoryOfCancerInFamily  \
# 0     155      57               0                        0
# 1     180      73               0                        0
# 2     158      59               0                        0
# 3     183      93               0                        0
# 4     166      88               0                        0
#
#    NumberOfMajorSurgeries  PremiumPrice
# 0                       0         25000
# 1                       0         29000
# 2                       1         23000
# 3                       2         28000
# 4                       1         23000

# %% [markdown]
# **Columns in the dataframe**

# %%
df.columns
# Out:
# Index(['Age', 'Diabetes', 'BloodPressureProblems', 'AnyTransplants',
#        'AnyChronicDiseases', 'Height', 'Weight', 'KnownAllergies',
#        'HistoryOfCancerInFamily', 'NumberOfMajorSurgeries', 'PremiumPrice'],
#       dtype='object')

# %% [markdown]
# **Concise Summary**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      986 non-null    int64
#  1   Diabetes                 986 non-null    int64
#  2   BloodPressureProblems    986 non-null    int64
#  3   AnyTransplants           986 non-null    int64
#  4   AnyChronicDiseases       986 non-null    int64
#  5   Height                   986 non-null    int64
#  6   Weight                   986 non-null    int64
#  7   KnownAllergies           986 non-null    int64
#  8   HistoryOfCancerInFamily  986 non-null    int64
#  9   NumberOfMajorSurgeries   986 non-null    int64
#  10  PremiumPrice             986 non-null    int64
# dtypes: int64(11)
# memory usage: 84.9 KB

# %% [markdown]
# **Inference**
#
# - There are no missing values in the dataset.
# - All columns are of numeric type

# %% [markdown]
# **Descriptive Statistics**

# %%
df.describe().T
# Out:
#                          count          mean          std      min      25%  \
# Age                      986.0     41.745436    13.963371     18.0     30.0
# Diabetes                 986.0      0.419878     0.493789      0.0      0.0
# BloodPressureProblems    986.0      0.468560     0.499264      0.0      0.0
# AnyTransplants           986.0      0.055781     0.229615      0.0      0.0
# AnyChronicDiseases       986.0      0.180527     0.384821      0.0      0.0
# Height                   986.0    168.182556    10.098155    145.0    161.0
# Weight                   986.0     76.950304    14.265096     51.0     67.0
# KnownAllergies           986.0      0.215010     0.411038      0.0      0.0
# HistoryOfCancerInFamily  986.0      0.117647     0.322353      0.0      0.0
# NumberOfMajorSurgeries   986.0      0.667343     0.749205      0.0      0.0
# PremiumPrice             986.0  24336.713996  6248.184382  15000.0  21000.0
#
#                              50%      75%      max
# Age                         42.0     53.0     66.0
# Diabetes                     0.0      1.0      1.0
# BloodPressureProblems        0.0      1.0      1.0
# AnyTransplants               0.0      0.0      1.0
# AnyChronicDiseases           0.0      0.0      1.0
# Height                     168.0    176.0    188.0
# Weight                      75.0     87.0    132.0
# KnownAllergies               0.0      0.0      1.0
# HistoryOfCancerInFamily      0.0      0.0      1.0
# NumberOfMajorSurgeries       1.0      1.0      3.0
# PremiumPrice             23000.0  28000.0  40000.0

# %% [markdown]
# **Missing Values Check**

# %%
df.isnull().sum()
# Out:
# Age                        0
# Diabetes                   0
# BloodPressureProblems      0
# AnyTransplants             0
# AnyChronicDiseases         0
# Height                     0
# Weight                     0
# KnownAllergies             0
# HistoryOfCancerInFamily    0
# NumberOfMajorSurgeries     0
# PremiumPrice               0
# dtype: int64

# %% [markdown]
# **Inference**
#
# There are no missing values in the dataset

# %% [markdown]
# # 📈 Exploratory Data Analysis

# %% [markdown]
# ## 📊 Univariate Analysis

# %% [markdown]
# **Creating feature BMI using height and weight of the users**

# %% [markdown]
# The formula for Body Mass Index (BMI) is:
#
# $$ \mathrm{BMI} = \frac{\text{weight}_{\mathrm{kg}}}{\text{height}_{\mathrm{m}}^{2}} $$

# %%
df['BMI'] = df['Weight'] / ((df['Height'] / 100) ** 2)
df
# Out:
#      Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0     45         0                      0               0                   0
# 1     60         1                      0               0                   0
# 2     36         1                      1               0                   0
# 3     52         1                      1               0                   1
# 4     38         0                      0               0                   1
# ..   ...       ...                    ...             ...                 ...
# 981   18         0                      0               0                   0
# 982   64         1                      1               0                   0
# 983   56         0                      1               0                   0
# 984   47         1                      1               0                   0
# 985   21         0                      0               0                   0
#
#      Height  Weight  KnownAllergies  HistoryOfCancerInFamily  \
# 0       155      57               0                        0
# 1       180      73               0                        0
# 2       158      59               0                        0
# 3       183      93               0                        0
# 4       166      88               0                        0
# ..      ...     ...             ...                      ...
# 981     169      67               0                        0
# 982     153      70               0                        0
# 983     155      71               0                        0
# 984     158      73               1                        0
# 985     158      75               1                        0
#
#      NumberOfMajorSurgeries  PremiumPrice        BMI
# 0                         0         25000  23.725286
# 1                         0         29000  22.530864
# 2                         1         23000  23.634033
# 3                         2         28000  27.770313
# 4                         1         23000  31.934969
# ..                      ...           ...        ...
# 981                       0         15000  23.458562
# 982                       3         28000  29.903029
# 983                       1         29000  29.552549
# 984                       1         39000  29.242109
# 985                       1         15000  30.043262
#
# [986 rows x 12 columns]

# %%
sns.boxplot(data=df, x='BMI')
plt.show()

# %% [markdown]
# ##

# %% [markdown]
# ### Distribution of Age

# %%
data = df.copy()

# %%
df
# Out:
#      Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0     45         0                      0               0                   0
# 1     60         1                      0               0                   0
# 2     36         1                      1               0                   0
# 3     52         1                      1               0                   1
# 4     38         0                      0               0                   1
# ..   ...       ...                    ...             ...                 ...
# 981   18         0                      0               0                   0
# 982   64         1                      1               0                   0
# 983   56         0                      1               0                   0
# 984   47         1                      1               0                   0
# 985   21         0                      0               0                   0
#
#      Height  Weight  KnownAllergies  HistoryOfCancerInFamily  \
# 0       155      57               0                        0
# 1       180      73               0                        0
# 2       158      59               0                        0
# 3       183      93               0                        0
# 4       166      88               0                        0
# ..      ...     ...             ...                      ...
# 981     169      67               0                        0
# 982     153      70               0                        0
# 983     155      71               0                        0
# 984     158      73               1                        0
# 985     158      75               1                        0
#
#      NumberOfMajorSurgeries  PremiumPrice        BMI
# 0                         0         25000  23.725286
# 1                         0         29000  22.530864
# 2                         1         23000  23.634033
# 3                         2         28000  27.770313
# 4                         1         23000  31.934969
# ..                      ...           ...        ...
# 981                       0         15000  23.458562
# 982                       3         28000  29.903029
# 983                       1         29000  29.552549
# 984                       1         39000  29.242109
# 985                       1         15000  30.043262
#
# [986 rows x 12 columns]

# %%
data['Age'].max()
# Out:
# np.int64(66)

# %%
data['age_category'] = pd.cut(data['Age'], bins=[17,30,50,66], labels = ['young','middle age','old'])
data
# Out:
#      Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0     45         0                      0               0                   0
# 1     60         1                      0               0                   0
# 2     36         1                      1               0                   0
# 3     52         1                      1               0                   1
# 4     38         0                      0               0                   1
# ..   ...       ...                    ...             ...                 ...
# 981   18         0                      0               0                   0
# 982   64         1                      1               0                   0
# 983   56         0                      1               0                   0
# 984   47         1                      1               0                   0
# 985   21         0                      0               0                   0
#
#      Height  Weight  KnownAllergies  HistoryOfCancerInFamily  \
# 0       155      57               0                        0
# 1       180      73               0                        0
# 2       158      59               0                        0
# 3       183      93               0                        0
# 4       166      88               0                        0
# ..      ...     ...             ...                      ...
# 981     169      67               0                        0
# 982     153      70               0                        0
# 983     155      71               0                        0
# 984     158      73               1                        0
# 985     158      75               1                        0
#
#      NumberOfMajorSurgeries  PremiumPrice        BMI age_category
# 0                         0         25000  23.725286   middle age
# 1                         0         29000  22.530864          old
# 2                         1         23000  23.634033   middle age
# 3                         2         28000  27.770313          old
# 4                         1         23000  31.934969   middle age
# ..                      ...           ...        ...          ...
# 981                       0         15000  23.458562        young
# 982                       3         28000  29.903029          old
# 983                       1         29000  29.552549          old
# 984                       1         39000  29.242109   middle age
# 985                       1         15000  30.043262        young
#
# [986 rows x 13 columns]

# %%
df
# Out:
#      Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0     45         0                      0               0                   0
# 1     60         1                      0               0                   0
# 2     36         1                      1               0                   0
# 3     52         1                      1               0                   1
# 4     38         0                      0               0                   1
# ..   ...       ...                    ...             ...                 ...
# 981   18         0                      0               0                   0
# 982   64         1                      1               0                   0
# 983   56         0                      1               0                   0
# 984   47         1                      1               0                   0
# 985   21         0                      0               0                   0
#
#      Height  Weight  KnownAllergies  HistoryOfCancerInFamily  \
# 0       155      57               0                        0
# 1       180      73               0                        0
# 2       158      59               0                        0
# 3       183      93               0                        0
# 4       166      88               0                        0
# ..      ...     ...             ...                      ...
# 981     169      67               0                        0
# 982     153      70               0                        0
# 983     155      71               0                        0
# 984     158      73               1                        0
# 985     158      75               1                        0
#
#      NumberOfMajorSurgeries  PremiumPrice        BMI
# 0                         0         25000  23.725286
# 1                         0         29000  22.530864
# 2                         1         23000  23.634033
# 3                         2         28000  27.770313
# 4                         1         23000  31.934969
# ..                      ...           ...        ...
# 981                       0         15000  23.458562
# 982                       3         28000  29.903029
# 983                       1         29000  29.552549
# 984                       1         39000  29.242109
# 985                       1         15000  30.043262
#
# [986 rows x 12 columns]

# %%
colors = ['#3C4F76' , '#D1BEB0' , '#AB9F9D']
labels = data['age_category'].value_counts().index
values = data['age_category'].value_counts()

# create pie chart

pie_chart = go.Figure(go.Pie(labels = labels, values = values, ))
pie_chart.update_traces(hoverinfo = 'label+value' , textinfo = 'percent', textfont_size = 20, 
                        marker = dict(colors = colors, line = dict( color = '#000000', width=2)))

# Bar Chart

bar_chart = go.Figure(go.Bar(x = labels, y = values, marker_color = colors))

# create subplots

fig = sp.make_subplots( rows = 1, cols = 2, column_width = [0.5,0.5], specs = [[{'type' : 'bar'}, {'type' : 'pie'}]],
                      subplot_titles = ("Bar Chart", "Pie Chart"))

# Add charts to subplots

fig.add_trace(bar_chart.data[0], row=1, col=1)
fig.add_trace(pie_chart.data[0], row=1, col=2)

# Update layout
fig.update_layout(
    showlegend=False,
    title=dict(
        text="Distribution of Age",
        font=dict(size=18)
    ),
    xaxis=dict(
        title=dict(
            text="Age-Groups",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    ),
    yaxis=dict(
        title=dict(
            text="Count",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    )
)


# Show subplots
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="ff4e9795-557d-4738-8ec5-10d06acd53a8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("ff4e9795-557d-4738-8ec5-10d06acd53a8")) {                    Plotly.newPlot(                        "ff4e9795-557d-4738-8ec5-10d06acd53a8",                        [{"marker":{"color":["#3C4F76","#D1BEB0","#AB9F9D"]},"x":["middle age","old","young"],"y":{"dtype":"i2","bdata":"rQEoAQUB"},"type":"bar","xaxis":"x","yaxis":"y"},{"hoverinfo":"label+value","labels":["middle age","old","young"],"marker":{"colors":["#3C4F76","#D1BEB0","#AB9F9D"],"line":{"color":"#000000","width":2}},"textfont":{"size":20},"textinfo":"percent","values":{"dtype":"i2","bdata":"rQEoAQUB"},"type":"pie","domain":{"x":[0.55,1.0],"y":[0.0,1.0]}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":" ...

# %% [markdown]
# ### Distribution of Height

# %%
plt.figure(figsize = (15, 6))

# Histplot
plt.subplot(1,2,1)
sns.histplot(data = data , x = 'Height', kde = True, color = '#797596')
plt.xlabel('Height')
plt.ylabel('Count')

# Boxplot
plt.subplot(1,2,2)
sns.boxplot(data = data, x = 'Height', color = '#797596')
plt.xlabel('Height')

plt.suptitle('Distribution of Height')
plt.show()

# %% [markdown]
# ### Distribution of Weight

# %%
plt.figure(figsize = (15, 6))

# Histplot
plt.subplot(1,2,1)
sns.histplot(data = data , x = 'Weight', kde = True, color = '#345995')
plt.xlabel('Weight')
plt.ylabel('Count')

# Boxplot
plt.subplot(1,2,2)
sns.boxplot(data = data, x = 'Weight', color = '#345995')
plt.xlabel('Weight')

plt.suptitle('Distribution of Weight')
plt.show()

# %% [markdown]
# ### Distribution of BMI

# %%
data['BMI']
# Out:
# 0      23.725286
# 1      22.530864
# 2      23.634033
# 3      27.770313
# 4      31.934969
#          ...
# 981    23.458562
# 982    29.903029
# 983    29.552549
# 984    29.242109
# 985    30.043262
# Name: BMI, Length: 986, dtype: float64

# %%
data['BMI_category'] = pd.cut(data['BMI'],bins = [0,18.5,24.9,29.9, float('inf')], labels = ['Underweight','Normal', 'Overweight', 'Obese'])
data['BMI_category']
# Out:
# 0          Normal
# 1          Normal
# 2          Normal
# 3      Overweight
# 4           Obese
#           ...
# 981        Normal
# 982         Obese
# 983    Overweight
# 984    Overweight
# 985         Obese
# Name: BMI_category, Length: 986, dtype: category
# Categories (4, object): ['Underweight' < 'Normal' < 'Overweight' < 'Obese']

# %%
# colors = ['#f6f5f5', '#fe346e', '#512b58', '#2c003e','#636efa']
#colors  = ['#E0B1CB','#BE95C4','#9F86C0','#5E548E','#231942']
colors = ['gold', 'mediumturquoise', 'darkorange', 'lightgreen']
labels = data['BMI_category'].value_counts().index
values = data['BMI_category'].value_counts()

# create pie chart

pie_chart = go.Figure(go.Pie(labels = labels, values = values,pull = [0.05,0.05,0.03,0.03] ))
pie_chart.update_traces(hoverinfo = 'label+value' , textinfo = 'percent', textfont_size = 20, 
                        marker = dict(colors = [colors[0], colors[1],colors[2],colors[3]], line = dict( color = '#000000', width=2)))

# Bar Chart

bar_chart = go.Figure(go.Bar(x = labels, y = values, marker_color = [colors[0], colors[1],colors[2],colors[3]]))

# create subplots

fig = sp.make_subplots( rows = 1, cols = 2, column_width = [0.5,0.5], specs = [[{'type' : 'bar'}, {'type' : 'pie'}]],
                      subplot_titles = ("Bar Chart", "Pie Chart"))

# Add charts to subplots

fig.add_trace(bar_chart.data[0], row=1, col=1)
fig.add_trace(pie_chart.data[0], row=1, col=2)

# Update layout
fig.update_layout(
    showlegend=False,
    title=dict(
        text="Distribution of BMI",
        font=dict(size=18)
    ),
    xaxis=dict(
        title=dict(
            text="BMI-Groups",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    ),
    yaxis=dict(
        title=dict(
            text="Count",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    )
)


# Show subplots
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="5b57b85d-3e80-4177-837e-25ad8bfaf217" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("5b57b85d-3e80-4177-837e-25ad8bfaf217")) {                    Plotly.newPlot(                        "5b57b85d-3e80-4177-837e-25ad8bfaf217",                        [{"marker":{"color":["gold","mediumturquoise","darkorange","lightgreen"]},"x":["Overweight","Normal","Obese","Underweight"],"y":{"dtype":"i2","bdata":"QQE7ATcBJwA="},"type":"bar","xaxis":"x","yaxis":"y"},{"hoverinfo":"label+value","labels":["Overweight","Normal","Obese","Underweight"],"marker":{"colors":["gold","mediumturquoise","darkorange","lightgreen"],"line":{"color":"#000000","width":2}},"pull":[0.05,0.05,0.03,0.03],"textfont":{"size":20},"textinfo":"percent","values":{"dtype":"i2","bdata":"QQE7ATcBJwA="},"type":"pie","domain":{"x":[0.55,1.0],"y":[0.0,1.0]}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[ ...

# %% [markdown]
# ### Distribution of 'BloodPressureProblems'

# %%
data['BloodPressureProblems'].value_counts()
# Out:
# BloodPressureProblems
# 0    524
# 1    462
# Name: count, dtype: int64

# %%
colors = ['#D0CDD7' , '#ACB0BD']
labels = ['No','Yes']
values = data['BloodPressureProblems'].value_counts()

# create pie chart

pie_chart = go.Figure(go.Pie(labels = labels, values = values, ))
pie_chart.update_traces(hoverinfo = 'label+value' , textinfo = 'percent', textfont_size = 20, 
                        marker = dict(colors = colors, line = dict( color = '#000000', width=2)))

# Bar Chart

bar_chart = go.Figure(go.Bar(x = labels, y = values, marker_color = colors))

# create subplots

fig = sp.make_subplots( rows = 1, cols = 2, column_width = [0.5,0.5], specs = [[{'type' : 'bar'}, {'type' : 'pie'}]],
                      subplot_titles = ("Bar Chart", "Pie Chart"))

# Add charts to subplots

fig.add_trace(bar_chart.data[0], row=1, col=1)
fig.add_trace(pie_chart.data[0], row=1, col=2)

# Update layout
fig.update_layout(
    showlegend=False,
    title=dict(
        text="Distribution of Blood Pressure Problems",
        font=dict(size=18)
    ),
    xaxis=dict(
        title=dict(
            text="Blood Pressure Problems",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    ),
    yaxis=dict(
        title=dict(
            text="Count",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    )
)


# Show subplots
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="a44c8227-e8f3-42f7-8ae9-a2aee9fb5f57" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("a44c8227-e8f3-42f7-8ae9-a2aee9fb5f57")) {                    Plotly.newPlot(                        "a44c8227-e8f3-42f7-8ae9-a2aee9fb5f57",                        [{"marker":{"color":["#D0CDD7","#ACB0BD"]},"x":["No","Yes"],"y":{"dtype":"i2","bdata":"DALOAQ=="},"type":"bar","xaxis":"x","yaxis":"y"},{"hoverinfo":"label+value","labels":["No","Yes"],"marker":{"colors":["#D0CDD7","#ACB0BD"],"line":{"color":"#000000","width":2}},"textfont":{"size":20},"textinfo":"percent","values":{"dtype":"i2","bdata":"DALOAQ=="},"type":"pie","domain":{"x":[0.55,1.0],"y":[0.0,1.0]}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"t ...

# %% [markdown]
# ### Distribution of transplants

# %%
data['AnyTransplants'].value_counts()
# Out:
# AnyTransplants
# 0    931
# 1     55
# Name: count, dtype: int64

# %%
colors = ['#D3C0CD' , '#B19994']
labels = ['No','Yes']
values = data['AnyTransplants'].value_counts()

# create pie chart

pie_chart = go.Figure(go.Pie(labels = labels, values = values, ))
pie_chart.update_traces(hoverinfo = 'label+value' , textinfo = 'percent', textfont_size = 20, 
                        marker = dict(colors = colors, line = dict( color = '#000000', width=2)))

# Bar Chart

bar_chart = go.Figure(go.Bar(x = labels, y = values, marker_color = colors))

# create subplots

fig = sp.make_subplots( rows = 1, cols = 2, column_width = [0.5,0.5], specs = [[{'type' : 'bar'}, {'type' : 'pie'}]],
                      subplot_titles = ("Bar Chart", "Pie Chart"))

# Add charts to subplots

fig.add_trace(bar_chart.data[0], row=1, col=1)
fig.add_trace(pie_chart.data[0], row=1, col=2)

# Update layout
fig.update_layout(
    showlegend=False,
    title=dict(
        text="Distribution of Transplants",
        font=dict(size=18)
    ),
    xaxis=dict(
        title=dict(
            text="No. of Transplants",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    ),
    yaxis=dict(
        title=dict(
            text="Count",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    )
)

# Show subplots
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="f437cda6-bfff-4e55-afb1-6171c679e7a5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("f437cda6-bfff-4e55-afb1-6171c679e7a5")) {                    Plotly.newPlot(                        "f437cda6-bfff-4e55-afb1-6171c679e7a5",                        [{"marker":{"color":["#D3C0CD","#B19994"]},"x":["No","Yes"],"y":{"dtype":"i2","bdata":"owM3AA=="},"type":"bar","xaxis":"x","yaxis":"y"},{"hoverinfo":"label+value","labels":["No","Yes"],"marker":{"colors":["#D3C0CD","#B19994"],"line":{"color":"#000000","width":2}},"textfont":{"size":20},"textinfo":"percent","values":{"dtype":"i2","bdata":"owM3AA=="},"type":"pie","domain":{"x":[0.55,1.0],"y":[0.0,1.0]}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"t ...

# %% [markdown]
# ### Distribution of Chronic Diseases

# %%
data
# Out:
#      Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0     45         0                      0               0                   0
# 1     60         1                      0               0                   0
# 2     36         1                      1               0                   0
# 3     52         1                      1               0                   1
# 4     38         0                      0               0                   1
# ..   ...       ...                    ...             ...                 ...
# 981   18         0                      0               0                   0
# 982   64         1                      1               0                   0
# 983   56         0                      1               0                   0
# 984   47         1                      1               0                   0
# 985   21         0                      0               0                   0
#
#      Height  Weight  KnownAllergies  HistoryOfCancerInFamily  \
# 0       155      57               0                        0
# 1       180      73               0                        0
# 2       158      59               0                        0
# 3       183      93               0                        0
# 4       166      88               0                        0
# ..      ...     ...             ...                      ...
# 981     169      67               0                        0
# 982     153      70               0                        0
# 983     155      71               0                        0
# 984     158      73               1                        0
# 985     158      75               1                        0
#
#      NumberOfMajorSurgeries  PremiumPrice        BMI age_category BMI_category
# 0                         0         25000  23.725286   middle age       Normal
# 1                         0         29000  22.530864          old       Normal
# 2                         1         23000  23.634033   middle age       Normal
# 3                         2         28000  27.770313          old   Overweight
# 4                         1         23000  31.934969   middle age        Obese
# ..                      ...           ...        ...          ...          ...
# 981                       0         15000  23.458562        young       Normal
# 982                       3         28000  29.903029          old        Obese
# 983                       1         29000  29.552549          old   Overweight
# 984                       1         39000  29.242109   middle age   Overweight
# 985                       1         15000  30.043262        young        Obese
#
# [986 rows x 14 columns]

# %%
data['AnyChronicDiseases'].value_counts()
# Out:
# AnyChronicDiseases
# 0    808
# 1    178
# Name: count, dtype: int64

# %%
custom_palette(bo)

# %%
colors = [bo[3] , bo[7]]
labels = ['No','Yes']
values = data['AnyChronicDiseases'].value_counts()

# create pie chart

pie_chart = go.Figure(go.Pie(labels = labels, values = values, ))
pie_chart.update_traces(hoverinfo = 'label+value' , textinfo = 'percent', textfont_size = 20, 
                        marker = dict(colors = colors, line = dict( color = '#000000', width=2)))

# Bar Chart

bar_chart = go.Figure(go.Bar(x = labels, y = values, marker_color = colors))

# create subplots

fig = sp.make_subplots( rows = 1, cols = 2, column_width = [0.5,0.5], specs = [[{'type' : 'bar'}, {'type' : 'pie'}]],
                      subplot_titles = ("Bar Chart", "Pie Chart"))

# Add charts to subplots

fig.add_trace(bar_chart.data[0], row=1, col=1)
fig.add_trace(pie_chart.data[0], row=1, col=2)

# Update layout
fig.update_layout(
    showlegend=False,
    title=dict(
        text="Distribution of Chronic Diseases",
        font=dict(size=18)
    ),
    xaxis=dict(
        title=dict(
            text="Chronic Diseases",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    ),
    yaxis=dict(
        title=dict(
            text="Count",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    )
)

# Show subplots
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="d02a3c74-1c65-44f5-a0fc-204eeaef07f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d02a3c74-1c65-44f5-a0fc-204eeaef07f2")) {                    Plotly.newPlot(                        "d02a3c74-1c65-44f5-a0fc-204eeaef07f2",                        [{"marker":{"color":["#48cae4","#ffbf69"]},"x":["No","Yes"],"y":{"dtype":"i2","bdata":"KAOyAA=="},"type":"bar","xaxis":"x","yaxis":"y"},{"hoverinfo":"label+value","labels":["No","Yes"],"marker":{"colors":["#48cae4","#ffbf69"],"line":{"color":"#000000","width":2}},"textfont":{"size":20},"textinfo":"percent","values":{"dtype":"i2","bdata":"KAOyAA=="},"type":"pie","domain":{"x":[0.55,1.0],"y":[0.0,1.0]}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"t ...

# %% [markdown]
# ### Distribution of Allergies

# %%
data['KnownAllergies'].value_counts()
# Out:
# KnownAllergies
# 0    774
# 1    212
# Name: count, dtype: int64

# %%
# colors = ['#A167A5','#D3BCCC']
colors = ['#716969', '#BCABAE']
labels = ['No','Yes']
values = data['KnownAllergies'].value_counts()

# create pie chart

pie_chart = go.Figure(go.Pie(labels = labels, values = values, ))
pie_chart.update_traces(hoverinfo = 'label+value' , textinfo = 'percent', textfont_size = 20, 
                        marker = dict(colors = colors, line = dict( color = '#000000', width=2)))

# Bar Chart

bar_chart = go.Figure(go.Bar(x = labels, y = values, marker_color = colors))

# create subplots

fig = sp.make_subplots( rows = 1, cols = 2, column_width = [0.5,0.5], specs = [[{'type' : 'bar'}, {'type' : 'pie'}]],
                      subplot_titles = ("Bar Chart", "Pie Chart"))

# Add charts to subplots

fig.add_trace(bar_chart.data[0], row=1, col=1)
fig.add_trace(pie_chart.data[0], row=1, col=2)

# Update layout
fig.update_layout(
    showlegend=False,
    title=dict(
        text="Distribution of Known Allergies",
        font=dict(size=18)
    ),
    xaxis=dict(
        title=dict(
            text="Allergies",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    ),
    yaxis=dict(
        title=dict(
            text="Count",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    )
)

# Show subplots
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="5fa07601-9f13-4670-8083-ee39fec55aff" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("5fa07601-9f13-4670-8083-ee39fec55aff")) {                    Plotly.newPlot(                        "5fa07601-9f13-4670-8083-ee39fec55aff",                        [{"marker":{"color":["#716969","#BCABAE"]},"x":["No","Yes"],"y":{"dtype":"i2","bdata":"BgPUAA=="},"type":"bar","xaxis":"x","yaxis":"y"},{"hoverinfo":"label+value","labels":["No","Yes"],"marker":{"colors":["#716969","#BCABAE"],"line":{"color":"#000000","width":2}},"textfont":{"size":20},"textinfo":"percent","values":{"dtype":"i2","bdata":"BgPUAA=="},"type":"pie","domain":{"x":[0.55,1.0],"y":[0.0,1.0]}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"t ...

# %% [markdown]
# ### Distribution of Cancer History

# %%
data['HistoryOfCancerInFamily'].value_counts()
# Out:
# HistoryOfCancerInFamily
# 0    870
# 1    116
# Name: count, dtype: int64

# %%
colors=['#485696','#F9C784']
# labels = data['HistoryOfCancerInFamily'].value_counts().index
labels = ['No', 'Yes']
values = data['HistoryOfCancerInFamily'].value_counts()

# create pie chart

pie_chart = go.Figure(go.Pie(labels = labels, values = values, ))
pie_chart.update_traces(hoverinfo = 'label+value' , textinfo = 'percent', textfont_size = 20, 
                        marker = dict(colors = colors, line = dict( color = '#000000', width=2)))

# Bar Chart

bar_chart = go.Figure(go.Bar(x = labels, y = values, marker_color = colors))

# create subplots

fig = sp.make_subplots( rows = 1, cols = 2, column_width = [0.5,0.5], specs = [[{'type' : 'bar'}, {'type' : 'pie'}]],
                      subplot_titles = ("Bar Chart", "Pie Chart"))

# Add charts to subplots

fig.add_trace(bar_chart.data[0], row=1, col=1)
fig.add_trace(pie_chart.data[0], row=1, col=2)

# Update layout
fig.update_layout(
    showlegend=False,
    title=dict(
        text="Distribution of Cancer History",
        font=dict(size=18)
    ),
    xaxis=dict(
        title=dict(
            text="Cancer History",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    ),
    yaxis=dict(
        title=dict(
            text="Count",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    )
)

# Show subplots
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="46db035c-5cb2-4b0e-8661-ee2779ddc542" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("46db035c-5cb2-4b0e-8661-ee2779ddc542")) {                    Plotly.newPlot(                        "46db035c-5cb2-4b0e-8661-ee2779ddc542",                        [{"marker":{"color":["#485696","#F9C784"]},"x":["No","Yes"],"y":{"dtype":"i2","bdata":"ZgN0AA=="},"type":"bar","xaxis":"x","yaxis":"y"},{"hoverinfo":"label+value","labels":["No","Yes"],"marker":{"colors":["#485696","#F9C784"],"line":{"color":"#000000","width":2}},"textfont":{"size":20},"textinfo":"percent","values":{"dtype":"i2","bdata":"ZgN0AA=="},"type":"pie","domain":{"x":[0.55,1.0],"y":[0.0,1.0]}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"t ...

# %% [markdown]
# ### Distribution of No. Of Surgeries

# %%
data['NumberOfMajorSurgeries'].value_counts()
# Out:
# NumberOfMajorSurgeries
# 0    479
# 1    372
# 2    119
# 3     16
# Name: count, dtype: int64

# %%
colors = ['#006BA6','#C1B372','#FFBC42','#D81159']
labels = data['NumberOfMajorSurgeries'].value_counts().index

values = data['NumberOfMajorSurgeries'].value_counts()

# create pie chart

pie_chart = go.Figure(go.Pie(labels = labels, values = values, ))
pie_chart.update_traces(hoverinfo = 'label+value' , textinfo = 'percent', textfont_size = 20, 
                        marker = dict(colors = colors, line = dict( color = '#000000', width=2)))

# Bar Chart

bar_chart = go.Figure(go.Bar(x = labels, y = values, marker_color = colors))

# create subplots

fig = sp.make_subplots( rows = 1, cols = 2, column_width = [0.5,0.5], specs = [[{'type' : 'bar'}, {'type' : 'pie'}]],
                      subplot_titles = ("Bar Chart", "Pie Chart"))

# Add charts to subplots

fig.add_trace(bar_chart.data[0], row=1, col=1)
fig.add_trace(pie_chart.data[0], row=1, col=2)

# Update layout
fig.update_layout(
    showlegend=False,
    title=dict(
        text="Distribution of Major Surgeries",
        font=dict(size=18)
    ),
    xaxis=dict(
        title=dict(
            text="No. of Major Surgeries",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    ),
    yaxis=dict(
        title=dict(
            text="Count",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    )
)

# Show subplots
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="a528b45c-7b6a-45e4-a8b8-66932e556c97" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("a528b45c-7b6a-45e4-a8b8-66932e556c97")) {                    Plotly.newPlot(                        "a528b45c-7b6a-45e4-a8b8-66932e556c97",                        [{"marker":{"color":["#006BA6","#C1B372","#FFBC42","#D81159"]},"x":{"dtype":"i1","bdata":"AAECAw=="},"y":{"dtype":"i2","bdata":"3wF0AXcAEAA="},"type":"bar","xaxis":"x","yaxis":"y"},{"hoverinfo":"label+value","labels":{"dtype":"i1","bdata":"AAECAw=="},"marker":{"colors":["#006BA6","#C1B372","#FFBC42","#D81159"],"line":{"color":"#000000","width":2}},"textfont":{"size":20},"textinfo":"percent","values":{"dtype":"i2","bdata":"3wF0AXcAEAA="},"type":"pie","domain":{"x":[0.55,1.0],"y":[0.0,1.0]}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type ...

# %% [markdown]
# ### Distribution of Target Variable

# %%
plt.figure(figsize = (15, 6))

# Histplot
plt.subplot(1,2,1)
sns.histplot(data = data , x = 'PremiumPrice', kde = True, color = '#998DA0')
plt.xlabel('Premium Price')
plt.ylabel('Count')

# Boxplot
plt.subplot(1,2,2)
sns.boxplot(data = data, x = 'PremiumPrice', color = '#998DA0')
plt.xlabel('Premium Price')

plt.suptitle('Distribution of Premium Price')
plt.show()

# %%
#BCA0BC

# %% [markdown]
# ## 📉 Bivariate Analysis

# %% [markdown]
# ### Distribution of premium price in age-category

# %%
plt.figure(figsize = (12,6))
sns.boxplot(data = data , y = 'PremiumPrice', x = 'age_category')
plt.xlabel('Age Category')
plt.ylabel('Premium Price')
plt.title('Distrbution of Premium Price in Age category')
plt.show()

# %% [markdown]
# ### Distribtion of Premium Price in BMI Categroy

# %%
plt.figure(figsize = (12,6))
sns.boxplot(data = data , y = 'PremiumPrice', x = 'BMI_category', palette = pink)
plt.xlabel('BMI Category')
plt.ylabel('Premium Price')
plt.title('Distrbution of Premium Price in BMI category')
plt.show()

# %% [markdown]
# ### Distribution of Premium Price in 'BloodPressureProblems', 'AnyTransplants', 'AnyChronicDiseases', 'KnownAllergies',	'HistoryOfCancerInFamily' and	'NumberOfMajorSurgeries'

# %%
cols = ['BloodPressureProblems', 'AnyTransplants', 'AnyChronicDiseases', 'KnownAllergies', 'HistoryOfCancerInFamily','NumberOfMajorSurgeries']
plt.figure(figsize =(20,12))
for i in range(len(cols)):
    plt.subplot(3,3,i+1)
    sns.violinplot(data = data , x = cols[i], y = 'PremiumPrice', palette =  red[1:])
    plt.xlabel(cols[i], fontsize =14)
    plt.ylabel('Premium Price', fontsize = 14)
plt.tight_layout()
plt.show()

# %%
custom_palette(red)

# %% [markdown]
# ### Heatmap and Correlation

# %%
plt.figure(figsize=(15,12))
sns.heatmap(df.corr(),annot=True,cmap='rocket',fmt='.2f')
plt.show()

# %% [markdown]
# # ⚒ Data Preprocessing

# %% [markdown]
# ## 👯 Checking Duplicates

# %%
print(df[df.duplicated()])
# Out:
# Empty DataFrame
# Columns: [Age, Diabetes, BloodPressureProblems, AnyTransplants, AnyChronicDiseases, Height, Weight, KnownAllergies, HistoryOfCancerInFamily, NumberOfMajorSurgeries, PremiumPrice, BMI]
# Index: []

# %% [markdown]
# ## 👾 Checking Outliers

# %%
df.boxplot(rot=45, figsize=(30,15), fontsize = 25)
plt.show()

# %% [markdown]
# **Inference**
#
# The dataset contains very few outliers, and given its relatively small size, we have chosen not to remove any outliers to preserve the integrity of the data.

# %% [markdown]
# # 🛠️ Data Preparation

# %% [markdown]
# ## ✂️ Splitting data into train and test data

# %%
X = df.drop(columns=['PremiumPrice'])
y = df['PremiumPrice']

# %%
X
# Out:
#      Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0     45         0                      0               0                   0
# 1     60         1                      0               0                   0
# 2     36         1                      1               0                   0
# 3     52         1                      1               0                   1
# 4     38         0                      0               0                   1
# ..   ...       ...                    ...             ...                 ...
# 981   18         0                      0               0                   0
# 982   64         1                      1               0                   0
# 983   56         0                      1               0                   0
# 984   47         1                      1               0                   0
# 985   21         0                      0               0                   0
#
#      Height  Weight  KnownAllergies  HistoryOfCancerInFamily  \
# 0       155      57               0                        0
# 1       180      73               0                        0
# 2       158      59               0                        0
# 3       183      93               0                        0
# 4       166      88               0                        0
# ..      ...     ...             ...                      ...
# 981     169      67               0                        0
# 982     153      70               0                        0
# 983     155      71               0                        0
# 984     158      73               1                        0
# 985     158      75               1                        0
#
#      NumberOfMajorSurgeries        BMI
# 0                         0  23.725286
# 1                         0  22.530864
# 2                         1  23.634033
# 3                         2  27.770313
# 4                         1  31.934969
# ..                      ...        ...
# 981                       0  23.458562
# 982                       3  29.903029
# 983                       1  29.552549
# 984                       1  29.242109
# 985                       1  30.043262
#
# [986 rows x 11 columns]

# %%
y
# Out:
# 0      25000
# 1      29000
# 2      23000
# 3      28000
# 4      23000
#        ...
# 981    15000
# 982    28000
# 983    29000
# 984    39000
# 985    15000
# Name: PremiumPrice, Length: 986, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train,y_test = train_test_split(X,y, random_state = 42, test_size = 0.25)

# %%
X_train.shape
# Out:
# (739, 11)

# %%
X_test.shape
# Out:
# (247, 11)

# %% [markdown]
# ## 📏 Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = pd.DataFrame(scaler.fit_transform(X_train),columns = X_train.columns)
X_test_scaled = pd.DataFrame(scaler.fit_transform(X_test), columns = X_test.columns)

# %%
X_train_scaled
# Out:
#           Age  Diabetes  BloodPressureProblems  AnyTransplants  \
# 0    0.026630 -0.854798              -0.915592       -0.236039
# 1   -0.545865  1.169867              -0.915592       -0.236039
# 2   -0.903675  1.169867              -0.915592       -0.236039
# 3   -0.760551 -0.854798              -0.915592       -0.236039
# 4    0.312878  1.169867              -0.915592       -0.236039
# ..        ...       ...                    ...             ...
# 734  1.314745 -0.854798              -0.915592       -0.236039
# 735  0.312878 -0.854798               1.092190       -0.236039
# 736  1.386307  1.169867              -0.915592       -0.236039
# 737 -0.331180  1.169867              -0.915592       -0.236039
# 738  1.243183  1.169867               1.092190       -0.236039
#
#      AnyChronicDiseases    Height    Weight  KnownAllergies  \
# 0             -0.470625  1.677017  0.492592       -0.536150
# 1             -0.470625  0.974059 -0.688857       -0.536150
# 2             -0.470625 -1.235239 -0.202378       -0.536150
# 3             -0.470625  0.371523 -1.383828       -0.536150
# 4             -0.470625 -1.636929 -1.453325       -0.536150
# ..                  ...       ...       ...             ...
# 734           -0.470625 -1.335662 -1.314331       -0.536150
# 735            2.124835 -0.231013 -1.314331       -0.536150
# 736           -0.470625 -0.733126 -0.758354       -0.536150
# 737           -0.470625  0.572368 -0.966846        1.865151
# 738           -0.470625 -0.833548  1.048568       -0.536150
#
#      HistoryOfCancerInFamily  NumberOfMajorSurgeries       BMI
# 0                  -0.350857                0.447422 -0.486226
# 1                  -0.350857               -0.880469 -1.063956
# 2                  -0.350857               -0.880469  0.511056
# 3                  -0.350857               -0.880469 -1.383531
# 4                  -0.350857               -0.880469 -0.538135
# ..                       ...                     ...       ...
# 734                -0.350857               -0.880469 -0.554582
# 735                -0.350857                0.447422 -1.080669
# 736                -0.350857                3.103205 -0.330019
# 737                 2.850168                0.447422 -1.121397
# 738                 2.850168                0.447422  1.451486
#
# [739 rows x 11 columns]

# %%
X_test_scaled
# Out:
#           Age  Diabetes  BloodPressureProblems  AnyTransplants  \
# 0    0.568652 -0.838718              -1.012220       -0.263181
# 1   -0.222858 -0.838718              -1.012220       -0.263181
# 2    1.647983  1.192296               0.987927       -0.263181
# 3   -0.942412 -0.838718              -1.012220       -0.263181
# 4    0.424741  1.192296               0.987927       -0.263181
# ..        ...       ...                    ...             ...
# 242  0.928429 -0.838718               0.987927       -0.263181
# 243 -1.086323 -0.838718               0.987927       -0.263181
# 244 -0.222858  1.192296               0.987927       -0.263181
# 245 -1.302189  1.192296              -1.012220       -0.263181
# 246  0.928429 -0.838718              -1.012220       -0.263181
#
#      AnyChronicDiseases    Height    Weight  KnownAllergies  \
# 0             -0.465563 -0.270060  0.500480        2.062842
# 1              2.147938  1.638521 -0.293335        2.062842
# 2             -0.465563 -0.270060  0.716975       -0.484768
# 3             -0.465563  1.065947 -0.509830       -0.484768
# 4             -0.465563  0.302514  0.500480        2.062842
# ..                  ...       ...       ...             ...
# 242           -0.465563  0.397943  1.005635        2.062842
# 243           -0.465563 -0.842635  3.098421        2.062842
# 244           -0.465563  0.111656  0.067490       -0.484768
# 245           -0.465563  0.207085  0.716975       -0.484768
# 246           -0.465563 -1.033493 -0.293335       -0.484768
#
#      HistoryOfCancerInFamily  NumberOfMajorSurgeries       BMI
# 0                   2.461126                0.434670  0.549467
# 1                   2.461126                0.434670 -1.076196
# 2                  -0.406318               -0.924361  0.737546
# 3                   2.461126                0.434670 -0.987856
# 4                  -0.406318               -0.924361  0.186393
# ..                       ...                     ...       ...
# 242                -0.406318                0.434670  0.533402
# 243                 2.461126                0.434670  3.384906
# 244                -0.406318               -0.924361 -0.055431
# 245                -0.406318                0.434670  0.421424
# 246                -0.406318               -0.924361  0.338132
#
# [247 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      986 non-null    int64
#  1   Diabetes                 986 non-null    int64
#  2   BloodPressureProblems    986 non-null    int64
#  3   AnyTransplants           986 non-null    int64
#  4   AnyChronicDiseases       986 non-null    int64
#  5   Height                   986 non-null    int64
#  6   Weight                   986 non-null    int64
#  7   KnownAllergies           986 non-null    int64
#  8   HistoryOfCancerInFamily  986 non-null    int64
#  9   NumberOfMajorSurgeries   986 non-null    int64
#  10  PremiumPrice             986 non-null    int64
#  11  BMI                      986 non-null    float64
# dtypes: float64(1), int64(11)
# memory usage: 92.6 KB

# %% [markdown]
# # 🪖 Model Training and Evaluation

# %% [markdown]
# ## 💡 Training LightGBM model using optuna hyperparameter tuning and K-Fold cross validation

# %%
# !pip install mlflow
# Out:
# Requirement already satisfied: mlflow in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (3.9.0)
# Requirement already satisfied: mlflow-skinny==3.9.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (3.9.0)
# Requirement already satisfied: mlflow-tracing==3.9.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (3.9.0)
# Requirement already satisfied: Flask-CORS<7 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (6.0.2)
# Requirement already satisfied: Flask<4 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (3.1.2)
# Requirement already satisfied: alembic!=1.10.0,<2 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (1.18.3)
# Requirement already satisfied: cryptography<47,>=43.0.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (46.0.4)
# Requirement already satisfied: docker<8,>=4.0.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: graphene<4 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (3.4.3)
# Requirement already satisfied: gunicorn<24 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (23.0.0)
# Requirement already satisfied: huey<3,>=2.5.4 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (2.6.0)
# Requirement already satisfied: matplotlib<4 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (3.10.8)
# Requirement already satisfied: numpy<3 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (2.3.3)
# Requirement already satisfied: pandas<3 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (2.3.3)
# Requirement already satisfied: pyarrow<23,>=4.0.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (22.0.0)
# Requirement already satisfied: scikit-learn<2 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (1.8.0)
# Requirement already satisfied: scipy<2 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (1.17.0)
# Requirement already satisfied: skops<1 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (0.13.0)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (2.0.46)
# Requirement already satisfied: cachetools<7,>=5.0.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (6.2.6)
# Requirement already satisfied: click<9,>=7.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (8.3.1)
# Requirement already satisfied: cloudpickle<4 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (3.1.2)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (0.85.0)
# Requirement already satisfied: fastapi<1 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (0.128.4)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (3.1.46)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (8.7.1)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (1.39.1)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (1.39.1)
# Requirement already satisfied: packaging<26 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (25.0)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (6.33.5)
# Requirement already satisfied: pydantic<3,>=2.0.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (2.12.5)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (1.2.1)
# Requirement already satisfied: pyyaml<7,>=5.1 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (6.0.3)
# Requirement already satisfied: requests<3,>=2.17.3 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (2.32.5)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (0.5.5)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (4.15.0)
# Requirement already satisfied: uvicorn<1 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (0.40.0)
# Requirement already satisfied: Mako in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.10)
# Requirement already satisfied: cffi>=2.0.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from cryptography<47,>=43.0.0->mlflow) (2.0.0)
# Requirement already satisfied: google-auth~=2.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.9.0->mlflow) (2.48.0)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from docker<8,>=4.0.0->mlflow) (2.6.3)
# Requirement already satisfied: starlette<1.0.0,>=0.40.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from fastapi<1->mlflow-skinny==3.9.0->mlflow) (0.52.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from fastapi<1->mlflow-skinny==3.9.0->mlflow) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from fastapi<1->mlflow-skinny==3.9.0->mlflow) (0.0.4)
# Requirement already satisfied: blinker>=1.9.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from Flask<4->mlflow) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from Flask<4->mlflow) (3.1.5)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.9.0->mlflow) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.9.0->mlflow) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.9.0->mlflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.9.0->mlflow) (4.9.1)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from graphene<4->mlflow) (3.2.7)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: zipp>=3.20 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.9.0->mlflow) (3.23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from matplotlib<4->mlflow) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from matplotlib<4->mlflow) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from matplotlib<4->mlflow) (1.4.9)
# Requirement already satisfied: pillow>=8 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from matplotlib<4->mlflow) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from matplotlib<4->mlflow) (3.3.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.9.0->mlflow) (0.60b1)
# Requirement already satisfied: pytz>=2020.1 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from pandas<3->mlflow) (2025.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.9.0->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.9.0->mlflow) (2.41.5)
# Requirement already satisfied: six>=1.5 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.9.0->mlflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.9.0->mlflow) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.9.0->mlflow) (2026.1.4)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.9.0->mlflow) (0.6.2)
# Requirement already satisfied: joblib>=1.3.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from scikit-learn<2->mlflow) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from scikit-learn<2->mlflow) (3.6.0)
# Requirement already satisfied: prettytable>=3.9 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from skops<1->mlflow) (3.17.0)
# Requirement already satisfied: anyio<5,>=3.6.2 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from starlette<1.0.0,>=0.40.0->fastapi<1->mlflow-skinny==3.9.0->mlflow) (4.12.1)
# Requirement already satisfied: h11>=0.8 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from uvicorn<1->mlflow-skinny==3.9.0->mlflow) (0.16.0)
# Requirement already satisfied: pycparser in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from cffi>=2.0.0->cryptography<47,>=43.0.0->mlflow) (3.0)
# Requirement already satisfied: wcwidth in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from prettytable>=3.9->skops<1->mlflow) (0.6.0)

# %%
import optuna
import mlflow # For experimental tracking
import lightgbm as lgb
from lightgbm import early_stopping
from sklearn.metrics import  root_mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import KFold

# %%
1e-1
# Out:
# 0.1

# %%
from pathlib import Path
import os

# Project root = parent of notebooks/
PROJECT_ROOT = Path.cwd().parent

# (optional) verify
print("Project root:", PROJECT_ROOT)
# Out:
# Project root: /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction

# %%
import os
MLRUNS_DIR = PROJECT_ROOT / "mlruns"
MLRUNS_DIR.mkdir(exist_ok=True)
mlflow.set_tracking_uri(f"file://{MLRUNS_DIR.resolve()}")
mlflow.set_experiment("Insurance Premium Prediction Model Experimental Tracking")
# Out:
# <Experiment: artifact_location=('file:///Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine '
#  'Learning/Insurance Premium '
#  'Prediction/Insurance-Premium-Prediction/mlruns/619644230268117697'), creation_time=1770488112521, experiment_id='619644230268117697', last_update_time=1770488112521, lifecycle_stage='active', name='Insurance Premium Prediction Model Experimental Tracking', tags={}>

# %%
def objective(trial):
    with mlflow.start_run(nested = True, run_name = f"trial {trial.number}") as child_run:
        params = {
            'objective':'regression',
            'metric':'rmse',
            'n_estimators': trial.suggest_int('n_estimators',500,2000),
            'boosting_type': trial.suggest_categorical('boosting',['gbdt','dart']),
            'max_depth':trial.suggest_int('max_depth',3,10),
            'num_leaves': trial.suggest_int('num_leaves',4,128),
            'learning_rate':trial.suggest_loguniform('learning_rate',1e-4,1e-1),
            'feature_fraction':trial.suggest_uniform('feature_fraction',0.6,1.0),
            'bagging_fraction':trial.suggest_uniform('bagging_fraction',0.6,0.9),
            'bagging_freq':trial.suggest_int('bagging_freq',1,20),
            'min_data_in_leaf':trial.suggest_int('min_data_in_leaf', 5,30),
            'reg_alpha':trial.suggest_float('reg_alpha',1e-8,10.0,log = True),
            'reg_lambda':trial.suggest_float('reg_lambda',1e-8,10.0,log = True),
            #'device_type':'gpu',
            'random_state':42,
            'verbose':-1
            }
        # log model params
        mlflow.log_params(params)
        model = lgb.LGBMRegressor(**params)
        scores = []
        kf = KFold(n_splits = 5, shuffle = True, random_state = 42)
        for train_idx,val_idx in kf.split(X_train):
            X_tr, X_val = X_train.iloc[train_idx], X_train.iloc[val_idx]
            y_tr, y_val = y_train.iloc[train_idx], y_train.iloc[val_idx]
            model.fit(X_tr,y_tr, eval_set = [(X_val, y_val)], callbacks=[early_stopping(stopping_rounds=100, verbose=False)])
            y_pred = model.predict(X_val)
            rmse = root_mean_squared_error(y_val,y_pred)
            scores.append(rmse)
        # log tuning metric RMSE
        mlflow.log_metrics({"RMSE":np.mean(scores)})
        # Log the model file
        mlflow.sklearn.log_model(model, name="model")
        # Make it easy to retrieve the best-performing child run later
        trial.set_user_attr("run_id", child_run.info.run_id)
    
        return float(np.mean(scores))

# %%
with mlflow.start_run(run_name = 'study') as run:
    
    study = optuna.create_study(direction='minimize')
    study.optimize(objective, n_trials = 50, show_progress_bar = True)
    # log model's best params, lowest rmse score and its id
    mlflow.log_params(study.best_params)
    mlflow.log_metrics({"best_error": study.best_value})
    if best_run_id := study.best_trial.user_attrs.get("run_id"):
        mlflow.log_param("best_child_run_id", best_run_id)
# Out:
# [I 2026-03-15 17:40:06,136] A new study created in memory with name: no-name-e93038f3-68f9-4f0e-bf6a-dc3d96fe29ba
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2026-03-15 17:40:09,391] Trial 0 finished with value: 5069.251192144231 and parameters: {'n_estimators': 891, 'boosting': 'gbdt', 'max_depth': 5, 'num_leaves': 126, 'learning_rate': 0.0004251571321819584, 'feature_fraction': 0.7564784401555786, 'bagging_fraction': 0.801467560834612, 'bagging_freq': 16, 'min_data_in_leaf': 10, 'reg_alpha': 7.278426817291779, 'reg_lambda': 0.000311769225151556}. Best is trial 0 with value: 5069.251192144231.
# [I 2026-03-15 17:40:11,127] Trial 1 finished with value: 2998.2332090259997 and parameters: {'n_estimators': 917, 'boosting': 'gbdt', 'max_depth': 5, 'num_leaves': 61, 'learning_rate': 0.08433510639289384, 'feature_fraction': 0.8889077239116654, 'bagging_fraction': 0.8840642221099408, 'bagging_freq': 3, 'min_data_in_leaf': 13, 'reg_alpha': 0.0008376405277121478, 'reg_lambda': 0.2372976544627297}. Best is trial 1 with value: 2998.2332090259997.
# [I 2026-03-15 17:40:16,140] Trial 2 finished with value: 19146.91844783461 and parameters: {'n_estimators': 652, 'boosting': 'dart', 'max_depth': 6, 'num_leaves': 116, 'learning_rate': 0.0007219472231194906, 'feature_fraction': 0.9433911285038089, 'bagging_fraction': 0.8520743449678895, 'bagging_freq': 3, 'min_data_in_leaf': 15, 'reg_alpha': 0.021698906950357887, 'reg_lambda': 8.674187356062924e-06}. Best is trial 1 with value: 2998.2332090259997.
# [I 2026-03-15 17:40:19,175] Trial 3 finished with value: 5470.830837731699 and parameters: {'n_estimators': 1384, 'boosting': 'gbdt', 'max_depth': 4, 'num_leaves': 123, 'learning_rate': 0.00016489000422634494, 'feature_fraction': 0.7085460032920946, 'bagging_fraction': 0.6985743871616665, 'bagging_freq': 12, 'min_data_in_leaf': 12, 'reg_alpha': 0.008795071991588766, 'reg_lambda': 4.28658206180665e-08}. Best is trial 1 with value: 2998.2332090259997.
# [I 2026-03-15 17:40:21,906] Trial 4 finished with value: 5654.352607369105 and parameters: {'n_estimators': 645, 'boosting': 'gbdt', 'max_depth': 9, 'num_leaves': 116, 'learning_rate': 0.00028226285198293866, 'feature_fraction': 0.6677841288179028, 'bagging_fraction': 0.6462940452327051, 'bagging_freq': 16, 'min_data_in_leaf': 16, 'reg_alpha': 0.03880806447289221, 'reg_lambda': 0.006043635733229431}. Best is trial 1 with value: 2998.2332090259997.
# [I 2026-03-15 17:40:24,740] Trial 5 finished with value: 28280.41975033581 and parameters: {'n_estimators': 839, 'boosting': 'dart', 'max_depth': 7, 'num_leaves': 80, 'learning_rate': 0.00041571962635433883, 'feature_fraction': 0.6181412894411856, 'bagging_fraction': 0.6370114604201267, 'bagging_freq': 14, 'min_data_in_leaf': 18, 'reg_alpha': 1.2007574138724201e-08, 'reg_lambda': 4.127259409376024}. Best is trial 1 with value: 2998.2332090259997.
# [I 2026-03-15 17:40:26,760] Trial 6 finished with value: 3107.2080621519553 and parameters: {'n_estimators': 746, 'boosting': 'gbdt', 'max_depth': 6, 'num_leaves': 15, 'learning_rate': 0.009579362689058428, 'feature_fraction': 0.8450727959427158, 'bagging_fraction': 0.8945436421165395, 'bagging_freq': 17, 'min_data_in_leaf': 20, 'reg_alpha': 0.9930853131979069, 'reg_lambda': 1.316545408419758e-05}. Best is trial 1 with value: 2998.2332090259997.
# [I 2026-03-15 17:40:33,351] Trial 7 finished with value: 14185.825312934376 and parameters: {'n_estimators': 1110, 'boosting': 'dart', 'max_depth': 7, 'num_leaves': 31, 'learning_rate': 0.0015872507710861503, 'feature_fraction': 0.9714250776979918, 'bagging_fraction': 0.6192868055412905, 'bagging_freq': 17, 'min_data_in_leaf': 20, 'reg_alpha': 0.2248055445711995, 'reg_lambda': 3.9118647467990444e-05}. Best is trial 1 with value: 2998.2332090259997.
# [I 2026-03-15 17:40:35,160] Trial 8 finished with value: 3004.4425876915784 and parameters: {'n_estimators': 545, 'boosting': 'gbdt', 'max_depth': 5, 'num_leaves': 103, 'learning_rate': 0.022170338295715932, 'feature_fraction': 0.9046046274635685, 'bagging_fraction': 0.7806530706258621, 'bagging_freq': 6, 'min_data_in_leaf': 8, 'reg_alpha': 2.9083699610220196e-06, 'reg_lambda': 0.07780953127603868}. Best is trial 1 with value: 2998.2332090259997.
# [I 2026-03-15 17:40:37,008] Trial 9 finished with value: 3399.309217317129 and parameters: {'n_estimators': 1565, 'boosting': 'gbdt', 'max_depth': 9, 'num_leaves': 14, 'learning_rate': 0.0370394223216481, 'feature_fraction': 0.7921526110021176, 'bagging_fraction': 0.8602319522442222, 'bagging_freq': 18, 'min_data_in_leaf': 30, 'reg_alpha': 6.918111414419515, 'reg_lambda': 0.0001252373125507149}. Best is trial 1 with value: 2998.2332090259997.
# [I 2026-03-15 17:40:42,745] Trial 10 finished with value: 21883.650795270623 and parameters: {'n_estimators': 1917, 'boosting': 'dart', 'max_depth': 3, 'num_leaves': 50, 'learning_rate': 0.08981945191036221, 'feature_fraction': 0.8685115369005921, 'bagging_fraction': 0.7172417715045872, 'bagging_freq': 8, 'min_data_in_leaf': 5, 'reg_alpha': 7.115986586735728e-05, 'reg_lambda': 5.297248649203781}. Best is trial 1 with value: 2998.2332090259997.
# [I 2026-03-15 17:40:44,601] Trial 11 finished with value: 3025.7552707220566 and parameters: {'n_estimators': 1088, 'boosting': 'gbdt', 'max_depth': 4, 'num_leaves': 77, 'learning_rate': 0.015138298038358628, 'feature_fraction': 0.9113954765629363, 'bagging_fraction': 0.7869219690512868, 'bagging_freq': 1, 'min_data_in_leaf': 6, 'reg_alpha': 6.119151719993975e-06, 'reg_lambda': 0.038296095041970964}. Best is trial 1 with value: 2998.2332090259997.
# [I 2026-03-15 17:40:46,206] Trial 12 finished with value: 3042.070303268505 and parameters: {'n_estimators': 507, 'boosting': 'gbdt', 'max_depth': 5, 'num_leaves': 86, 'learning_rate': 0.08168581344781284, 'feature_fraction': 0.9987794314143879, 'bagging_fraction': 0.7848603169146187, 'bagging_freq': 6, 'min_data_in_leaf': 10, 'reg_alpha': 7.334002837749459e-07, 'reg_lambda': 0.10560027555983208}. Best is trial 1 with value: 2998.2332090259997.
# [I 2026-03-15 17:40:48,017] Trial 13 finished with value: 3300.5633295886173 and parameters: {'n_estimators': 978, 'boosting': 'gbdt', 'max_depth': 3, 'num_leaves': 53, 'learning_rate': 0.010324407643675029, 'feature_fraction': 0.8821086037821351, 'bagging_fraction': 0.834383326258239, 'bagging_freq': 7, 'min_data_in_leaf': 24, 'reg_alpha': 0.0004147559677018126, 'reg_lambda': 0.17693642071032167}. Best is trial 1 with value: 2998.2332090259997.
# [I 2026-03-15 17:40:49,920] Trial 14 finished with value: 2986.0644605848 and parameters: {'n_estimators': 504, 'boosting': 'gbdt', 'max_depth': 8, 'num_leaves': 97, 'learning_rate': 0.031149487040632043, 'feature_fraction': 0.81618937786443, 'bagging_fraction': 0.741048033893408, 'bagging_freq': 4, 'min_data_in_leaf': 8, 'reg_alpha': 0.0003906899437852834, 'reg_lambda': 0.003645321627466664}. Best is trial 14 with value: 2986.0644605848.
# [I 2026-03-15 17:40:53,150] Trial 15 finished with value: 3043.258572161337 and parameters: {'n_estimators': 1336, 'boosting': 'gbdt', 'max_depth': 10, 'num_leaves': 95, 'learning_rate': 0.0047845647949326916, 'feature_fraction': 0.8165942802704759, 'bagging_fraction': 0.7296772926602249, 'bagging_freq': 3, 'min_data_in_leaf': 13, 'reg_alpha': 0.0014144901229241299, 'reg_lambda': 0.0027448403556883925}. Best is trial 14 with value: 2986.0644605848.
# [I 2026-03-15 17:40:54,996] Trial 16 finished with value: 3091.371768560396 and parameters: {'n_estimators': 1595, 'boosting': 'gbdt', 'max_depth': 8, 'num_leaves': 61, 'learning_rate': 0.03933535954447456, 'feature_fraction': 0.7519630133957663, 'bagging_fraction': 0.6679487845912693, 'bagging_freq': 10, 'min_data_in_leaf': 9, 'reg_alpha': 6.060127330789149e-05, 'reg_lambda': 1.7382252125489714e-07}. Best is trial 14 with value: 2986.0644605848.
# [I 2026-03-15 17:40:58,330] Trial 17 finished with value: 3047.4357804643355 and parameters: {'n_estimators': 1191, 'boosting': 'gbdt', 'max_depth': 8, 'num_leaves': 38, 'learning_rate': 0.0043370342318026335, 'feature_fraction': 0.8212969816106032, 'bagging_fraction': 0.7533507798498128, 'bagging_freq': 1, 'min_data_in_leaf': 13, 'reg_alpha': 0.0022544120875914414, 'reg_lambda': 1.0317038440624797}. Best is trial 14 with value: 2986.0644605848.
# [I 2026-03-15 17:41:04,154] Trial 18 finished with value: 3382.8694565502783 and parameters: {'n_estimators': 818, 'boosting': 'dart', 'max_depth': 8, 'num_leaves': 104, 'learning_rate': 0.036062593721959635, 'feature_fraction': 0.7697801079023975, 'bagging_fraction': 0.8884264434257609, 'bagging_freq': 4, 'min_data_in_leaf': 24, 'reg_alpha': 4.098742110498402e-05, 'reg_lambda': 0.0037383392550402604}. Best is trial 14 with value: 2986.0644605848.
# [I 2026-03-15 17:41:08,095] Trial 19 finished with value: 3255.0529286314695 and parameters: {'n_estimators': 1002, 'boosting': 'gbdt', 'max_depth': 7, 'num_leaves': 66, 'learning_rate': 0.0022110430992937705, 'feature_fraction': 0.7048283687385385, 'bagging_fraction': 0.6893430148624072, 'bagging_freq': 20, 'min_data_in_leaf': 7, 'reg_alpha': 1.8941215818174568e-07, 'reg_lambda': 6.532572055786414e-07}. Best is trial 14 with value: 2986.0644605848.
# [I 2026-03-15 17:41:10,227] Trial 20 finished with value: 3036.340254110113 and parameters: {'n_estimators': 698, 'boosting': 'gbdt', 'max_depth': 10, 'num_leaves': 74, 'learning_rate': 0.09539991172092556, 'feature_fraction': 0.9375964923435497, 'bagging_fraction': 0.7471213934024584, 'bagging_freq': 9, 'min_data_in_leaf': 11, 'reg_alpha': 0.00033623375609807154, 'reg_lambda': 0.011699617107535896}. Best is trial 14 with value: 2986.0644605848.
# [I 2026-03-15 17:41:12,242] Trial 21 finished with value: 2978.5523327158708 and parameters: {'n_estimators': 640, 'boosting': 'gbdt', 'max_depth': 5, 'num_leaves': 96, 'learning_rate': 0.019971713806497673, 'feature_fraction': 0.8939068792940801, 'bagging_fraction': 0.8186419235793917, 'bagging_freq': 5, 'min_data_in_leaf': 8, 'reg_alpha': 3.668025551577405e-06, 'reg_lambda': 0.4416866726854262}. Best is trial 21 with value: 2978.5523327158708.
# [I 2026-03-15 17:41:14,071] Trial 22 finished with value: 3043.9496944181387 and parameters: {'n_estimators': 513, 'boosting': 'gbdt', 'max_depth': 4, 'num_leaves': 92, 'learning_rate': 0.044523135247168985, 'feature_fraction': 0.8393432038770361, 'bagging_fraction': 0.8258219946561974, 'bagging_freq': 5, 'min_data_in_leaf': 8, 'reg_alpha': 8.687273471219148e-06, 'reg_lambda': 0.5665558188259049}. Best is trial 21 with value: 2978.5523327158708.
# [I 2026-03-15 17:41:16,241] Trial 23 finished with value: 2981.0616785869106 and parameters: {'n_estimators': 628, 'boosting': 'gbdt', 'max_depth': 6, 'num_leaves': 103, 'learning_rate': 0.020701403385683163, 'feature_fraction': 0.8694583745379927, 'bagging_fraction': 0.8685167546297682, 'bagging_freq': 3, 'min_data_in_leaf': 5, 'reg_alpha': 1.5170234346739465e-07, 'reg_lambda': 0.0010816854330312335}. Best is trial 21 with value: 2978.5523327158708.
# [I 2026-03-15 17:41:19,102] Trial 24 finished with value: 2983.4713749010502 and parameters: {'n_estimators': 696, 'boosting': 'gbdt', 'max_depth': 6, 'num_leaves': 105, 'learning_rate': 0.00878742835283431, 'feature_fraction': 0.8632464813129125, 'bagging_fraction': 0.8151868372804868, 'bagging_freq': 1, 'min_data_in_leaf': 5, 'reg_alpha': 7.758925375194681e-08, 'reg_lambda': 0.0009682774652901526}. Best is trial 21 with value: 2978.5523327158708.
# [I 2026-03-15 17:41:21,946] Trial 25 finished with value: 2966.6307852559416 and parameters: {'n_estimators': 747, 'boosting': 'gbdt', 'max_depth': 6, 'num_leaves': 109, 'learning_rate': 0.00746903891265121, 'feature_fraction': 0.8654818604214056, 'bagging_fraction': 0.8216865920244529, 'bagging_freq': 1, 'min_data_in_leaf': 5, 'reg_alpha': 4.2507931509833115e-08, 'reg_lambda': 0.0008297212455275193}. Best is trial 25 with value: 2966.6307852559416.
# [I 2026-03-15 17:41:28,800] Trial 26 finished with value: 8830.465019005047 and parameters: {'n_estimators': 797, 'boosting': 'dart', 'max_depth': 6, 'num_leaves': 111, 'learning_rate': 0.005482528628062665, 'feature_fraction': 0.9369574393432606, 'bagging_fraction': 0.8520861631248084, 'bagging_freq': 2, 'min_data_in_leaf': 5, 'reg_alpha': 1.1718953527022282e-08, 'reg_lambda': 0.00040079296799004285}. Best is trial 25 with value: 2966.6307852559416.
# [I 2026-03-15 17:41:30,705] Trial 27 finished with value: 2989.020269777912 and parameters: {'n_estimators': 621, 'boosting': 'gbdt', 'max_depth': 5, 'num_leaves': 87, 'learning_rate': 0.017484097600855595, 'feature_fraction': 0.9143016689142118, 'bagging_fraction': 0.8709560464874183, 'bagging_freq': 5, 'min_data_in_leaf': 7, 'reg_alpha': 8.019232248437192e-08, 'reg_lambda': 3.7701365909316995e-06}. Best is trial 25 with value: 2966.6307852559416.
# [I 2026-03-15 17:41:33,268] Trial 28 finished with value: 3578.0278442146314 and parameters: {'n_estimators': 1021, 'boosting': 'gbdt', 'max_depth': 4, 'num_leaves': 112, 'learning_rate': 0.0014032496483018476, 'feature_fraction': 0.8553347942218387, 'bagging_fraction': 0.8303999872488558, 'bagging_freq': 12, 'min_data_in_leaf': 6, 'reg_alpha': 1.042214636479552e-06, 'reg_lambda': 0.018731496680996718}. Best is trial 25 with value: 2966.6307852559416.
# [I 2026-03-15 17:41:35,501] Trial 29 finished with value: 3026.3342925850116 and parameters: {'n_estimators': 899, 'boosting': 'gbdt', 'max_depth': 5, 'num_leaves': 126, 'learning_rate': 0.007751191959002415, 'feature_fraction': 0.7800301389949769, 'bagging_fraction': 0.8055770437070221, 'bagging_freq': 7, 'min_data_in_leaf': 10, 'reg_alpha': 3.752571360498728e-07, 'reg_lambda': 8.135567128905717e-05}. Best is trial 25 with value: 2966.6307852559416.
# [I 2026-03-15 17:41:39,411] Trial 30 finished with value: 2966.6160813296656 and parameters: {'n_estimators': 1928, 'boosting': 'gbdt', 'max_depth': 7, 'num_leaves': 127, 'learning_rate': 0.0026874435924181656, 'feature_fraction': 0.9707834057466715, 'bagging_fraction': 0.8438881925145991, 'bagging_freq': 4, 'min_data_in_leaf': 10, 'reg_alpha': 5.4829871650222364e-08, 'reg_lambda': 0.0006637606265832807}. Best is trial 30 with value: 2966.6160813296656.
# [I 2026-03-15 17:41:43,492] Trial 31 finished with value: 2971.622804373612 and parameters: {'n_estimators': 1895, 'boosting': 'gbdt', 'max_depth': 7, 'num_leaves': 127, 'learning_rate': 0.0027585745576572504, 'feature_fraction': 0.965360839886442, 'bagging_fraction': 0.8432031443605761, 'bagging_freq': 2, 'min_data_in_leaf': 10, 'reg_alpha': 4.297372425491244e-08, 'reg_lambda': 0.0004279223526322134}. Best is trial 30 with value: 2966.6160813296656.
# [I 2026-03-15 17:41:47,830] Trial 32 finished with value: 2968.4982326365257 and parameters: {'n_estimators': 1994, 'boosting': 'gbdt', 'max_depth': 7, 'num_leaves': 127, 'learning_rate': 0.002164557505400431, 'feature_fraction': 0.9920477733259542, 'bagging_fraction': 0.8392804535973853, 'bagging_freq': 2, 'min_data_in_leaf': 10, 'reg_alpha': 3.3606414133142366e-08, 'reg_lambda': 0.0003142377908844633}. Best is trial 30 with value: 2966.6160813296656.
# [I 2026-03-15 17:41:52,271] Trial 33 finished with value: 3214.594590843305 and parameters: {'n_estimators': 1943, 'boosting': 'gbdt', 'max_depth': 7, 'num_leaves': 128, 'learning_rate': 0.0008832692964253681, 'feature_fraction': 0.9984078540680666, 'bagging_fraction': 0.8440426755340682, 'bagging_freq': 2, 'min_data_in_leaf': 15, 'reg_alpha': 3.357730028643039e-08, 'reg_lambda': 0.0003352577547674575}. Best is trial 30 with value: 2966.6160813296656.
# [I 2026-03-15 17:41:56,096] Trial 34 finished with value: 2960.7015776017533 and parameters: {'n_estimators': 1805, 'boosting': 'gbdt', 'max_depth': 7, 'num_leaves': 120, 'learning_rate': 0.002784238006619581, 'feature_fraction': 0.9713663290094113, 'bagging_fraction': 0.7945206719179753, 'bagging_freq': 2, 'min_data_in_leaf': 12, 'reg_alpha': 3.475006897491102e-08, 'reg_lambda': 2.4219150665040194e-05}. Best is trial 34 with value: 2960.7015776017533.
# [I 2026-03-15 17:42:00,869] Trial 35 finished with value: 3171.9290876913165 and parameters: {'n_estimators': 1794, 'boosting': 'gbdt', 'max_depth': 9, 'num_leaves': 116, 'learning_rate': 0.001080928106558905, 'feature_fraction': 0.9550378493047569, 'bagging_fraction': 0.7658367624643757, 'bagging_freq': 3, 'min_data_in_leaf': 15, 'reg_alpha': 1.0122401524500961e-08, 'reg_lambda': 1.516035263793576e-05}. Best is trial 34 with value: 2960.7015776017533.
# [I 2026-03-15 17:42:15,572] Trial 36 finished with value: 9731.571119742304 and parameters: {'n_estimators': 1776, 'boosting': 'dart', 'max_depth': 6, 'num_leaves': 120, 'learning_rate': 0.00207781535391785, 'feature_fraction': 0.9717341841989676, 'bagging_fraction': 0.7986477308909252, 'bagging_freq': 2, 'min_data_in_leaf': 12, 'reg_alpha': 6.020583581124358e-07, 'reg_lambda': 2.6557550238331624e-06}. Best is trial 34 with value: 2960.7015776017533.
# [I 2026-03-15 17:42:19,670] Trial 37 finished with value: 3638.5351826472847 and parameters: {'n_estimators': 1998, 'boosting': 'gbdt', 'max_depth': 7, 'num_leaves': 118, 'learning_rate': 0.0006509688807469214, 'feature_fraction': 0.9297792588626653, 'bagging_fraction': 0.7661532207680062, 'bagging_freq': 4, 'min_data_in_leaf': 17, 'reg_alpha': 3.2116059779113594e-08, 'reg_lambda': 7.387895959706267e-05}. Best is trial 34 with value: 2960.7015776017533.
# [I 2026-03-15 17:42:23,658] Trial 38 finished with value: 2961.6051616274535 and parameters: {'n_estimators': 1630, 'boosting': 'gbdt', 'max_depth': 8, 'num_leaves': 109, 'learning_rate': 0.0028328832461805, 'feature_fraction': 0.982988208398535, 'bagging_fraction': 0.8057217374152191, 'bagging_freq': 1, 'min_data_in_leaf': 12, 'reg_alpha': 1.7919023568833946e-07, 'reg_lambda': 3.182197139414499e-05}. Best is trial 34 with value: 2960.7015776017533.
# [I 2026-03-15 17:42:37,426] Trial 39 finished with value: 6834.589965420202 and parameters: {'n_estimators': 1579, 'boosting': 'dart', 'max_depth': 8, 'num_leaves': 112, 'learning_rate': 0.003800985102588859, 'feature_fraction': 0.9826668704311715, 'bagging_fraction': 0.8023434419924883, 'bagging_freq': 1, 'min_data_in_leaf': 12, 'reg_alpha': 1.4722624826300624e-06, 'reg_lambda': 7.129234506329171e-07}. Best is trial 34 with value: 2960.7015776017533.
# [I 2026-03-15 17:42:40,437] Trial 40 finished with value: 3123.6216880557536 and parameters: {'n_estimators': 1667, 'boosting': 'gbdt', 'max_depth': 9, 'num_leaves': 109, 'learning_rate': 0.006469835802666302, 'feature_fraction': 0.9598744912946553, 'bagging_fraction': 0.7722963151917208, 'bagging_freq': 4, 'min_data_in_leaf': 19, 'reg_alpha': 1.4618282015559461e-05, 'reg_lambda': 1.7065909995084088e-05}. Best is trial 34 with value: 2960.7015776017533.
# [I 2026-03-15 17:42:43,974] Trial 41 finished with value: 2953.6209943593926 and parameters: {'n_estimators': 1809, 'boosting': 'gbdt', 'max_depth': 7, 'num_leaves': 122, 'learning_rate': 0.003490184371194653, 'feature_fraction': 0.9871889112558938, 'bagging_fraction': 0.8762207182391977, 'bagging_freq': 1, 'min_data_in_leaf': 14, 'reg_alpha': 2.4763422378329856e-07, 'reg_lambda': 3.594868297420598e-05}. Best is trial 41 with value: 2953.6209943593926.
# [I 2026-03-15 17:42:48,462] Trial 42 finished with value: 2977.769564144768 and parameters: {'n_estimators': 1785, 'boosting': 'gbdt', 'max_depth': 8, 'num_leaves': 120, 'learning_rate': 0.0031189365767204137, 'feature_fraction': 0.9501120576495187, 'bagging_fraction': 0.8792097762317097, 'bagging_freq': 1, 'min_data_in_leaf': 14, 'reg_alpha': 2.00555867482662e-07, 'reg_lambda': 4.2639400975806645e-05}. Best is trial 41 with value: 2953.6209943593926.
# [I 2026-03-15 17:42:52,295] Trial 43 finished with value: 3129.3449535666587 and parameters: {'n_estimators': 1438, 'boosting': 'gbdt', 'max_depth': 7, 'num_leaves': 121, 'learning_rate': 0.0014925361373132225, 'feature_fraction': 0.9778979921461771, 'bagging_fraction': 0.8585549450720856, 'bagging_freq': 3, 'min_data_in_leaf': 16, 'reg_alpha': 2.993883546608577e-07, 'reg_lambda': 4.199335074883163e-06}. Best is trial 41 with value: 2953.6209943593926.
# [I 2026-03-15 17:42:55,952] Trial 44 finished with value: 5278.375953766369 and parameters: {'n_estimators': 1711, 'boosting': 'gbdt', 'max_depth': 6, 'num_leaves': 114, 'learning_rate': 0.00014093713592396967, 'feature_fraction': 0.9300370305444897, 'bagging_fraction': 0.81340237643796, 'bagging_freq': 14, 'min_data_in_leaf': 14, 'reg_alpha': 8.472186911867093e-08, 'reg_lambda': 0.00011571696842309579}. Best is trial 41 with value: 2953.6209943593926.
# [I 2026-03-15 17:42:58,556] Trial 45 finished with value: 2978.6169451342034 and parameters: {'n_estimators': 1844, 'boosting': 'gbdt', 'max_depth': 7, 'num_leaves': 122, 'learning_rate': 0.013342004147065215, 'feature_fraction': 0.9221243679516484, 'bagging_fraction': 0.8964076989543271, 'bagging_freq': 1, 'min_data_in_leaf': 11, 'reg_alpha': 1.462024093251961e-06, 'reg_lambda': 0.0008949216370384691}. Best is trial 41 with value: 2953.6209943593926.
# [I 2026-03-15 17:43:02,006] Trial 46 finished with value: 3060.8342155203113 and parameters: {'n_estimators': 1683, 'boosting': 'gbdt', 'max_depth': 8, 'num_leaves': 108, 'learning_rate': 0.003397748288677526, 'feature_fraction': 0.8920922705281163, 'bagging_fraction': 0.7889790509123388, 'bagging_freq': 3, 'min_data_in_leaf': 17, 'reg_alpha': 1.777932002826884e-08, 'reg_lambda': 2.4549044649734446e-05}. Best is trial 41 with value: 2953.6209943593926.
# [I 2026-03-15 17:43:05,824] Trial 47 finished with value: 4929.678995497248 and parameters: {'n_estimators': 1439, 'boosting': 'gbdt', 'max_depth': 6, 'num_leaves': 21, 'learning_rate': 0.0003471406603466556, 'feature_fraction': 0.6401178929635437, 'bagging_fraction': 0.873976593045843, 'bagging_freq': 6, 'min_data_in_leaf': 13, 'reg_alpha': 8.851133173631837e-08, 'reg_lambda': 6.682060709963118e-06}. Best is trial 41 with value: 2953.6209943593926.
# [I 2026-03-15 17:43:17,507] Trial 48 finished with value: 5636.158386205892 and parameters: {'n_estimators': 1507, 'boosting': 'dart', 'max_depth': 7, 'num_leaves': 102, 'learning_rate': 0.006026851661471976, 'feature_fraction': 0.9802326788816712, 'bagging_fraction': 0.8261796871097791, 'bagging_freq': 2, 'min_data_in_leaf': 22, 'reg_alpha': 4.71598817212439e-07, 'reg_lambda': 9.852912024196603e-07}. Best is trial 41 with value: 2953.6209943593926.
# [I 2026-03-15 17:43:21,002] Trial 49 finished with value: 4190.907196641901 and parameters: {'n_estimators': 1739, 'boosting': 'gbdt', 'max_depth': 8, 'num_leaves': 86, 'learning_rate': 0.0005846210309107672, 'feature_fraction': 0.9511040015794003, 'bagging_fraction': 0.797360937763921, 'bagging_freq': 4, 'min_data_in_leaf': 30, 'reg_alpha': 0.05350072796311967, 'reg_lambda': 0.00016574359077776586}. Best is trial 41 with value: 2953.6209943593926.

# %%
params = study.best_params
params
# Out:
# {'n_estimators': 1809,
#  'boosting': 'gbdt',
#  'max_depth': 7,
#  'num_leaves': 122,
#  'learning_rate': 0.003490184371194653,
#  'feature_fraction': 0.9871889112558938,
#  'bagging_fraction': 0.8762207182391977,
#  'bagging_freq': 1,
#  'min_data_in_leaf': 14,
#  'reg_alpha': 2.4763422378329856e-07,
#  'reg_lambda': 3.594868297420598e-05}

# %%
model = lgb.LGBMRegressor(**params)
model.fit(X_train, y_train)
model.predict(X_test)
# Out:
# array([30402.92735066, 27955.47258865, 28567.82355597, 14781.32201344,
#        25196.99939733, 28363.0747362 , 23939.89674434, 23874.99251722,
#        27778.76341588, 28204.56069858, 21838.8347129 , 28823.34850939,
#        14855.39867028, 17914.44715768, 34837.45579979, 28969.0362694 ,
#        27736.7079517 , 29412.81416004, 28361.85252574, 24204.06905616,
#        36118.5536132 , 14424.76452018, 23166.63452905, 32903.00323983,
#        35610.11257084, 25357.31904859, 24932.50770111, 28276.12066298,
#        14866.59236817, 27946.04976992, 28370.105805  , 25107.39947442,
#        13923.07099776, 26625.08152975, 16459.53164908, 33926.66222387,
#        23155.7540464 , 23218.25724538, 17420.29700736, 28277.75320877,
#        25436.76335861, 23385.18365554, 23236.48661546, 23077.90572937,
#        20067.05052395, 25186.71477231, 27195.12245256, 27529.442026  ,
#        16578.8043918 , 25340.00872201, 23442.08358441, 20433.45047224,
#        26750.78777603, 14848.68105167, 29682.45735878, 23221.94702927,
#        23116.16576257, 24224.50050884, 26204.20195421, 29540.2812511 ,
#        23370.98530719, 19621.60695587, 25210.10632221, 25285.65328774,
#        28988.96618766, 28438.28940576, 34497.28370623, 15606.20278746,
#        28835.24089095, 28134.45588265, 33094.36077296, 23818.03791217,
#        26602.95937775, 17131.90587738, 15108.01600668, 14982.72681481,
#        27053.8747138 , 23446.14519079, 21832.42301481, 14319.66136238,
#        16821.21116325, 33490.66470318, 25311.66827808, 16516.02982464,
#        23114.2401514 , 26301.98875788, 23455.73625041, 29021.00702369,
#        31051.95785392, 15731.16715149, 27378.28610228, 35290.83142166,
#        28030.15329156, 28910.99101556, 22281.46611995, 24744.74309066,
#        24997.77165744, 16001.67069985, 28084.42082787, 28827.96575079,
#        23122.25740691, 16482.98717536, 28114.84358458, 16286.25458672,
#        33094.92583405, 27870.45789433, 22464.36755952, 13986.10642637,
#        25428.93584425, 19842.42966888, 29234.60664177, 23184.23992954,
#        18292.83150274, 28997.50259858, 28041.32497173, 24628.49677471,
#        25160.61136696, 23578.00849849, 14687.15758125, 25186.36028144,
#        36022.71774409, 29545.36969983, 25309.29374754, 34457.71319401,
#        28532.31114377, 27465.17264589, 28121.48300944, 35112.57197912,
#        18120.48785868, 35162.23391263, 23029.63563776, 14570.86975937,
#        27564.50785637, 22830.04728396, 33564.76367873, 28177.40884001,
#        27378.63730215, 23091.27049883, 29387.11505221, 21940.93529409,
#        24575.92952727, 22914.93366014, 29025.88192706, 30229.19191334,
#        23260.82420479, 27233.30397951, 33179.96750103, 23101.27155779,
#        33789.79673558, 30883.11081637, 15004.64778864, 22938.0384461 ,
#        15231.24040725, 23501.16157668, 14875.94567085, 27995.68694625,
#        21903.4314664 , 23466.23382949, 30430.13290047, 23672.09633763,
#        29815.73762553, 28251.26364622, 25307.79568869, 29158.7555741 ,
#        22796.98756524, 27675.34655675, 21786.07998637, 18279.23996998,
#        15607.82787441, 27997.08944012, 22623.69277257, 15732.82521978,
#        29015.39810692, 26927.02830574, 21707.33939004, 17242.60955139,
#        15798.95479847, 17429.54699256, 14978.35957431, 23995.91621733,
#        28109.45937059, 15417.83605952, 15722.13134102, 14735.04172474,
#        27483.18323416, 15505.33869299, 27871.94040155, 24608.35148466,
#        30221.52684056, 28276.71449738, 29816.03846471, 23159.93562275,
#        23142.18710967, 34572.25192473, 29019.37344431, 14973.90567689,
#        27189.53936079, 15838.7703117 , 14724.52738695, 23257.72661084,
#        28157.10030204, 22871.02414295, 14707.88220314, 33274.37399564,
#        23144.41803049, 32097.53435216, 14723.57391711, 21538.77393738,
#        27928.7741022 , 30044.16456398, 35892.53661675, 22660.04125068,
#        28553.12992753, 26431.90588725, 26645.71630061, 33206.8564929 ,
#        27196.00026496, 22821.23940823, 22901.10668611, 28788.3250038 ,
#        25504.83200714, 16877.87461525, 28246.78212672, 28970.45065658,
#        27712.00131528, 14500.86657548, 28433.18487493, 23019.46477572,
#        23554.81627757, 35431.1005746 , 28884.48696354, 18272.19526937,
#        32159.26939923, 22703.29155166, 15592.20073368, 21816.59635579,
#        25484.67594323, 23774.58467078, 30465.69823574, 23649.12237025,
#        28795.44293893, 23097.39964464, 30712.77852883, 15997.81741453,
#        22601.79552864, 16493.52078   , 28793.7112074 ])

# %%
lgb_regressor = lgb.train(params, lgb.Dataset(X_train, label = y_train))
y_pred = lgb_regressor.predict(X_test)
y_pred
# Out:
# array([30402.92735066, 27955.47258865, 28567.82355597, 14781.32201344,
#        25196.99939733, 28363.0747362 , 23939.89674434, 23874.99251722,
#        27778.76341588, 28204.56069858, 21838.8347129 , 28823.34850939,
#        14855.39867028, 17914.44715768, 34837.45579979, 28969.0362694 ,
#        27736.7079517 , 29412.81416004, 28361.85252574, 24204.06905616,
#        36118.5536132 , 14424.76452018, 23166.63452905, 32903.00323983,
#        35610.11257084, 25357.31904859, 24932.50770111, 28276.12066298,
#        14866.59236817, 27946.04976992, 28370.105805  , 25107.39947442,
#        13923.07099776, 26625.08152975, 16459.53164908, 33926.66222387,
#        23155.7540464 , 23218.25724538, 17420.29700736, 28277.75320877,
#        25436.76335861, 23385.18365554, 23236.48661546, 23077.90572937,
#        20067.05052395, 25186.71477231, 27195.12245256, 27529.442026  ,
#        16578.8043918 , 25340.00872201, 23442.08358441, 20433.45047224,
#        26750.78777603, 14848.68105167, 29682.45735878, 23221.94702927,
#        23116.16576257, 24224.50050884, 26204.20195421, 29540.2812511 ,
#        23370.98530719, 19621.60695587, 25210.10632221, 25285.65328774,
#        28988.96618766, 28438.28940576, 34497.28370623, 15606.20278746,
#        28835.24089095, 28134.45588265, 33094.36077296, 23818.03791217,
#        26602.95937775, 17131.90587738, 15108.01600668, 14982.72681481,
#        27053.8747138 , 23446.14519079, 21832.42301481, 14319.66136238,
#        16821.21116325, 33490.66470318, 25311.66827808, 16516.02982464,
#        23114.2401514 , 26301.98875788, 23455.73625041, 29021.00702369,
#        31051.95785392, 15731.16715149, 27378.28610228, 35290.83142166,
#        28030.15329156, 28910.99101556, 22281.46611995, 24744.74309066,
#        24997.77165744, 16001.67069985, 28084.42082787, 28827.96575079,
#        23122.25740691, 16482.98717536, 28114.84358458, 16286.25458672,
#        33094.92583405, 27870.45789433, 22464.36755952, 13986.10642637,
#        25428.93584425, 19842.42966888, 29234.60664177, 23184.23992954,
#        18292.83150274, 28997.50259858, 28041.32497173, 24628.49677471,
#        25160.61136696, 23578.00849849, 14687.15758125, 25186.36028144,
#        36022.71774409, 29545.36969983, 25309.29374754, 34457.71319401,
#        28532.31114377, 27465.17264589, 28121.48300944, 35112.57197912,
#        18120.48785868, 35162.23391263, 23029.63563776, 14570.86975937,
#        27564.50785637, 22830.04728396, 33564.76367873, 28177.40884001,
#        27378.63730215, 23091.27049883, 29387.11505221, 21940.93529409,
#        24575.92952727, 22914.93366014, 29025.88192706, 30229.19191334,
#        23260.82420479, 27233.30397951, 33179.96750103, 23101.27155779,
#        33789.79673558, 30883.11081637, 15004.64778864, 22938.0384461 ,
#        15231.24040725, 23501.16157668, 14875.94567085, 27995.68694625,
#        21903.4314664 , 23466.23382949, 30430.13290047, 23672.09633763,
#        29815.73762553, 28251.26364622, 25307.79568869, 29158.7555741 ,
#        22796.98756524, 27675.34655675, 21786.07998637, 18279.23996998,
#        15607.82787441, 27997.08944012, 22623.69277257, 15732.82521978,
#        29015.39810692, 26927.02830574, 21707.33939004, 17242.60955139,
#        15798.95479847, 17429.54699256, 14978.35957431, 23995.91621733,
#        28109.45937059, 15417.83605952, 15722.13134102, 14735.04172474,
#        27483.18323416, 15505.33869299, 27871.94040155, 24608.35148466,
#        30221.52684056, 28276.71449738, 29816.03846471, 23159.93562275,
#        23142.18710967, 34572.25192473, 29019.37344431, 14973.90567689,
#        27189.53936079, 15838.7703117 , 14724.52738695, 23257.72661084,
#        28157.10030204, 22871.02414295, 14707.88220314, 33274.37399564,
#        23144.41803049, 32097.53435216, 14723.57391711, 21538.77393738,
#        27928.7741022 , 30044.16456398, 35892.53661675, 22660.04125068,
#        28553.12992753, 26431.90588725, 26645.71630061, 33206.8564929 ,
#        27196.00026496, 22821.23940823, 22901.10668611, 28788.3250038 ,
#        25504.83200714, 16877.87461525, 28246.78212672, 28970.45065658,
#        27712.00131528, 14500.86657548, 28433.18487493, 23019.46477572,
#        23554.81627757, 35431.1005746 , 28884.48696354, 18272.19526937,
#        32159.26939923, 22703.29155166, 15592.20073368, 21816.59635579,
#        25484.67594323, 23774.58467078, 30465.69823574, 23649.12237025,
#        28795.44293893, 23097.39964464, 30712.77852883, 15997.81741453,
#        22601.79552864, 16493.52078   , 28793.7112074 ])

# %% [markdown]
# ## 📉 Evaluating Model Performance

# %% [markdown]
# ### Evaluation metrics for LightGBM Regressor : R2 Score, Adjusted R2, Root Mean Squared Error, Mean, Absolute Error

# %%
def adj_r2_score(r_squared,n,d):
    # n is no. of sample
    # d is no. of features
    # r_squared is standard R²
    adj_r2 = 1 - (((1-r_squared)*(n-1))/(n-d-1))
    return adj_r2

# %%
r2_score = r2_score(y_test,y_pred)
adjusted_r2 = adj_r2_score(r2_score,len(y_test), X_test.shape[1])
rmse = root_mean_squared_error(y_test,y_pred)
mae = mean_absolute_error(y_test,y_pred)

# %% [markdown]
# **Log final model**

# %%
with mlflow.start_run(run_name = "best LGBM Model") as run:
    mlflow.log_params(params)
    mlflow.log_metrics({"RMSE": rmse,"MAE":mae,"R2":r2_score,"Adjusted R2": adjusted_r2})
    mlflow.sklearn.log_model(model, name="best model")

# %%
metrics = pd.DataFrame({'metric':['R2 Score', 'Adjusted R2','Root Mean Squared Error', 'Mean Absoulte Error'], 
                        'values':[r2_score, adjusted_r2, rmse, mae]})
metrics
# Out:
#                     metric       values
# 0                 R2 Score     0.834928
# 1              Adjusted R2     0.827201
# 2  Root Mean Squared Error  2683.234073
# 3      Mean Absoulte Error  1445.062230

# %% [markdown]
# ### Prediction Intervals for LightGBM Model

# %% [markdown]
# **Computing Prediction Intervals**

# %%
X_fit,X_cal, y_fit, y_cal = train_test_split(X_train, y_train, test_size = 0.2, random_state = 42)

# %%
model = lgb.LGBMRegressor(**params)
model.fit(X_fit,y_fit)
# Out:
# LGBMRegressor(bagging_fraction=0.8762207182391977, bagging_freq=1,
#               boosting='gbdt', feature_fraction=0.9871889112558938,
#               learning_rate=0.003490184371194653, max_depth=7,
#               min_data_in_leaf=14, n_estimators=1809, num_leaves=122,
#               reg_alpha=2.4763422378329856e-07,
#               reg_lambda=3.594868297420598e-05)

# %%
y_cal_pred = model.predict(X_cal)
residual  = np.abs(y_cal, y_cal_pred)

# %%
alpha = 0.10
q = np.quantile(residual, 1 - alpha)
pi_low = y_pred - q
pi_high = y_pred + q

# %%
coverage = np.mean((y_test >= pi_low) & (y_test <= pi_high))
coverage
# Out:
# np.float64(1.0)

# %% [markdown]
# **Visualizing Prediction Interval**

# %%
outside = (y_test < pi_low )| (y_test > pi_high)
df_plot = pd.DataFrame({
    'Predicted': y_pred,
    'Actual' : y_test,
    'Inside_PI': ~outside
})

df_plot
# Out:
#         Predicted  Actual  Inside_PI
# 613  30402.927351   31000       True
# 451  27955.472589   31000       True
# 731  28567.823556   29000       True
# 436  14781.322013   15000       True
# 275  25196.999397   23000       True
# ..            ...     ...        ...
# 597  30712.778529   29000       True
# 204  15997.817415   39000       True
# 514  22601.795529   23000       True
# 628  16493.520780   15000       True
# 945  28793.711207   29000       True
#
# [247 rows x 3 columns]

# %%
x_inside = df_plot[df_plot['Inside_PI']==True]['Predicted']
y_inside = df_plot.loc[df_plot['Inside_PI']==True]['Actual']
x_outside = df_plot[~df_plot['Inside_PI']]['Predicted']
y_outside = df_plot[~df_plot['Inside_PI']]['Actual']

# %%
# Reference diagonal line

min_val = min(df_plot['Actual'].min(), df_plot['Predicted'].min())
max_val = max(df_plot['Actual'].max(), df_plot['Predicted'].max())

fig = go.Figure()

# Points Inside the prediction interval

fig.add_trace(go.Scatter(
    x = x_inside,
    y = y_inside,
    mode = 'markers',
    name = 'Inside PI',
    marker = dict(size = 8, opacity = 0.6)
    
))

# Points outside the prediction Interval

fig.add_trace(go.Scatter(
    x = x_outside,
    y = y_outside,
    mode = 'markers',
    name = 'Outside PI',
    marker = dict(size = 8, color = 'red')
    
))

# Prediction Line

fig.add_trace(go.Scatter(
    x = [min_val, max_val],
    y = [min_val, max_val],
    mode = 'lines',
    name = 'perfect prediction',
    line = dict(dash = 'dash', color = 'grey')
))

fig.update_layout(
    title = 'Prediction Interval Coverage',
    xaxis_title = 'Predicted',
    yaxis_title = 'Actual',
    template = 'plotly_white',
    width = 800,
    height = 600
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="823afba4-2936-486f-8ba1-4828fe1652b1" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("823afba4-2936-486f-8ba1-4828fe1652b1")) {                    Plotly.newPlot(                        "823afba4-2936-486f-8ba1-4828fe1652b1",                        [{"marker":{"opacity":0.6,"size":8},"mode":"markers","name":"Inside PI","x":{"dtype":"f8","bdata":"9JK2Wbuw3UDse+Q+3kzbQI4eJLX05dtA9Im8N6nezEAJOiD2P5vYQG9UesjEsttAoltCZPlg10D17WaFv1DXQLRLztuwINtAkkp84iOL20CKqO9rtVPVQO5R+k3WJdxAU6ygB7MDzUCbOjuenH7RQFRx6ZWuAuFAh+I8UkJK3EAHpBRPLRbbQH23Mhs0udxARSPIj3ay20DrgWprBKPXQPIHM7fRouFApyHM22EszEAsvh+cqJ\\u002fxuaOAL\u002fYQN9oclmF5NZAXYCJ1Fz000A\u002fI+xqsh\u002faQMWEsyxXAM1AKsZdRZ383EBCqSCcfK3WQNCZ2psKk9ZAKThWCCCo10DFWdHsDJfZQB+fBAAS2dxAjt5FD7\u002fS1kAGdF3YZinTQPmm+82GnthAK2V3z2mx2EDpwQTWPU\u002fcQBm8n4WSxdtAnhUfFCnY4ECDi\u002fD0GXvOQMbjwWrPKNxAjmkuLZ1520DMvHOLyyjgQJ4rJ22CQtdAzvJxZr362UC\u002fG+X5+brQQOrMgQwCgs1AwpBECF1DzUAkkk\u002f7d2vaQJdQzkqJ5dZABLGsEhtS1UDTyYWn1PfLQO7dsoNNbdBAa5k\u002fRVVa4EBgaBHF6rfYQG+dpegBIdBAR\u002fijXo+S1kDJHc9Hf6\u002fZQIAFuh7v59ZApHoTc0BX3EAfg3pN\u002fVLeQKlYOGWVuc5Ay+5\u002fT5K82kBrmQGbWjvhQNpih8+JX9tAl4PMbL873ECnyOjUXcLVQCkizI4vKthAcN\u002fVYnFp2EBNI37Z1UDPQBMA2O4abdtA3Wnczv0m3ECl1lp5kJTWQOWQ4S2\u002fGNBAxi9K\u002fbV020DVK0yWIM\u002fPQGK8bqDdKOBAzQMkTp0320C6WxiGF\u002fDVQKwbYZ8NUctAAEbf5DvV2EAv47F\u002fm2DTQPwEONOmjNxAX3ABWw+k1kBlQVc3Nd3RQMw5kypgUdxAETtWzFRi20BjIijLHw3YQAjioiAnkthA\u002fEE9i4AG10BVX58rlK\u002fMQN3h2Q6XmNhAiXXC99aW4UC5eympV9rcQGF9wsxSt9hAOT180jbT4EATksfpE93bQC1WoQxL0tpA62mg6V5220D6J6dNEiXhQN2gEzkfstFAVVU2fEcr4UA6BEquaH3WQCtlRlRvdcxA2gG4gCDr2kBxT7MGg0vWQOViDnCYY+BAX0VvKlqE20DO+Y7JqLzaQFZR2k\u002fRjNZAtPUDXcey3EBCwdvbO23VQGX1X337\u002f9dAnXQWwbtg1kDxMH5xeFjcQPrgTkhMhd1AmHDFvzS31kDUfWZ0U5jaQIW4xPV+M+BAoO8zYVGP1kDTmtt+uX\u002fgQKKLnRfHKN5ANPG86lJOzUBPn+Z1gmbWQFIsqsWev81AKblFV0rz1kDQDL4L+Q3NQCxm7fbrVttAh0Mlndtj1UDH9Q\u002f3jurWQLrzcIGIt91Aq01lKgYe10BUskE17x3dQFhplN\u002fQlttAgz+Q7PK22ECoeFNbsHncQGfURDQ\u002fQ9ZAVlr8LdYG20DHIX8ehUbVQBEPq1vP2dFAzuXJ9+l7zkBhDWO5RVfbQPXAYlbsF9ZAFD7NoGm6zkDWdZV62VXcQFvkws\u002fBS9pAdf+QuNUy1UAk1OMCp9bQQJsX1jZ6285ANhrtAWMF0UCF5ocGLkHNQNP\u002fTaP6btdAYeJTZl1z20DPlv8D6xzOQNNdyM8Qtc5Arno8V4XHzEC+yBu6y9baQOa8SlqrSM5ACP+JL\u002fw320BYh7l+FgjYQE9zwbdhg91AHjRTui2d20A6tTR2Ah7dQBM5PuH7ndZAgdWa+YuZ1kDsdcQPiOHgQOf6gubXVtxA4mg47fM+zUBKI+OEYo3aQKflkpli785Aj1hqgUPCzECPwsqAbrbWQO4\u002fWWtGf9tAL+KOi8FV1kDTWAjs8LnMQDC2xfdLP+BAlPYCwRqa1kBladMyYljfQIezHXbJwcxAg6cwiLEI1UBn8uOKMUbbQD1ZN4gKV91AHOP2K5GG4UCg39mjAiHWQP6Ku1BI4ttA2oQO+vnP2UA5hN7XbQXaQOnJY2jbNuBAyk5XBACP2kBd4XZST0nWQAD+8dNGXdZAYbrczBQd3EBp4Zo\u002fNejYQDo+svl3e9BASjtdDrKV20D2sI7XnErcQEerjBUAENtAXgLy625SzEDGqv3US8TbQF6m4r7detZAg0TkPbQA10CvOeg340zhQEwhaSofNdxA4hRLfwzY0UAvSNY90WffQAFOyKjSK9ZANSaksRl0zkDyd7EqJk7VQE5op0Ir49hAdPg+a6U310As9uSvbMDdQKwG6tRHGNdAsYUcWdwe3EC0GseTWY7WQJ6WatMx\u002ft1ApRIKoeg+z0Cc9fDpchLWQBmndVRhG9BAQA9shG0e3EA="},"y":{"dtype":"i4","bdata":"..."},"type":"scatter"},{"marker":{"color":"red","size":8},"mode":"markers","name":"Outside PI","x":[],"y":[],"type":"scatter"},{"line":{"color":"grey","dash":"dash"},"mode":"lines","name":"perfect prediction","x":[13923.070997759583,39000],"y":[13923.070997759583,39000],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size ...

# %% [markdown]
# **Inference**
#
# - All test points lie within the 90% prediction interval, resulting in 100% empirical coverage on the test set, indicating conservative uncertainty estimates.
# - The prediction intervals are conservative, meaning they are wider than strictly necessary to guarantee coverage.
# - The model captures the general relationship between features and insurance cost, but individual predictions can still vary substantially
# - The model does not show clear systematic over-prediction or under-prediction across the test set.
# - The model prioritizes reliability over precision, which is acceptable and often preferred in insurance risk estimation.

# %%
import matplotlib.pyplot as plt
import numpy as np

idx = np.arange(len(y_test))

plt.figure(figsize=(10, 6))
plt.plot(idx, y_test.values, label="Actual", color="black")
plt.plot(idx, y_pred, label="Prediction", color="blue")
plt.fill_between(
    idx,
    pi_low,
    pi_high,
    color="blue",
    alpha=0.25,
    label="Prediction Interval (90%)"
)

plt.xlabel("Test Sample Index")
plt.ylabel("Target Value")
plt.title("Predictions with Prediction Intervals")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Feature Importance using SHAP

# %%
import shap
explainer = shap.TreeExplainer(lgb_regressor)
shap_values = explainer.shap_values(X_test)

# %%
shap.summary_plot(shap_values,X_test)

# %%
plt.figure(figsize = (20,8))
shap.summary_plot(shap_values,X_test, plot_type = 'bar')
plt.show()

# %% [markdown]
# **Model Insights**:
#
# - Age contributes the most to the model’s predictions, followed by AnyTransplants, Weight, AnyChronicDiseases, and HistoryOfCancerInFamily.
# - Features such as BMI, NumberOfMajorSurgeries, Height, BloodPressureProblems, Diabetes, and KnownAllergies contribute less to the final prediction.

# %% [markdown]
# #  📂 Saving the model

# %%
import pickle
import os
MODELS_DIR = PROJECT_ROOT / "models"
MODELS_DIR.mkdir(exist_ok=True)

model_path = MODELS_DIR / "insurance_lgbm_model.pkl"



with open(model_path,"wb") as f:
    pickle.dump(model,f)

print("Model saved at:", model_path)
print("File exists:", os.path.exists(model_path))
# Out:
# Model saved at: /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/models/insurance_lgbm_model.pkl
# File exists: True

# %%
with open(model_path, "rb") as f:
    loaded_model = pickle.load(f)

preds = loaded_model.predict(X_train.head(5))
print(preds)
# Out:
# [23501.16355537 23569.32455085 15054.63498404 20722.99305537
#  24291.97317368]

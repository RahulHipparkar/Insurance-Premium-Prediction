# %% [markdown]
# # 🏆 About Project

# %% [markdown]
# ## 🎯  Objective
#
# Insurance companies need to accurately predict the cost of health insurance for individuals to set premiums appropriately. However, traditional methods of cost prediction often rely on broad actuarial tables and historical averages, which may not account for the nuanced differences among individuals. By leveraging machine learning techniques, insurers can predict more accurately the insurance costs tailored to individual profiles, leading to more competitive pricing and better risk management.
#
# **Insurance Cost Prediction need**
# The primary need for this project arises from the challenges insurers face in pricing policies accurately while remaining competitive in the market. Inaccurate predictions can lead to losses for insurers and unfairly high premiums for policyholders. By implementing a machine learning model, insurers can:
# - Enhance Precision in Pricing: Use individual data points to determine premiums that reflect actual risk more closely than generic estimates.
# - Increase Competitiveness: Offer rates that are attractive to consumers while ensuring that the pricing is sustainable for the insurer.
# - Improve Customer Satisfaction: Fair and transparent pricing based on personal health data can increase trust and satisfaction among policyholders.
# - Enable Personalized Offerings: Create customized insurance packages based on predicted costs, which can cater more directly to the needs and preferences of individuals.
# - Risk Assessment: Insurers can use the model to refine their risk assessment processes, identifying key factors that influence costs most significantly.
# - Policy Development: The insights gained from the model can inform the development of new insurance products or adjustments to existing ones.
# - Strategic Decision Making: Predictive analytics can aid in broader strategic decisions, such as entering new markets or adjusting policy terms based on risk predictions.
# - Customer Engagement: Insights from the model can be used in customer engagement initiatives, such as personalized marketing and tailored advice for policyholders.

# %% [markdown]
# ## 📚 Data Description

# %% [markdown]
# The dataset comprises the following 11 attributes:
# 1. Age: Numeric, ranging from 18 to 66 years.
# 2. Diabetes: Binary (0 or 1), where 1 indicates the presence of diabetes.
# 3. BloodPressureProblems: Binary (0 or 1), indicating the presence of blood pressure-related issues.
# 4. AnyTransplants: Binary (0 or 1), where 1 indicates the person has had a transplant.
# 5. AnyChronicDiseases: Binary (0 or 1), indicating the presence of any chronic diseases.
# 6. Height: Numeric, measured in centimeters, ranging from 145 cm to 188 cm.
# 7. Weight: Numeric, measured in kilograms, ranging from 51 kg to 132 kg.
# 8. KnownAllergies: Binary (0 or 1), where 1 indicates known allergies.
# 9. HistoryOfCancerInFamily: Binary (0 or 1), indicating a family history of cancer.
# 10. NumberOfMajorSurgeries: Numeric, counting the number of major surgeries, ranging from 0 to 3 surgeries.
# 11. PremiumPrice: Numeric, representing the premium price in currency, ranging from 15,000 to 40,000.

# %% [markdown]
# # 🚀 Let's Get Started

# %% [markdown]
# ## 📚 Importing Libraries

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objs as go
import plotly.subplots as sp
from plotly.subplots import make_subplots
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
import plotly.express as px
import warnings
import time
import datetime as dt
warnings.filterwarnings("ignore")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.1.min"</script>

# %% [markdown]
# ## 📊 Importing Dataset

# %%
from pathlib import Path
DATA_PATH = Path("..") / "data" / "insurance.csv"
df = pd.read_csv(DATA_PATH)

# %% [markdown]
# ## 🎨 Custom Color Palette

# %%
def custom_palette(custom_colors):
    customPalette=sns.set_palette(sns.color_palette(custom_colors))
    sns.palplot(sns.color_palette(custom_colors),size=0.8)
    plt.tick_params(axis='both',labelsize=0,length=0)
    return

# %%
#defining colour palette
red = ["#4f000b","#720026","#ce4257","#ff7f51","#ff9b54"]
bo = ["#6930c3","#5e60ce","#0096c7","#48cae4","#ade8f4","#ff7f51","#ff9b54","#ffbf69"]
pink = ["#aa4465","#dd2d4a","#f26a8d","#f49cbb","#ffcbf2","#e2afff","#ff86c8","#ffa3a5","#ffbf81","#e9b827","#f9e576"]
custom_palette(pink)

# %% [markdown]
# ## 📉 Basic Analysis

# %% [markdown]
# **Shape of the data**

# %%
df.shape
# Out:
# (986, 11)

# %% [markdown]
# **Inference**
#
# - Shape of the data is 986 * 11
# - Number of rows: 986
# - Number of Columns: 11

# %% [markdown]
# **First Few Rows**

# %%
df.head()
# Out:
#    Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0   45         0                      0               0                   0
# 1   60         1                      0               0                   0
# 2   36         1                      1               0                   0
# 3   52         1                      1               0                   1
# 4   38         0                      0               0                   1
#
#    Height  Weight  KnownAllergies  HistoryOfCancerInFamily  \
# 0     155      57               0                        0
# 1     180      73               0                        0
# 2     158      59               0                        0
# 3     183      93               0                        0
# 4     166      88               0                        0
#
#    NumberOfMajorSurgeries  PremiumPrice
# 0                       0         25000
# 1                       0         29000
# 2                       1         23000
# 3                       2         28000
# 4                       1         23000

# %% [markdown]
# **Columns in the dataframe**

# %%
df.columns
# Out:
# Index(['Age', 'Diabetes', 'BloodPressureProblems', 'AnyTransplants',
#        'AnyChronicDiseases', 'Height', 'Weight', 'KnownAllergies',
#        'HistoryOfCancerInFamily', 'NumberOfMajorSurgeries', 'PremiumPrice'],
#       dtype='object')

# %% [markdown]
# **Concise Summary**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      986 non-null    int64
#  1   Diabetes                 986 non-null    int64
#  2   BloodPressureProblems    986 non-null    int64
#  3   AnyTransplants           986 non-null    int64
#  4   AnyChronicDiseases       986 non-null    int64
#  5   Height                   986 non-null    int64
#  6   Weight                   986 non-null    int64
#  7   KnownAllergies           986 non-null    int64
#  8   HistoryOfCancerInFamily  986 non-null    int64
#  9   NumberOfMajorSurgeries   986 non-null    int64
#  10  PremiumPrice             986 non-null    int64
# dtypes: int64(11)
# memory usage: 84.9 KB

# %% [markdown]
# **Inference**
#
# - There are no missing values in the dataset.
# - All columns are of numeric type

# %% [markdown]
# **Descriptive Statistics**

# %%
df.describe().T
# Out:
#                          count          mean          std      min      25%  \
# Age                      986.0     41.745436    13.963371     18.0     30.0
# Diabetes                 986.0      0.419878     0.493789      0.0      0.0
# BloodPressureProblems    986.0      0.468560     0.499264      0.0      0.0
# AnyTransplants           986.0      0.055781     0.229615      0.0      0.0
# AnyChronicDiseases       986.0      0.180527     0.384821      0.0      0.0
# Height                   986.0    168.182556    10.098155    145.0    161.0
# Weight                   986.0     76.950304    14.265096     51.0     67.0
# KnownAllergies           986.0      0.215010     0.411038      0.0      0.0
# HistoryOfCancerInFamily  986.0      0.117647     0.322353      0.0      0.0
# NumberOfMajorSurgeries   986.0      0.667343     0.749205      0.0      0.0
# PremiumPrice             986.0  24336.713996  6248.184382  15000.0  21000.0
#
#                              50%      75%      max
# Age                         42.0     53.0     66.0
# Diabetes                     0.0      1.0      1.0
# BloodPressureProblems        0.0      1.0      1.0
# AnyTransplants               0.0      0.0      1.0
# AnyChronicDiseases           0.0      0.0      1.0
# Height                     168.0    176.0    188.0
# Weight                      75.0     87.0    132.0
# KnownAllergies               0.0      0.0      1.0
# HistoryOfCancerInFamily      0.0      0.0      1.0
# NumberOfMajorSurgeries       1.0      1.0      3.0
# PremiumPrice             23000.0  28000.0  40000.0

# %% [markdown]
# **Missing Values Check**

# %%
df.isnull().sum()
# Out:
# Age                        0
# Diabetes                   0
# BloodPressureProblems      0
# AnyTransplants             0
# AnyChronicDiseases         0
# Height                     0
# Weight                     0
# KnownAllergies             0
# HistoryOfCancerInFamily    0
# NumberOfMajorSurgeries     0
# PremiumPrice               0
# dtype: int64

# %% [markdown]
# **Inference**
#
# There are no missing values in the dataset

# %% [markdown]
# # 📈 Exploratory Data Analysis

# %% [markdown]
# ## 📊 Univariate Analysis

# %% [markdown]
# **Creating feature BMI using height and weight of the users**

# %% [markdown]
# The formula for Body Mass Index (BMI) is:
#
# $$ \mathrm{BMI} = \frac{\text{weight}_{\mathrm{kg}}}{\text{height}_{\mathrm{m}}^{2}} $$

# %%
df['BMI'] = df['Weight'] / ((df['Height'] / 100) ** 2)
df
# Out:
#      Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0     45         0                      0               0                   0
# 1     60         1                      0               0                   0
# 2     36         1                      1               0                   0
# 3     52         1                      1               0                   1
# 4     38         0                      0               0                   1
# ..   ...       ...                    ...             ...                 ...
# 981   18         0                      0               0                   0
# 982   64         1                      1               0                   0
# 983   56         0                      1               0                   0
# 984   47         1                      1               0                   0
# 985   21         0                      0               0                   0
#
#      Height  Weight  KnownAllergies  HistoryOfCancerInFamily  \
# 0       155      57               0                        0
# 1       180      73               0                        0
# 2       158      59               0                        0
# 3       183      93               0                        0
# 4       166      88               0                        0
# ..      ...     ...             ...                      ...
# 981     169      67               0                        0
# 982     153      70               0                        0
# 983     155      71               0                        0
# 984     158      73               1                        0
# 985     158      75               1                        0
#
#      NumberOfMajorSurgeries  PremiumPrice        BMI
# 0                         0         25000  23.725286
# 1                         0         29000  22.530864
# 2                         1         23000  23.634033
# 3                         2         28000  27.770313
# 4                         1         23000  31.934969
# ..                      ...           ...        ...
# 981                       0         15000  23.458562
# 982                       3         28000  29.903029
# 983                       1         29000  29.552549
# 984                       1         39000  29.242109
# 985                       1         15000  30.043262
#
# [986 rows x 12 columns]

# %%
sns.boxplot(data=df, x='BMI')
plt.show()

# %% [markdown]
# ##

# %% [markdown]
# ### Distribution of Age

# %%
data = df.copy()

# %%
df
# Out:
#      Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0     45         0                      0               0                   0
# 1     60         1                      0               0                   0
# 2     36         1                      1               0                   0
# 3     52         1                      1               0                   1
# 4     38         0                      0               0                   1
# ..   ...       ...                    ...             ...                 ...
# 981   18         0                      0               0                   0
# 982   64         1                      1               0                   0
# 983   56         0                      1               0                   0
# 984   47         1                      1               0                   0
# 985   21         0                      0               0                   0
#
#      Height  Weight  KnownAllergies  HistoryOfCancerInFamily  \
# 0       155      57               0                        0
# 1       180      73               0                        0
# 2       158      59               0                        0
# 3       183      93               0                        0
# 4       166      88               0                        0
# ..      ...     ...             ...                      ...
# 981     169      67               0                        0
# 982     153      70               0                        0
# 983     155      71               0                        0
# 984     158      73               1                        0
# 985     158      75               1                        0
#
#      NumberOfMajorSurgeries  PremiumPrice        BMI
# 0                         0         25000  23.725286
# 1                         0         29000  22.530864
# 2                         1         23000  23.634033
# 3                         2         28000  27.770313
# 4                         1         23000  31.934969
# ..                      ...           ...        ...
# 981                       0         15000  23.458562
# 982                       3         28000  29.903029
# 983                       1         29000  29.552549
# 984                       1         39000  29.242109
# 985                       1         15000  30.043262
#
# [986 rows x 12 columns]

# %%
data['Age'].max()
# Out:
# np.int64(66)

# %%
data['age_category'] = pd.cut(data['Age'], bins=[17,30,50,66], labels = ['young','middle age','old'])
data
# Out:
#      Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0     45         0                      0               0                   0
# 1     60         1                      0               0                   0
# 2     36         1                      1               0                   0
# 3     52         1                      1               0                   1
# 4     38         0                      0               0                   1
# ..   ...       ...                    ...             ...                 ...
# 981   18         0                      0               0                   0
# 982   64         1                      1               0                   0
# 983   56         0                      1               0                   0
# 984   47         1                      1               0                   0
# 985   21         0                      0               0                   0
#
#      Height  Weight  KnownAllergies  HistoryOfCancerInFamily  \
# 0       155      57               0                        0
# 1       180      73               0                        0
# 2       158      59               0                        0
# 3       183      93               0                        0
# 4       166      88               0                        0
# ..      ...     ...             ...                      ...
# 981     169      67               0                        0
# 982     153      70               0                        0
# 983     155      71               0                        0
# 984     158      73               1                        0
# 985     158      75               1                        0
#
#      NumberOfMajorSurgeries  PremiumPrice        BMI age_category
# 0                         0         25000  23.725286   middle age
# 1                         0         29000  22.530864          old
# 2                         1         23000  23.634033   middle age
# 3                         2         28000  27.770313          old
# 4                         1         23000  31.934969   middle age
# ..                      ...           ...        ...          ...
# 981                       0         15000  23.458562        young
# 982                       3         28000  29.903029          old
# 983                       1         29000  29.552549          old
# 984                       1         39000  29.242109   middle age
# 985                       1         15000  30.043262        young
#
# [986 rows x 13 columns]

# %%
df
# Out:
#      Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0     45         0                      0               0                   0
# 1     60         1                      0               0                   0
# 2     36         1                      1               0                   0
# 3     52         1                      1               0                   1
# 4     38         0                      0               0                   1
# ..   ...       ...                    ...             ...                 ...
# 981   18         0                      0               0                   0
# 982   64         1                      1               0                   0
# 983   56         0                      1               0                   0
# 984   47         1                      1               0                   0
# 985   21         0                      0               0                   0
#
#      Height  Weight  KnownAllergies  HistoryOfCancerInFamily  \
# 0       155      57               0                        0
# 1       180      73               0                        0
# 2       158      59               0                        0
# 3       183      93               0                        0
# 4       166      88               0                        0
# ..      ...     ...             ...                      ...
# 981     169      67               0                        0
# 982     153      70               0                        0
# 983     155      71               0                        0
# 984     158      73               1                        0
# 985     158      75               1                        0
#
#      NumberOfMajorSurgeries  PremiumPrice        BMI
# 0                         0         25000  23.725286
# 1                         0         29000  22.530864
# 2                         1         23000  23.634033
# 3                         2         28000  27.770313
# 4                         1         23000  31.934969
# ..                      ...           ...        ...
# 981                       0         15000  23.458562
# 982                       3         28000  29.903029
# 983                       1         29000  29.552549
# 984                       1         39000  29.242109
# 985                       1         15000  30.043262
#
# [986 rows x 12 columns]

# %%
colors = ['#3C4F76' , '#D1BEB0' , '#AB9F9D']
labels = data['age_category'].value_counts().index
values = data['age_category'].value_counts()

# create pie chart

pie_chart = go.Figure(go.Pie(labels = labels, values = values, ))
pie_chart.update_traces(hoverinfo = 'label+value' , textinfo = 'percent', textfont_size = 20, 
                        marker = dict(colors = colors, line = dict( color = '#000000', width=2)))

# Bar Chart

bar_chart = go.Figure(go.Bar(x = labels, y = values, marker_color = colors))

# create subplots

fig = sp.make_subplots( rows = 1, cols = 2, column_width = [0.5,0.5], specs = [[{'type' : 'bar'}, {'type' : 'pie'}]],
                      subplot_titles = ("Bar Chart", "Pie Chart"))

# Add charts to subplots

fig.add_trace(bar_chart.data[0], row=1, col=1)
fig.add_trace(pie_chart.data[0], row=1, col=2)

# Update layout
fig.update_layout(
    showlegend=False,
    title=dict(
        text="Distribution of Age",
        font=dict(size=18)
    ),
    xaxis=dict(
        title=dict(
            text="Age-Groups",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    ),
    yaxis=dict(
        title=dict(
            text="Count",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    )
)


# Show subplots
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="2000f01d-cdda-410e-aec4-d13deb7a1684" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("2000f01d-cdda-410e-aec4-d13deb7a1684")) {                    Plotly.newPlot(                        "2000f01d-cdda-410e-aec4-d13deb7a1684",                        [{"marker":{"color":["#3C4F76","#D1BEB0","#AB9F9D"]},"x":["middle age","old","young"],"y":{"dtype":"i2","bdata":"rQEoAQUB"},"type":"bar","xaxis":"x","yaxis":"y"},{"hoverinfo":"label+value","labels":["middle age","old","young"],"marker":{"colors":["#3C4F76","#D1BEB0","#AB9F9D"],"line":{"color":"#000000","width":2}},"textfont":{"size":20},"textinfo":"percent","values":{"dtype":"i2","bdata":"rQEoAQUB"},"type":"pie","domain":{"x":[0.55,1.0],"y":[0.0,1.0]}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":" ...

# %% [markdown]
# ### Distribution of Height

# %%
plt.figure(figsize = (15, 6))

# Histplot
plt.subplot(1,2,1)
sns.histplot(data = data , x = 'Height', kde = True, color = '#797596')
plt.xlabel('Height')
plt.ylabel('Count')

# Boxplot
plt.subplot(1,2,2)
sns.boxplot(data = data, x = 'Height', color = '#797596')
plt.xlabel('Height')

plt.suptitle('Distribution of Height')
plt.show()

# %% [markdown]
# ### Distribution of Weight

# %%
plt.figure(figsize = (15, 6))

# Histplot
plt.subplot(1,2,1)
sns.histplot(data = data , x = 'Weight', kde = True, color = '#345995')
plt.xlabel('Weight')
plt.ylabel('Count')

# Boxplot
plt.subplot(1,2,2)
sns.boxplot(data = data, x = 'Weight', color = '#345995')
plt.xlabel('Weight')

plt.suptitle('Distribution of Weight')
plt.show()

# %% [markdown]
# ### Distribution of BMI

# %%
data['BMI']
# Out:
# 0      23.725286
# 1      22.530864
# 2      23.634033
# 3      27.770313
# 4      31.934969
#          ...
# 981    23.458562
# 982    29.903029
# 983    29.552549
# 984    29.242109
# 985    30.043262
# Name: BMI, Length: 986, dtype: float64

# %%
data['BMI_category'] = pd.cut(data['BMI'],bins = [0,18.5,24.9,29.9, float('inf')], labels = ['Underweight','Normal', 'Overweight', 'Obese'])
data['BMI_category']
# Out:
# 0          Normal
# 1          Normal
# 2          Normal
# 3      Overweight
# 4           Obese
#           ...
# 981        Normal
# 982         Obese
# 983    Overweight
# 984    Overweight
# 985         Obese
# Name: BMI_category, Length: 986, dtype: category
# Categories (4, object): ['Underweight' < 'Normal' < 'Overweight' < 'Obese']

# %%
# colors = ['#f6f5f5', '#fe346e', '#512b58', '#2c003e','#636efa']
#colors  = ['#E0B1CB','#BE95C4','#9F86C0','#5E548E','#231942']
colors = ['gold', 'mediumturquoise', 'darkorange', 'lightgreen']
labels = data['BMI_category'].value_counts().index
values = data['BMI_category'].value_counts()

# create pie chart

pie_chart = go.Figure(go.Pie(labels = labels, values = values,pull = [0.05,0.05,0.03,0.03] ))
pie_chart.update_traces(hoverinfo = 'label+value' , textinfo = 'percent', textfont_size = 20, 
                        marker = dict(colors = [colors[0], colors[1],colors[2],colors[3]], line = dict( color = '#000000', width=2)))

# Bar Chart

bar_chart = go.Figure(go.Bar(x = labels, y = values, marker_color = [colors[0], colors[1],colors[2],colors[3]]))

# create subplots

fig = sp.make_subplots( rows = 1, cols = 2, column_width = [0.5,0.5], specs = [[{'type' : 'bar'}, {'type' : 'pie'}]],
                      subplot_titles = ("Bar Chart", "Pie Chart"))

# Add charts to subplots

fig.add_trace(bar_chart.data[0], row=1, col=1)
fig.add_trace(pie_chart.data[0], row=1, col=2)

# Update layout
fig.update_layout(
    showlegend=False,
    title=dict(
        text="Distribution of BMI",
        font=dict(size=18)
    ),
    xaxis=dict(
        title=dict(
            text="BMI-Groups",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    ),
    yaxis=dict(
        title=dict(
            text="Count",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    )
)


# Show subplots
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="55c70bec-9401-4e71-a1e1-41a798f14432" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("55c70bec-9401-4e71-a1e1-41a798f14432")) {                    Plotly.newPlot(                        "55c70bec-9401-4e71-a1e1-41a798f14432",                        [{"marker":{"color":["gold","mediumturquoise","darkorange","lightgreen"]},"x":["Overweight","Normal","Obese","Underweight"],"y":{"dtype":"i2","bdata":"QQE7ATcBJwA="},"type":"bar","xaxis":"x","yaxis":"y"},{"hoverinfo":"label+value","labels":["Overweight","Normal","Obese","Underweight"],"marker":{"colors":["gold","mediumturquoise","darkorange","lightgreen"],"line":{"color":"#000000","width":2}},"pull":[0.05,0.05,0.03,0.03],"textfont":{"size":20},"textinfo":"percent","values":{"dtype":"i2","bdata":"QQE7ATcBJwA="},"type":"pie","domain":{"x":[0.55,1.0],"y":[0.0,1.0]}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[ ...

# %% [markdown]
# ### Distribution of 'BloodPressureProblems'

# %%
data['BloodPressureProblems'].value_counts()
# Out:
# BloodPressureProblems
# 0    524
# 1    462
# Name: count, dtype: int64

# %%
colors = ['#D0CDD7' , '#ACB0BD']
labels = ['No','Yes']
values = data['BloodPressureProblems'].value_counts()

# create pie chart

pie_chart = go.Figure(go.Pie(labels = labels, values = values, ))
pie_chart.update_traces(hoverinfo = 'label+value' , textinfo = 'percent', textfont_size = 20, 
                        marker = dict(colors = colors, line = dict( color = '#000000', width=2)))

# Bar Chart

bar_chart = go.Figure(go.Bar(x = labels, y = values, marker_color = colors))

# create subplots

fig = sp.make_subplots( rows = 1, cols = 2, column_width = [0.5,0.5], specs = [[{'type' : 'bar'}, {'type' : 'pie'}]],
                      subplot_titles = ("Bar Chart", "Pie Chart"))

# Add charts to subplots

fig.add_trace(bar_chart.data[0], row=1, col=1)
fig.add_trace(pie_chart.data[0], row=1, col=2)

# Update layout
fig.update_layout(
    showlegend=False,
    title=dict(
        text="Distribution of Blood Pressure Problems",
        font=dict(size=18)
    ),
    xaxis=dict(
        title=dict(
            text="Blood Pressure Problems",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    ),
    yaxis=dict(
        title=dict(
            text="Count",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    )
)


# Show subplots
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="02b50321-62db-4129-88d0-a634f3d03a2f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("02b50321-62db-4129-88d0-a634f3d03a2f")) {                    Plotly.newPlot(                        "02b50321-62db-4129-88d0-a634f3d03a2f",                        [{"marker":{"color":["#D0CDD7","#ACB0BD"]},"x":["No","Yes"],"y":{"dtype":"i2","bdata":"DALOAQ=="},"type":"bar","xaxis":"x","yaxis":"y"},{"hoverinfo":"label+value","labels":["No","Yes"],"marker":{"colors":["#D0CDD7","#ACB0BD"],"line":{"color":"#000000","width":2}},"textfont":{"size":20},"textinfo":"percent","values":{"dtype":"i2","bdata":"DALOAQ=="},"type":"pie","domain":{"x":[0.55,1.0],"y":[0.0,1.0]}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"t ...

# %% [markdown]
# ### Distribution of transplants

# %%
data['AnyTransplants'].value_counts()
# Out:
# AnyTransplants
# 0    931
# 1     55
# Name: count, dtype: int64

# %%
colors = ['#D3C0CD' , '#B19994']
labels = ['No','Yes']
values = data['AnyTransplants'].value_counts()

# create pie chart

pie_chart = go.Figure(go.Pie(labels = labels, values = values, ))
pie_chart.update_traces(hoverinfo = 'label+value' , textinfo = 'percent', textfont_size = 20, 
                        marker = dict(colors = colors, line = dict( color = '#000000', width=2)))

# Bar Chart

bar_chart = go.Figure(go.Bar(x = labels, y = values, marker_color = colors))

# create subplots

fig = sp.make_subplots( rows = 1, cols = 2, column_width = [0.5,0.5], specs = [[{'type' : 'bar'}, {'type' : 'pie'}]],
                      subplot_titles = ("Bar Chart", "Pie Chart"))

# Add charts to subplots

fig.add_trace(bar_chart.data[0], row=1, col=1)
fig.add_trace(pie_chart.data[0], row=1, col=2)

# Update layout
fig.update_layout(
    showlegend=False,
    title=dict(
        text="Distribution of Transplants",
        font=dict(size=18)
    ),
    xaxis=dict(
        title=dict(
            text="No. of Transplants",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    ),
    yaxis=dict(
        title=dict(
            text="Count",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    )
)

# Show subplots
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="2dc4dbc5-618c-4ed1-8a1e-21c4177dbefd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("2dc4dbc5-618c-4ed1-8a1e-21c4177dbefd")) {                    Plotly.newPlot(                        "2dc4dbc5-618c-4ed1-8a1e-21c4177dbefd",                        [{"marker":{"color":["#D3C0CD","#B19994"]},"x":["No","Yes"],"y":{"dtype":"i2","bdata":"owM3AA=="},"type":"bar","xaxis":"x","yaxis":"y"},{"hoverinfo":"label+value","labels":["No","Yes"],"marker":{"colors":["#D3C0CD","#B19994"],"line":{"color":"#000000","width":2}},"textfont":{"size":20},"textinfo":"percent","values":{"dtype":"i2","bdata":"owM3AA=="},"type":"pie","domain":{"x":[0.55,1.0],"y":[0.0,1.0]}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"t ...

# %% [markdown]
# ### Distribution of Chronic Diseases

# %%
data
# Out:
#      Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0     45         0                      0               0                   0
# 1     60         1                      0               0                   0
# 2     36         1                      1               0                   0
# 3     52         1                      1               0                   1
# 4     38         0                      0               0                   1
# ..   ...       ...                    ...             ...                 ...
# 981   18         0                      0               0                   0
# 982   64         1                      1               0                   0
# 983   56         0                      1               0                   0
# 984   47         1                      1               0                   0
# 985   21         0                      0               0                   0
#
#      Height  Weight  KnownAllergies  HistoryOfCancerInFamily  \
# 0       155      57               0                        0
# 1       180      73               0                        0
# 2       158      59               0                        0
# 3       183      93               0                        0
# 4       166      88               0                        0
# ..      ...     ...             ...                      ...
# 981     169      67               0                        0
# 982     153      70               0                        0
# 983     155      71               0                        0
# 984     158      73               1                        0
# 985     158      75               1                        0
#
#      NumberOfMajorSurgeries  PremiumPrice        BMI age_category BMI_category
# 0                         0         25000  23.725286   middle age       Normal
# 1                         0         29000  22.530864          old       Normal
# 2                         1         23000  23.634033   middle age       Normal
# 3                         2         28000  27.770313          old   Overweight
# 4                         1         23000  31.934969   middle age        Obese
# ..                      ...           ...        ...          ...          ...
# 981                       0         15000  23.458562        young       Normal
# 982                       3         28000  29.903029          old        Obese
# 983                       1         29000  29.552549          old   Overweight
# 984                       1         39000  29.242109   middle age   Overweight
# 985                       1         15000  30.043262        young        Obese
#
# [986 rows x 14 columns]

# %%
data['AnyChronicDiseases'].value_counts()
# Out:
# AnyChronicDiseases
# 0    808
# 1    178
# Name: count, dtype: int64

# %%
custom_palette(bo)

# %%
colors = [bo[3] , bo[7]]
labels = ['No','Yes']
values = data['AnyChronicDiseases'].value_counts()

# create pie chart

pie_chart = go.Figure(go.Pie(labels = labels, values = values, ))
pie_chart.update_traces(hoverinfo = 'label+value' , textinfo = 'percent', textfont_size = 20, 
                        marker = dict(colors = colors, line = dict( color = '#000000', width=2)))

# Bar Chart

bar_chart = go.Figure(go.Bar(x = labels, y = values, marker_color = colors))

# create subplots

fig = sp.make_subplots( rows = 1, cols = 2, column_width = [0.5,0.5], specs = [[{'type' : 'bar'}, {'type' : 'pie'}]],
                      subplot_titles = ("Bar Chart", "Pie Chart"))

# Add charts to subplots

fig.add_trace(bar_chart.data[0], row=1, col=1)
fig.add_trace(pie_chart.data[0], row=1, col=2)

# Update layout
fig.update_layout(
    showlegend=False,
    title=dict(
        text="Distribution of Chronic Diseases",
        font=dict(size=18)
    ),
    xaxis=dict(
        title=dict(
            text="Chronic Diseases",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    ),
    yaxis=dict(
        title=dict(
            text="Count",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    )
)

# Show subplots
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="fe00d061-f818-40a7-a79a-772f9509c5b8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("fe00d061-f818-40a7-a79a-772f9509c5b8")) {                    Plotly.newPlot(                        "fe00d061-f818-40a7-a79a-772f9509c5b8",                        [{"marker":{"color":["#48cae4","#ffbf69"]},"x":["No","Yes"],"y":{"dtype":"i2","bdata":"KAOyAA=="},"type":"bar","xaxis":"x","yaxis":"y"},{"hoverinfo":"label+value","labels":["No","Yes"],"marker":{"colors":["#48cae4","#ffbf69"],"line":{"color":"#000000","width":2}},"textfont":{"size":20},"textinfo":"percent","values":{"dtype":"i2","bdata":"KAOyAA=="},"type":"pie","domain":{"x":[0.55,1.0],"y":[0.0,1.0]}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"t ...

# %% [markdown]
# ### Distribution of Allergies

# %%
data['KnownAllergies'].value_counts()
# Out:
# KnownAllergies
# 0    774
# 1    212
# Name: count, dtype: int64

# %%
# colors = ['#A167A5','#D3BCCC']
colors = ['#716969', '#BCABAE']
labels = ['No','Yes']
values = data['KnownAllergies'].value_counts()

# create pie chart

pie_chart = go.Figure(go.Pie(labels = labels, values = values, ))
pie_chart.update_traces(hoverinfo = 'label+value' , textinfo = 'percent', textfont_size = 20, 
                        marker = dict(colors = colors, line = dict( color = '#000000', width=2)))

# Bar Chart

bar_chart = go.Figure(go.Bar(x = labels, y = values, marker_color = colors))

# create subplots

fig = sp.make_subplots( rows = 1, cols = 2, column_width = [0.5,0.5], specs = [[{'type' : 'bar'}, {'type' : 'pie'}]],
                      subplot_titles = ("Bar Chart", "Pie Chart"))

# Add charts to subplots

fig.add_trace(bar_chart.data[0], row=1, col=1)
fig.add_trace(pie_chart.data[0], row=1, col=2)

# Update layout
fig.update_layout(
    showlegend=False,
    title=dict(
        text="Distribution of Known Allergies",
        font=dict(size=18)
    ),
    xaxis=dict(
        title=dict(
            text="Allergies",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    ),
    yaxis=dict(
        title=dict(
            text="Count",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    )
)

# Show subplots
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="fe874486-a33f-484b-97bc-168156c10297" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("fe874486-a33f-484b-97bc-168156c10297")) {                    Plotly.newPlot(                        "fe874486-a33f-484b-97bc-168156c10297",                        [{"marker":{"color":["#716969","#BCABAE"]},"x":["No","Yes"],"y":{"dtype":"i2","bdata":"BgPUAA=="},"type":"bar","xaxis":"x","yaxis":"y"},{"hoverinfo":"label+value","labels":["No","Yes"],"marker":{"colors":["#716969","#BCABAE"],"line":{"color":"#000000","width":2}},"textfont":{"size":20},"textinfo":"percent","values":{"dtype":"i2","bdata":"BgPUAA=="},"type":"pie","domain":{"x":[0.55,1.0],"y":[0.0,1.0]}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"t ...

# %% [markdown]
# ### Distribution of Cancer History

# %%
data['HistoryOfCancerInFamily'].value_counts()
# Out:
# HistoryOfCancerInFamily
# 0    870
# 1    116
# Name: count, dtype: int64

# %%
colors=['#485696','#F9C784']
# labels = data['HistoryOfCancerInFamily'].value_counts().index
labels = ['No', 'Yes']
values = data['HistoryOfCancerInFamily'].value_counts()

# create pie chart

pie_chart = go.Figure(go.Pie(labels = labels, values = values, ))
pie_chart.update_traces(hoverinfo = 'label+value' , textinfo = 'percent', textfont_size = 20, 
                        marker = dict(colors = colors, line = dict( color = '#000000', width=2)))

# Bar Chart

bar_chart = go.Figure(go.Bar(x = labels, y = values, marker_color = colors))

# create subplots

fig = sp.make_subplots( rows = 1, cols = 2, column_width = [0.5,0.5], specs = [[{'type' : 'bar'}, {'type' : 'pie'}]],
                      subplot_titles = ("Bar Chart", "Pie Chart"))

# Add charts to subplots

fig.add_trace(bar_chart.data[0], row=1, col=1)
fig.add_trace(pie_chart.data[0], row=1, col=2)

# Update layout
fig.update_layout(
    showlegend=False,
    title=dict(
        text="Distribution of Cancer History",
        font=dict(size=18)
    ),
    xaxis=dict(
        title=dict(
            text="Cancer History",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    ),
    yaxis=dict(
        title=dict(
            text="Count",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    )
)

# Show subplots
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="5163bc4b-95da-4baa-846d-8c4f885adae4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("5163bc4b-95da-4baa-846d-8c4f885adae4")) {                    Plotly.newPlot(                        "5163bc4b-95da-4baa-846d-8c4f885adae4",                        [{"marker":{"color":["#485696","#F9C784"]},"x":["No","Yes"],"y":{"dtype":"i2","bdata":"ZgN0AA=="},"type":"bar","xaxis":"x","yaxis":"y"},{"hoverinfo":"label+value","labels":["No","Yes"],"marker":{"colors":["#485696","#F9C784"],"line":{"color":"#000000","width":2}},"textfont":{"size":20},"textinfo":"percent","values":{"dtype":"i2","bdata":"ZgN0AA=="},"type":"pie","domain":{"x":[0.55,1.0],"y":[0.0,1.0]}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"t ...

# %% [markdown]
# ### Distribution of No. Of Surgeries

# %%
data['NumberOfMajorSurgeries'].value_counts()
# Out:
# NumberOfMajorSurgeries
# 0    479
# 1    372
# 2    119
# 3     16
# Name: count, dtype: int64

# %%
colors = ['#006BA6','#C1B372','#FFBC42','#D81159']
labels = data['NumberOfMajorSurgeries'].value_counts().index

values = data['NumberOfMajorSurgeries'].value_counts()

# create pie chart

pie_chart = go.Figure(go.Pie(labels = labels, values = values, ))
pie_chart.update_traces(hoverinfo = 'label+value' , textinfo = 'percent', textfont_size = 20, 
                        marker = dict(colors = colors, line = dict( color = '#000000', width=2)))

# Bar Chart

bar_chart = go.Figure(go.Bar(x = labels, y = values, marker_color = colors))

# create subplots

fig = sp.make_subplots( rows = 1, cols = 2, column_width = [0.5,0.5], specs = [[{'type' : 'bar'}, {'type' : 'pie'}]],
                      subplot_titles = ("Bar Chart", "Pie Chart"))

# Add charts to subplots

fig.add_trace(bar_chart.data[0], row=1, col=1)
fig.add_trace(pie_chart.data[0], row=1, col=2)

# Update layout
fig.update_layout(
    showlegend=False,
    title=dict(
        text="Distribution of Major Surgeries",
        font=dict(size=18)
    ),
    xaxis=dict(
        title=dict(
            text="No. of Major Surgeries",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    ),
    yaxis=dict(
        title=dict(
            text="Count",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    )
)

# Show subplots
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="661924ba-32d0-4eff-be0f-8c36b721f973" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("661924ba-32d0-4eff-be0f-8c36b721f973")) {                    Plotly.newPlot(                        "661924ba-32d0-4eff-be0f-8c36b721f973",                        [{"marker":{"color":["#006BA6","#C1B372","#FFBC42","#D81159"]},"x":{"dtype":"i1","bdata":"AAECAw=="},"y":{"dtype":"i2","bdata":"3wF0AXcAEAA="},"type":"bar","xaxis":"x","yaxis":"y"},{"hoverinfo":"label+value","labels":{"dtype":"i1","bdata":"AAECAw=="},"marker":{"colors":["#006BA6","#C1B372","#FFBC42","#D81159"],"line":{"color":"#000000","width":2}},"textfont":{"size":20},"textinfo":"percent","values":{"dtype":"i2","bdata":"3wF0AXcAEAA="},"type":"pie","domain":{"x":[0.55,1.0],"y":[0.0,1.0]}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type ...

# %% [markdown]
# ### Distribution of Target Variable

# %%
plt.figure(figsize = (15, 6))

# Histplot
plt.subplot(1,2,1)
sns.histplot(data = data , x = 'PremiumPrice', kde = True, color = '#998DA0')
plt.xlabel('Premium Price')
plt.ylabel('Count')

# Boxplot
plt.subplot(1,2,2)
sns.boxplot(data = data, x = 'PremiumPrice', color = '#998DA0')
plt.xlabel('Premium Price')

plt.suptitle('Distribution of Premium Price')
plt.show()

# %%
#BCA0BC

# %% [markdown]
# ## 📉 Bivariate Analysis

# %% [markdown]
# ### Distribution of premium price in age-category

# %%
plt.figure(figsize = (12,6))
sns.boxplot(data = data , y = 'PremiumPrice', x = 'age_category')
plt.xlabel('Age Category')
plt.ylabel('Premium Price')
plt.title('Distrbution of Premium Price in Age category')
plt.show()

# %% [markdown]
# ### Distribtion of Premium Price in BMI Categroy

# %%
plt.figure(figsize = (12,6))
sns.boxplot(data = data , y = 'PremiumPrice', x = 'BMI_category', palette = pink)
plt.xlabel('BMI Category')
plt.ylabel('Premium Price')
plt.title('Distrbution of Premium Price in BMI category')
plt.show()

# %% [markdown]
# ### Distribution of Premium Price in 'BloodPressureProblems', 'AnyTransplants', 'AnyChronicDiseases', 'KnownAllergies',	'HistoryOfCancerInFamily' and	'NumberOfMajorSurgeries'

# %%
cols = ['BloodPressureProblems', 'AnyTransplants', 'AnyChronicDiseases', 'KnownAllergies', 'HistoryOfCancerInFamily','NumberOfMajorSurgeries']
plt.figure(figsize =(20,12))
for i in range(len(cols)):
    plt.subplot(3,3,i+1)
    sns.violinplot(data = data , x = cols[i], y = 'PremiumPrice', palette =  red[1:])
    plt.xlabel(cols[i], fontsize =14)
    plt.ylabel('Premium Price', fontsize = 14)
plt.tight_layout()
plt.show()

# %%
custom_palette(red)

# %% [markdown]
# ### Heatmap and Correlation

# %%
plt.figure(figsize=(15,12))
sns.heatmap(df.corr(),annot=True,cmap='rocket',fmt='.2f')
plt.show()

# %% [markdown]
# # ⚒ Data Preprocessing

# %% [markdown]
# ## 👯 Checking Duplicates

# %%
print(df[df.duplicated()])
# Out:
# Empty DataFrame
# Columns: [Age, Diabetes, BloodPressureProblems, AnyTransplants, AnyChronicDiseases, Height, Weight, KnownAllergies, HistoryOfCancerInFamily, NumberOfMajorSurgeries, PremiumPrice, BMI]
# Index: []

# %% [markdown]
# ## 👾 Checking Outliers

# %%
df.boxplot(rot=45, figsize=(30,15), fontsize = 25)
plt.show()

# %% [markdown]
# **Inference**
#
# The dataset contains very few outliers, and given its relatively small size, we have chosen not to remove any outliers to preserve the integrity of the data.

# %% [markdown]
# # 🛠️ Data Preparation

# %% [markdown]
# ## ✂️ Splitting data into train and test data

# %%
X = df.drop(columns=['PremiumPrice'])
y = df['PremiumPrice']

# %%
X
# Out:
#      Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0     45         0                      0               0                   0
# 1     60         1                      0               0                   0
# 2     36         1                      1               0                   0
# 3     52         1                      1               0                   1
# 4     38         0                      0               0                   1
# ..   ...       ...                    ...             ...                 ...
# 981   18         0                      0               0                   0
# 982   64         1                      1               0                   0
# 983   56         0                      1               0                   0
# 984   47         1                      1               0                   0
# 985   21         0                      0               0                   0
#
#      Height  Weight  KnownAllergies  HistoryOfCancerInFamily  \
# 0       155      57               0                        0
# 1       180      73               0                        0
# 2       158      59               0                        0
# 3       183      93               0                        0
# 4       166      88               0                        0
# ..      ...     ...             ...                      ...
# 981     169      67               0                        0
# 982     153      70               0                        0
# 983     155      71               0                        0
# 984     158      73               1                        0
# 985     158      75               1                        0
#
#      NumberOfMajorSurgeries        BMI
# 0                         0  23.725286
# 1                         0  22.530864
# 2                         1  23.634033
# 3                         2  27.770313
# 4                         1  31.934969
# ..                      ...        ...
# 981                       0  23.458562
# 982                       3  29.903029
# 983                       1  29.552549
# 984                       1  29.242109
# 985                       1  30.043262
#
# [986 rows x 11 columns]

# %%
y
# Out:
# 0      25000
# 1      29000
# 2      23000
# 3      28000
# 4      23000
#        ...
# 981    15000
# 982    28000
# 983    29000
# 984    39000
# 985    15000
# Name: PremiumPrice, Length: 986, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train,y_test = train_test_split(X,y, random_state = 42, test_size = 0.25)

# %%
X_train.shape
# Out:
# (739, 11)

# %%
X_test.shape
# Out:
# (247, 11)

# %% [markdown]
# ## 📏 Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = pd.DataFrame(scaler.fit_transform(X_train),columns = X_train.columns)
X_test_scaled = pd.DataFrame(scaler.fit_transform(X_test), columns = X_test.columns)

# %%
X_train_scaled
# Out:
#           Age  Diabetes  BloodPressureProblems  AnyTransplants  \
# 0    0.026630 -0.854798              -0.915592       -0.236039
# 1   -0.545865  1.169867              -0.915592       -0.236039
# 2   -0.903675  1.169867              -0.915592       -0.236039
# 3   -0.760551 -0.854798              -0.915592       -0.236039
# 4    0.312878  1.169867              -0.915592       -0.236039
# ..        ...       ...                    ...             ...
# 734  1.314745 -0.854798              -0.915592       -0.236039
# 735  0.312878 -0.854798               1.092190       -0.236039
# 736  1.386307  1.169867              -0.915592       -0.236039
# 737 -0.331180  1.169867              -0.915592       -0.236039
# 738  1.243183  1.169867               1.092190       -0.236039
#
#      AnyChronicDiseases    Height    Weight  KnownAllergies  \
# 0             -0.470625  1.677017  0.492592       -0.536150
# 1             -0.470625  0.974059 -0.688857       -0.536150
# 2             -0.470625 -1.235239 -0.202378       -0.536150
# 3             -0.470625  0.371523 -1.383828       -0.536150
# 4             -0.470625 -1.636929 -1.453325       -0.536150
# ..                  ...       ...       ...             ...
# 734           -0.470625 -1.335662 -1.314331       -0.536150
# 735            2.124835 -0.231013 -1.314331       -0.536150
# 736           -0.470625 -0.733126 -0.758354       -0.536150
# 737           -0.470625  0.572368 -0.966846        1.865151
# 738           -0.470625 -0.833548  1.048568       -0.536150
#
#      HistoryOfCancerInFamily  NumberOfMajorSurgeries       BMI
# 0                  -0.350857                0.447422 -0.486226
# 1                  -0.350857               -0.880469 -1.063956
# 2                  -0.350857               -0.880469  0.511056
# 3                  -0.350857               -0.880469 -1.383531
# 4                  -0.350857               -0.880469 -0.538135
# ..                       ...                     ...       ...
# 734                -0.350857               -0.880469 -0.554582
# 735                -0.350857                0.447422 -1.080669
# 736                -0.350857                3.103205 -0.330019
# 737                 2.850168                0.447422 -1.121397
# 738                 2.850168                0.447422  1.451486
#
# [739 rows x 11 columns]

# %%
X_test_scaled
# Out:
#           Age  Diabetes  BloodPressureProblems  AnyTransplants  \
# 0    0.568652 -0.838718              -1.012220       -0.263181
# 1   -0.222858 -0.838718              -1.012220       -0.263181
# 2    1.647983  1.192296               0.987927       -0.263181
# 3   -0.942412 -0.838718              -1.012220       -0.263181
# 4    0.424741  1.192296               0.987927       -0.263181
# ..        ...       ...                    ...             ...
# 242  0.928429 -0.838718               0.987927       -0.263181
# 243 -1.086323 -0.838718               0.987927       -0.263181
# 244 -0.222858  1.192296               0.987927       -0.263181
# 245 -1.302189  1.192296              -1.012220       -0.263181
# 246  0.928429 -0.838718              -1.012220       -0.263181
#
#      AnyChronicDiseases    Height    Weight  KnownAllergies  \
# 0             -0.465563 -0.270060  0.500480        2.062842
# 1              2.147938  1.638521 -0.293335        2.062842
# 2             -0.465563 -0.270060  0.716975       -0.484768
# 3             -0.465563  1.065947 -0.509830       -0.484768
# 4             -0.465563  0.302514  0.500480        2.062842
# ..                  ...       ...       ...             ...
# 242           -0.465563  0.397943  1.005635        2.062842
# 243           -0.465563 -0.842635  3.098421        2.062842
# 244           -0.465563  0.111656  0.067490       -0.484768
# 245           -0.465563  0.207085  0.716975       -0.484768
# 246           -0.465563 -1.033493 -0.293335       -0.484768
#
#      HistoryOfCancerInFamily  NumberOfMajorSurgeries       BMI
# 0                   2.461126                0.434670  0.549467
# 1                   2.461126                0.434670 -1.076196
# 2                  -0.406318               -0.924361  0.737546
# 3                   2.461126                0.434670 -0.987856
# 4                  -0.406318               -0.924361  0.186393
# ..                       ...                     ...       ...
# 242                -0.406318                0.434670  0.533402
# 243                 2.461126                0.434670  3.384906
# 244                -0.406318               -0.924361 -0.055431
# 245                -0.406318                0.434670  0.421424
# 246                -0.406318               -0.924361  0.338132
#
# [247 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      986 non-null    int64
#  1   Diabetes                 986 non-null    int64
#  2   BloodPressureProblems    986 non-null    int64
#  3   AnyTransplants           986 non-null    int64
#  4   AnyChronicDiseases       986 non-null    int64
#  5   Height                   986 non-null    int64
#  6   Weight                   986 non-null    int64
#  7   KnownAllergies           986 non-null    int64
#  8   HistoryOfCancerInFamily  986 non-null    int64
#  9   NumberOfMajorSurgeries   986 non-null    int64
#  10  PremiumPrice             986 non-null    int64
#  11  BMI                      986 non-null    float64
# dtypes: float64(1), int64(11)
# memory usage: 92.6 KB

# %% [markdown]
# # 🪖 Model Training and Evaluation

# %% [markdown]
# ## 💡 Training LightGBM model using optuna hyperparameter tuning and K-Fold cross validation

# %%
# !pip install mlflow
# Out:
# Requirement already satisfied: mlflow in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (3.9.0)
# Requirement already satisfied: mlflow-skinny==3.9.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (3.9.0)
# Requirement already satisfied: mlflow-tracing==3.9.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (3.9.0)
# Requirement already satisfied: Flask-CORS<7 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (6.0.2)
# Requirement already satisfied: Flask<4 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (3.1.2)
# Requirement already satisfied: alembic!=1.10.0,<2 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (1.18.3)
# Requirement already satisfied: cryptography<47,>=43.0.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (46.0.4)
# Requirement already satisfied: docker<8,>=4.0.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: graphene<4 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (3.4.3)
# Requirement already satisfied: gunicorn<24 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (23.0.0)
# Requirement already satisfied: huey<3,>=2.5.4 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (2.6.0)
# Requirement already satisfied: matplotlib<4 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (3.10.8)
# Requirement already satisfied: numpy<3 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (2.3.3)
# Requirement already satisfied: pandas<3 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (2.3.3)
# Requirement already satisfied: pyarrow<23,>=4.0.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (22.0.0)
# Requirement already satisfied: scikit-learn<2 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (1.8.0)
# Requirement already satisfied: scipy<2 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (1.17.0)
# Requirement already satisfied: skops<1 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (0.13.0)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (2.0.46)
# Requirement already satisfied: cachetools<7,>=5.0.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (6.2.6)
# Requirement already satisfied: click<9,>=7.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (8.3.1)
# Requirement already satisfied: cloudpickle<4 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (3.1.2)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (0.85.0)
# Requirement already satisfied: fastapi<1 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (0.128.4)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (3.1.46)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (8.7.1)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (1.39.1)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (1.39.1)
# Requirement already satisfied: packaging<26 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (25.0)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (6.33.5)
# Requirement already satisfied: pydantic<3,>=2.0.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (2.12.5)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (1.2.1)
# Requirement already satisfied: pyyaml<7,>=5.1 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (6.0.3)
# Requirement already satisfied: requests<3,>=2.17.3 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (2.32.5)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (0.5.5)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (4.15.0)
# Requirement already satisfied: uvicorn<1 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (0.40.0)
# Requirement already satisfied: Mako in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.10)
# Requirement already satisfied: cffi>=2.0.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from cryptography<47,>=43.0.0->mlflow) (2.0.0)
# Requirement already satisfied: google-auth~=2.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.9.0->mlflow) (2.48.0)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from docker<8,>=4.0.0->mlflow) (2.6.3)
# Requirement already satisfied: starlette<1.0.0,>=0.40.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from fastapi<1->mlflow-skinny==3.9.0->mlflow) (0.52.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from fastapi<1->mlflow-skinny==3.9.0->mlflow) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from fastapi<1->mlflow-skinny==3.9.0->mlflow) (0.0.4)
# Requirement already satisfied: blinker>=1.9.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from Flask<4->mlflow) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from Flask<4->mlflow) (3.1.5)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.9.0->mlflow) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.9.0->mlflow) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.9.0->mlflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.9.0->mlflow) (4.9.1)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from graphene<4->mlflow) (3.2.7)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: zipp>=3.20 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.9.0->mlflow) (3.23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from matplotlib<4->mlflow) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from matplotlib<4->mlflow) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from matplotlib<4->mlflow) (1.4.9)
# Requirement already satisfied: pillow>=8 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from matplotlib<4->mlflow) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from matplotlib<4->mlflow) (3.3.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.9.0->mlflow) (0.60b1)
# Requirement already satisfied: pytz>=2020.1 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from pandas<3->mlflow) (2025.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.9.0->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.9.0->mlflow) (2.41.5)
# Requirement already satisfied: six>=1.5 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.9.0->mlflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.9.0->mlflow) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.9.0->mlflow) (2026.1.4)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.9.0->mlflow) (0.6.2)
# Requirement already satisfied: joblib>=1.3.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from scikit-learn<2->mlflow) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from scikit-learn<2->mlflow) (3.6.0)
# Requirement already satisfied: prettytable>=3.9 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from skops<1->mlflow) (3.17.0)
# Requirement already satisfied: anyio<5,>=3.6.2 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from starlette<1.0.0,>=0.40.0->fastapi<1->mlflow-skinny==3.9.0->mlflow) (4.12.1)
# Requirement already satisfied: h11>=0.8 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from uvicorn<1->mlflow-skinny==3.9.0->mlflow) (0.16.0)
# Requirement already satisfied: pycparser in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from cffi>=2.0.0->cryptography<47,>=43.0.0->mlflow) (3.0)
# Requirement already satisfied: wcwidth in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from prettytable>=3.9->skops<1->mlflow) (0.6.0)

# %%
import optuna
import mlflow # For experimental tracking
import lightgbm as lgb
from lightgbm import early_stopping
from sklearn.metrics import  root_mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import KFold

# %%
1e-1
# Out:
# 0.1

# %%
from pathlib import Path
import os

# Project root = parent of notebooks/
PROJECT_ROOT = Path.cwd().parent

# (optional) verify
print("Project root:", PROJECT_ROOT)
# Out:
# Project root: /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction

# %%
import os
MLRUNS_DIR = PROJECT_ROOT / "mlruns"
MLRUNS_DIR.mkdir(exist_ok=True)
mlflow.set_tracking_uri(f"file://{MLRUNS_DIR.resolve()}")
mlflow.set_experiment("Insurance Premium Prediction Model Experimental Tracking")
# Out:
# 2026/02/07 11:15:12 INFO mlflow.tracking.fluent: Experiment with name 'Insurance Premium Prediction Model Experimental Tracking' does not exist. Creating a new experiment.
# <Experiment: artifact_location=('file:///Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine '
#  'Learning/Insurance Premium '
#  'Prediction/Insurance-Premium-Prediction/mlruns/619644230268117697'), creation_time=1770488112521, experiment_id='619644230268117697', last_update_time=1770488112521, lifecycle_stage='active', name='Insurance Premium Prediction Model Experimental Tracking', tags={}>

# %%
def objective(trial):
    with mlflow.start_run(nested = True, run_name = f"trial {trial.number}") as child_run:
        params = {
            'objective':'regression',
            'metric':'rmse',
            'n_estimators': trial.suggest_int('n_estimators',500,2000),
            'boosting_type': trial.suggest_categorical('boosting',['gbdt','dart']),
            'max_depth':trial.suggest_int('max_depth',3,10),
            'num_leaves': trial.suggest_int('num_leaves',4,128),
            'learning_rate':trial.suggest_loguniform('learning_rate',1e-4,1e-1),
            'feature_fraction':trial.suggest_uniform('feature_fraction',0.6,1.0),
            'bagging_fraction':trial.suggest_uniform('bagging_fraction',0.6,0.9),
            'bagging_freq':trial.suggest_int('bagging_freq',1,20),
            'min_data_in_leaf':trial.suggest_int('min_data_in_leaf', 5,30),
            'reg_alpha':trial.suggest_float('reg_alpha',1e-8,10.0,log = True),
            'reg_lambda':trial.suggest_float('reg_lambda',1e-8,10.0,log = True),
            #'device_type':'gpu',
            'random_state':42,
            'verbose':-1
            }
        # log model params
        mlflow.log_params(params)
        model = lgb.LGBMRegressor(**params)
        scores = []
        kf = KFold(n_splits = 5, shuffle = True, random_state = 42)
        for train_idx,val_idx in kf.split(X_train):
            X_tr, X_val = X_train.iloc[train_idx], X_train.iloc[val_idx]
            y_tr, y_val = y_train.iloc[train_idx], y_train.iloc[val_idx]
            model.fit(X_tr,y_tr, eval_set = [(X_val, y_val)], callbacks=[early_stopping(stopping_rounds=100, verbose=False)])
            y_pred = model.predict(X_val)
            rmse = root_mean_squared_error(y_val,y_pred)
            scores.append(rmse)
        # log tuning metric RMSE
        mlflow.log_metrics({"RMSE":np.mean(scores)})
        # Log the model file
        mlflow.sklearn.log_model(model, name="model")
        # Make it easy to retrieve the best-performing child run later
        trial.set_user_attr("run_id", child_run.info.run_id)
    
        return float(np.mean(scores))

# %%
with mlflow.start_run(run_name = 'study') as run:
    
    study = optuna.create_study(direction='minimize')
    study.optimize(objective, n_trials = 50, show_progress_bar = True)
    # log model's best params, lowest rmse score and its id
    mlflow.log_params(study.best_params)
    mlflow.log_metrics({"best_error": study.best_value})
    if best_run_id := study.best_trial.user_attrs.get("run_id"):
        mlflow.log_param("best_child_run_id", best_run_id)
# Out:
# [I 2026-02-07 11:15:12,538] A new study created in memory with name: no-name-1fceb04c-75c8-41df-884c-84394be86f31
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2026-02-07 11:15:16,393] Trial 0 finished with value: 3580.18244287322 and parameters: {'n_estimators': 1208, 'boosting': 'gbdt', 'max_depth': 3, 'num_leaves': 68, 'learning_rate': 0.001746535215793872, 'feature_fraction': 0.688514073925025, 'bagging_fraction': 0.8027636141512527, 'bagging_freq': 8, 'min_data_in_leaf': 5, 'reg_alpha': 1.834812135793495, 'reg_lambda': 4.244754538317209}. Best is trial 0 with value: 3580.18244287322.
# [I 2026-02-07 11:15:18,742] Trial 1 finished with value: 2996.614342735572 and parameters: {'n_estimators': 1063, 'boosting': 'gbdt', 'max_depth': 7, 'num_leaves': 88, 'learning_rate': 0.012161666437769348, 'feature_fraction': 0.8144455276982072, 'bagging_fraction': 0.8975194594765794, 'bagging_freq': 8, 'min_data_in_leaf': 13, 'reg_alpha': 2.8353911016799644, 'reg_lambda': 1.206349747602669}. Best is trial 1 with value: 2996.614342735572.
# [I 2026-02-07 11:15:32,786] Trial 2 finished with value: 3343.920410991576 and parameters: {'n_estimators': 1508, 'boosting': 'dart', 'max_depth': 6, 'num_leaves': 56, 'learning_rate': 0.01995093765891641, 'feature_fraction': 0.8767966166168134, 'bagging_fraction': 0.6077000009320771, 'bagging_freq': 3, 'min_data_in_leaf': 5, 'reg_alpha': 5.779158665111174e-06, 'reg_lambda': 0.07152366778587745}. Best is trial 1 with value: 2996.614342735572.
# [I 2026-02-07 11:15:35,176] Trial 3 finished with value: 3274.1595535294955 and parameters: {'n_estimators': 1087, 'boosting': 'gbdt', 'max_depth': 3, 'num_leaves': 17, 'learning_rate': 0.003252901731139577, 'feature_fraction': 0.7511938411615011, 'bagging_fraction': 0.7619335510862814, 'bagging_freq': 10, 'min_data_in_leaf': 13, 'reg_alpha': 6.130588434749323e-06, 'reg_lambda': 0.007606065960162461}. Best is trial 1 with value: 2996.614342735572.
# [I 2026-02-07 11:15:51,637] Trial 4 finished with value: 4956.773650100454 and parameters: {'n_estimators': 1446, 'boosting': 'dart', 'max_depth': 9, 'num_leaves': 63, 'learning_rate': 0.007383782496353603, 'feature_fraction': 0.6022868394482758, 'bagging_fraction': 0.8991032898977991, 'bagging_freq': 13, 'min_data_in_leaf': 12, 'reg_alpha': 4.636105293449636e-05, 'reg_lambda': 3.2762930712204584e-06}. Best is trial 1 with value: 2996.614342735572.
# [I 2026-02-07 11:16:02,134] Trial 5 finished with value: 20589.043914238846 and parameters: {'n_estimators': 1020, 'boosting': 'dart', 'max_depth': 9, 'num_leaves': 100, 'learning_rate': 0.0002580801529957161, 'feature_fraction': 0.7839115587660294, 'bagging_fraction': 0.8284028234293948, 'bagging_freq': 6, 'min_data_in_leaf': 16, 'reg_alpha': 0.0016199231784114977, 'reg_lambda': 4.522943443374387e-05}. Best is trial 1 with value: 2996.614342735572.
# [I 2026-02-07 11:16:05,336] Trial 6 finished with value: 5145.260462871959 and parameters: {'n_estimators': 944, 'boosting': 'gbdt', 'max_depth': 8, 'num_leaves': 80, 'learning_rate': 0.0003757151926358586, 'feature_fraction': 0.6877686089119643, 'bagging_fraction': 0.8102522131038413, 'bagging_freq': 13, 'min_data_in_leaf': 15, 'reg_alpha': 4.016113964771337e-08, 'reg_lambda': 5.278535873290874e-05}. Best is trial 1 with value: 2996.614342735572.
# [I 2026-02-07 11:16:11,593] Trial 7 finished with value: 12245.05842155274 and parameters: {'n_estimators': 938, 'boosting': 'dart', 'max_depth': 4, 'num_leaves': 39, 'learning_rate': 0.0027396208230030124, 'feature_fraction': 0.9193126197773653, 'bagging_fraction': 0.6709876437771262, 'bagging_freq': 18, 'min_data_in_leaf': 30, 'reg_alpha': 1.4291488429136741e-08, 'reg_lambda': 1.3554109427413936e-07}. Best is trial 1 with value: 2996.614342735572.
# [I 2026-02-07 11:16:14,046] Trial 8 finished with value: 4739.294139253508 and parameters: {'n_estimators': 999, 'boosting': 'gbdt', 'max_depth': 8, 'num_leaves': 77, 'learning_rate': 0.0005776613407444879, 'feature_fraction': 0.8719211485096604, 'bagging_fraction': 0.7353781253294862, 'bagging_freq': 16, 'min_data_in_leaf': 27, 'reg_alpha': 2.0427216794314923e-07, 'reg_lambda': 1.3085629326036772}. Best is trial 1 with value: 2996.614342735572.
# [I 2026-02-07 11:16:23,087] Trial 9 finished with value: 26386.585873411736 and parameters: {'n_estimators': 1979, 'boosting': 'dart', 'max_depth': 9, 'num_leaves': 111, 'learning_rate': 0.000200206243705424, 'feature_fraction': 0.8491507612899694, 'bagging_fraction': 0.8758033200810234, 'bagging_freq': 8, 'min_data_in_leaf': 9, 'reg_alpha': 0.001594600658128573, 'reg_lambda': 3.0009944491532594}. Best is trial 1 with value: 2996.614342735572.
# [I 2026-02-07 11:16:25,061] Trial 10 finished with value: 3272.0049254507867 and parameters: {'n_estimators': 542, 'boosting': 'gbdt', 'max_depth': 6, 'num_leaves': 121, 'learning_rate': 0.07246829163870559, 'feature_fraction': 0.9828653291472765, 'bagging_fraction': 0.6992405769802214, 'bagging_freq': 2, 'min_data_in_leaf': 22, 'reg_alpha': 6.592979274788206, 'reg_lambda': 0.004667241763058506}. Best is trial 1 with value: 2996.614342735572.
# [I 2026-02-07 11:16:27,098] Trial 11 finished with value: 3260.812162042808 and parameters: {'n_estimators': 521, 'boosting': 'gbdt', 'max_depth': 6, 'num_leaves': 127, 'learning_rate': 0.09555439991736751, 'feature_fraction': 0.9882884143054391, 'bagging_fraction': 0.6934409454851735, 'bagging_freq': 1, 'min_data_in_leaf': 22, 'reg_alpha': 9.001105960876371, 'reg_lambda': 0.0058347037279213925}. Best is trial 1 with value: 2996.614342735572.
# [I 2026-02-07 11:16:28,862] Trial 12 finished with value: 3257.7905269440366 and parameters: {'n_estimators': 545, 'boosting': 'gbdt', 'max_depth': 5, 'num_leaves': 128, 'learning_rate': 0.08445984266349618, 'feature_fraction': 0.9859649123084585, 'bagging_fraction': 0.6403935820404859, 'bagging_freq': 1, 'min_data_in_leaf': 20, 'reg_alpha': 0.1384901785301787, 'reg_lambda': 0.06922866113762559}. Best is trial 1 with value: 2996.614342735572.
# [I 2026-02-07 11:16:31,183] Trial 13 finished with value: 3288.9412601442664 and parameters: {'n_estimators': 700, 'boosting': 'gbdt', 'max_depth': 5, 'num_leaves': 95, 'learning_rate': 0.024175901774084546, 'feature_fraction': 0.9325527970861619, 'bagging_fraction': 0.6014759057189525, 'bagging_freq': 5, 'min_data_in_leaf': 20, 'reg_alpha': 0.09752701960317717, 'reg_lambda': 0.15731962625520854}. Best is trial 1 with value: 2996.614342735572.
# [I 2026-02-07 11:16:33,857] Trial 14 finished with value: 3216.845179910445 and parameters: {'n_estimators': 767, 'boosting': 'gbdt', 'max_depth': 7, 'num_leaves': 97, 'learning_rate': 0.01615624254841718, 'feature_fraction': 0.8079854882665035, 'bagging_fraction': 0.6476497762681618, 'bagging_freq': 5, 'min_data_in_leaf': 18, 'reg_alpha': 0.0815132093077951, 'reg_lambda': 0.1240266650739296}. Best is trial 1 with value: 2996.614342735572.
# [I 2026-02-07 11:16:37,415] Trial 15 finished with value: 2988.028733422635 and parameters: {'n_estimators': 775, 'boosting': 'gbdt', 'max_depth': 7, 'num_leaves': 94, 'learning_rate': 0.013900800314120809, 'feature_fraction': 0.8140272617935722, 'bagging_fraction': 0.7365175211758052, 'bagging_freq': 5, 'min_data_in_leaf': 10, 'reg_alpha': 0.10037619747068098, 'reg_lambda': 0.0010805394556262255}. Best is trial 15 with value: 2988.028733422635.
# [I 2026-02-07 11:16:44,205] Trial 16 finished with value: 3070.0840121088336 and parameters: {'n_estimators': 1443, 'boosting': 'gbdt', 'max_depth': 10, 'num_leaves': 46, 'learning_rate': 0.007751256429161813, 'feature_fraction': 0.7280773930726425, 'bagging_fraction': 0.7557794433708898, 'bagging_freq': 10, 'min_data_in_leaf': 9, 'reg_alpha': 0.018909266006016726, 'reg_lambda': 3.4430680669598963e-08}. Best is trial 15 with value: 2988.028733422635.
# [I 2026-02-07 11:16:49,970] Trial 17 finished with value: 4206.76997077017 and parameters: {'n_estimators': 771, 'boosting': 'gbdt', 'max_depth': 7, 'num_leaves': 85, 'learning_rate': 0.0009499575034171015, 'feature_fraction': 0.8167879946216745, 'bagging_fraction': 0.8538915873512785, 'bagging_freq': 8, 'min_data_in_leaf': 9, 'reg_alpha': 0.815526196345888, 'reg_lambda': 0.0004528643276952629}. Best is trial 15 with value: 2988.028733422635.
# [I 2026-02-07 11:16:52,704] Trial 18 finished with value: 3055.0195716471517 and parameters: {'n_estimators': 1682, 'boosting': 'gbdt', 'max_depth': 8, 'num_leaves': 109, 'learning_rate': 0.008017600797435553, 'feature_fraction': 0.7656713082288054, 'bagging_fraction': 0.788140116452624, 'bagging_freq': 13, 'min_data_in_leaf': 12, 'reg_alpha': 0.004974040362943026, 'reg_lambda': 6.1700250397117e-07}. Best is trial 15 with value: 2988.028733422635.
# [I 2026-02-07 11:16:54,526] Trial 19 finished with value: 3013.280587484821 and parameters: {'n_estimators': 1192, 'boosting': 'gbdt', 'max_depth': 7, 'num_leaves': 88, 'learning_rate': 0.03713813429710131, 'feature_fraction': 0.8357589221457741, 'bagging_fraction': 0.7246593910909155, 'bagging_freq': 4, 'min_data_in_leaf': 9, 'reg_alpha': 0.6945641841000048, 'reg_lambda': 0.000454318379406795}. Best is trial 15 with value: 2988.028733422635.
# [I 2026-02-07 11:16:56,631] Trial 20 finished with value: 3148.7375750454876 and parameters: {'n_estimators': 825, 'boosting': 'gbdt', 'max_depth': 5, 'num_leaves': 8, 'learning_rate': 0.004994215642697476, 'feature_fraction': 0.7175690602597061, 'bagging_fraction': 0.7733200850329569, 'bagging_freq': 7, 'min_data_in_leaf': 14, 'reg_alpha': 0.029351272600117276, 'reg_lambda': 7.870150800462406e-06}. Best is trial 15 with value: 2988.028733422635.
# [I 2026-02-07 11:16:58,603] Trial 21 finished with value: 2971.6993055600096 and parameters: {'n_estimators': 1243, 'boosting': 'gbdt', 'max_depth': 7, 'num_leaves': 81, 'learning_rate': 0.0370928283715613, 'feature_fraction': 0.8330984825299509, 'bagging_fraction': 0.7145169872718159, 'bagging_freq': 3, 'min_data_in_leaf': 8, 'reg_alpha': 0.6049777491532101, 'reg_lambda': 0.0003961979738111936}. Best is trial 21 with value: 2971.6993055600096.
# [I 2026-02-07 11:17:00,526] Trial 22 finished with value: 2976.3424662550924 and parameters: {'n_estimators': 1296, 'boosting': 'gbdt', 'max_depth': 7, 'num_leaves': 73, 'learning_rate': 0.03564386752386003, 'feature_fraction': 0.8986696260273561, 'bagging_fraction': 0.7108393286335627, 'bagging_freq': 3, 'min_data_in_leaf': 11, 'reg_alpha': 0.43242605067524253, 'reg_lambda': 8.537251205614368e-05}. Best is trial 21 with value: 2971.6993055600096.
# [I 2026-02-07 11:17:02,391] Trial 23 finished with value: 2987.5892643354114 and parameters: {'n_estimators': 1307, 'boosting': 'gbdt', 'max_depth': 8, 'num_leaves': 71, 'learning_rate': 0.04322144814367644, 'feature_fraction': 0.9043011318566211, 'bagging_fraction': 0.7124184462250956, 'bagging_freq': 4, 'min_data_in_leaf': 7, 'reg_alpha': 0.39057767815014505, 'reg_lambda': 8.600568547448318e-05}. Best is trial 21 with value: 2971.6993055600096.
# [I 2026-02-07 11:17:04,483] Trial 24 finished with value: 2954.0811569689827 and parameters: {'n_estimators': 1325, 'boosting': 'gbdt', 'max_depth': 8, 'num_leaves': 71, 'learning_rate': 0.03545835374652434, 'feature_fraction': 0.9203757695217134, 'bagging_fraction': 0.7064787308012036, 'bagging_freq': 3, 'min_data_in_leaf': 7, 'reg_alpha': 0.4728153263627471, 'reg_lambda': 6.424036868376331e-05}. Best is trial 24 with value: 2954.0811569689827.
# [I 2026-02-07 11:17:15,084] Trial 25 finished with value: 5477.742817907385 and parameters: {'n_estimators': 1670, 'boosting': 'gbdt', 'max_depth': 10, 'num_leaves': 53, 'learning_rate': 0.00010153705735610938, 'feature_fraction': 0.9505108614947315, 'bagging_fraction': 0.6766131544560001, 'bagging_freq': 2, 'min_data_in_leaf': 7, 'reg_alpha': 0.00034479172468274654, 'reg_lambda': 1.0482433181705616e-05}. Best is trial 24 with value: 2954.0811569689827.
# [I 2026-02-07 11:17:32,266] Trial 26 finished with value: 3239.9171098559905 and parameters: {'n_estimators': 1323, 'boosting': 'dart', 'max_depth': 8, 'num_leaves': 34, 'learning_rate': 0.044259060815410284, 'feature_fraction': 0.8816279603581129, 'bagging_fraction': 0.6629282840465637, 'bagging_freq': 3, 'min_data_in_leaf': 7, 'reg_alpha': 0.008344671347784013, 'reg_lambda': 2.244729924272181e-06}. Best is trial 24 with value: 2954.0811569689827.
# [I 2026-02-07 11:17:35,245] Trial 27 finished with value: 3043.7526589964436 and parameters: {'n_estimators': 1534, 'boosting': 'gbdt', 'max_depth': 6, 'num_leaves': 61, 'learning_rate': 0.02848298980483736, 'feature_fraction': 0.9516685344688643, 'bagging_fraction': 0.6878473796307581, 'bagging_freq': 20, 'min_data_in_leaf': 11, 'reg_alpha': 0.3076121065920991, 'reg_lambda': 0.00013070042726902992}. Best is trial 24 with value: 2954.0811569689827.
# [I 2026-02-07 11:17:38,064] Trial 28 finished with value: 2972.3763234843304 and parameters: {'n_estimators': 1647, 'boosting': 'gbdt', 'max_depth': 9, 'num_leaves': 73, 'learning_rate': 0.05677019978912587, 'feature_fraction': 0.900630889704763, 'bagging_fraction': 0.708304255440022, 'bagging_freq': 3, 'min_data_in_leaf': 5, 'reg_alpha': 2.1252265566639004, 'reg_lambda': 6.24722093322305e-07}. Best is trial 24 with value: 2954.0811569689827.
# [I 2026-02-07 11:17:40,275] Trial 29 finished with value: 3060.386865397312 and parameters: {'n_estimators': 1771, 'boosting': 'gbdt', 'max_depth': 9, 'num_leaves': 66, 'learning_rate': 0.06054752777432256, 'feature_fraction': 0.8536814271984929, 'bagging_fraction': 0.6315700264124177, 'bagging_freq': 6, 'min_data_in_leaf': 5, 'reg_alpha': 1.726262051086853, 'reg_lambda': 2.3422075165621113e-07}. Best is trial 24 with value: 2954.0811569689827.
# [I 2026-02-07 11:17:48,327] Trial 30 finished with value: 3003.6291101124275 and parameters: {'n_estimators': 1898, 'boosting': 'gbdt', 'max_depth': 10, 'num_leaves': 50, 'learning_rate': 0.001674677023925931, 'feature_fraction': 0.92871087854309, 'bagging_fraction': 0.7306089859733804, 'bagging_freq': 1, 'min_data_in_leaf': 5, 'reg_alpha': 2.716793151530561, 'reg_lambda': 2.342261715500382e-08}. Best is trial 24 with value: 2954.0811569689827.
# [I 2026-02-07 11:17:50,445] Trial 31 finished with value: 2948.7973536078343 and parameters: {'n_estimators': 1175, 'boosting': 'gbdt', 'max_depth': 8, 'num_leaves': 72, 'learning_rate': 0.05433574316612065, 'feature_fraction': 0.8985894333181738, 'bagging_fraction': 0.709407835891495, 'bagging_freq': 3, 'min_data_in_leaf': 7, 'reg_alpha': 1.0340130525365832, 'reg_lambda': 1.7854073331878468e-05}. Best is trial 31 with value: 2948.7973536078343.
# [I 2026-02-07 11:17:53,437] Trial 32 finished with value: 2947.259923079041 and parameters: {'n_estimators': 1169, 'boosting': 'gbdt', 'max_depth': 9, 'num_leaves': 83, 'learning_rate': 0.05412335568463934, 'feature_fraction': 0.9576997728451829, 'bagging_fraction': 0.7123595011360163, 'bagging_freq': 4, 'min_data_in_leaf': 7, 'reg_alpha': 2.7814735370624875, 'reg_lambda': 2.2506323003882272e-05}. Best is trial 32 with value: 2947.259923079041.
# [I 2026-02-07 11:17:55,991] Trial 33 finished with value: 2910.993768755679 and parameters: {'n_estimators': 1167, 'boosting': 'gbdt', 'max_depth': 8, 'num_leaves': 82, 'learning_rate': 0.02301646339802857, 'feature_fraction': 0.9576264130599703, 'bagging_fraction': 0.742267771513603, 'bagging_freq': 4, 'min_data_in_leaf': 7, 'reg_alpha': 9.625193154936303, 'reg_lambda': 1.6344037702121245e-05}. Best is trial 33 with value: 2910.993768755679.
# [I 2026-02-07 11:17:58,597] Trial 34 finished with value: 2928.8089033570236 and parameters: {'n_estimators': 1129, 'boosting': 'gbdt', 'max_depth': 8, 'num_leaves': 105, 'learning_rate': 0.02278966812588537, 'feature_fraction': 0.9599922000210801, 'bagging_fraction': 0.744917602255499, 'bagging_freq': 7, 'min_data_in_leaf': 7, 'reg_alpha': 5.457653116581702, 'reg_lambda': 1.4796113744520549e-05}. Best is trial 33 with value: 2910.993768755679.
# [I 2026-02-07 11:18:01,487] Trial 35 finished with value: 2942.2034820249505 and parameters: {'n_estimators': 1163, 'boosting': 'gbdt', 'max_depth': 9, 'num_leaves': 109, 'learning_rate': 0.020179253813582924, 'feature_fraction': 0.9648487026458754, 'bagging_fraction': 0.775089802522402, 'bagging_freq': 7, 'min_data_in_leaf': 6, 'reg_alpha': 8.971256167861448, 'reg_lambda': 1.2202972339994017e-05}. Best is trial 33 with value: 2910.993768755679.
# [I 2026-02-07 11:18:18,076] Trial 36 finished with value: 4149.484480137115 and parameters: {'n_estimators': 1096, 'boosting': 'dart', 'max_depth': 9, 'num_leaves': 107, 'learning_rate': 0.01074034102729994, 'feature_fraction': 0.9591350436177066, 'bagging_fraction': 0.7731252874222745, 'bagging_freq': 9, 'min_data_in_leaf': 6, 'reg_alpha': 9.356915478018692, 'reg_lambda': 2.110010767957044e-06}. Best is trial 33 with value: 2910.993768755679.
# [I 2026-02-07 11:18:22,647] Trial 37 finished with value: 2923.8724001686323 and parameters: {'n_estimators': 1124, 'boosting': 'gbdt', 'max_depth': 10, 'num_leaves': 102, 'learning_rate': 0.019683674143163344, 'feature_fraction': 0.9624880572180079, 'bagging_fraction': 0.8051446671642531, 'bagging_freq': 7, 'min_data_in_leaf': 11, 'reg_alpha': 3.2888977941242428, 'reg_lambda': 1.2175080396336924e-05}. Best is trial 33 with value: 2910.993768755679.
# [I 2026-02-07 11:18:38,194] Trial 38 finished with value: 3291.7874090269906 and parameters: {'n_estimators': 1095, 'boosting': 'dart', 'max_depth': 10, 'num_leaves': 114, 'learning_rate': 0.019296601515802328, 'feature_fraction': 0.998575138688957, 'bagging_fraction': 0.8178746313995177, 'bagging_freq': 7, 'min_data_in_leaf': 13, 'reg_alpha': 4.004422326490801e-06, 'reg_lambda': 4.52945354572964e-06}. Best is trial 33 with value: 2910.993768755679.
# [I 2026-02-07 11:18:41,945] Trial 39 finished with value: 3148.4440381165286 and parameters: {'n_estimators': 894, 'boosting': 'gbdt', 'max_depth': 10, 'num_leaves': 102, 'learning_rate': 0.004741135913673619, 'feature_fraction': 0.6183898111011871, 'bagging_fraction': 0.794609188977587, 'bagging_freq': 12, 'min_data_in_leaf': 11, 'reg_alpha': 9.948211680513488, 'reg_lambda': 4.2723091545475757e-07}. Best is trial 33 with value: 2910.993768755679.
# [I 2026-02-07 11:18:54,118] Trial 40 finished with value: 3652.59302981651 and parameters: {'n_estimators': 1401, 'boosting': 'dart', 'max_depth': 9, 'num_leaves': 103, 'learning_rate': 0.012913935940900664, 'feature_fraction': 0.9711564196903595, 'bagging_fraction': 0.7743260735752349, 'bagging_freq': 11, 'min_data_in_leaf': 16, 'reg_alpha': 2.947884195865075e-05, 'reg_lambda': 1.4217839093879306e-06}. Best is trial 33 with value: 2910.993768755679.
# [I 2026-02-07 11:18:56,277] Trial 41 finished with value: 2943.5332721418986 and parameters: {'n_estimators': 1147, 'boosting': 'gbdt', 'max_depth': 9, 'num_leaves': 94, 'learning_rate': 0.02500345957302045, 'feature_fraction': 0.9641335094512555, 'bagging_fraction': 0.7474756164273528, 'bagging_freq': 7, 'min_data_in_leaf': 8, 'reg_alpha': 4.0427871482363145, 'reg_lambda': 2.6902233996220723e-05}. Best is trial 33 with value: 2910.993768755679.
# [I 2026-02-07 11:18:58,564] Trial 42 finished with value: 2958.428963238822 and parameters: {'n_estimators': 1022, 'boosting': 'gbdt', 'max_depth': 10, 'num_leaves': 118, 'learning_rate': 0.022006539424163255, 'feature_fraction': 0.9417361791369754, 'bagging_fraction': 0.7483746228011954, 'bagging_freq': 7, 'min_data_in_leaf': 10, 'reg_alpha': 4.68715818191843, 'reg_lambda': 2.2790691241692412e-05}. Best is trial 33 with value: 2910.993768755679.
# [I 2026-02-07 11:19:01,423] Trial 43 finished with value: 2918.167165501992 and parameters: {'n_estimators': 1118, 'boosting': 'gbdt', 'max_depth': 9, 'num_leaves': 90, 'learning_rate': 0.009731365499064669, 'feature_fraction': 0.9730601000026622, 'bagging_fraction': 0.7462428158589327, 'bagging_freq': 9, 'min_data_in_leaf': 8, 'reg_alpha': 2.7074105384300666, 'reg_lambda': 0.0014224215252617205}. Best is trial 33 with value: 2910.993768755679.
# [I 2026-02-07 11:19:04,342] Trial 44 finished with value: 2945.886937109978 and parameters: {'n_estimators': 952, 'boosting': 'gbdt', 'max_depth': 8, 'num_leaves': 89, 'learning_rate': 0.010104081499378194, 'feature_fraction': 0.9710761415833563, 'bagging_fraction': 0.8345503948390399, 'bagging_freq': 9, 'min_data_in_leaf': 6, 'reg_alpha': 1.8223768482384652, 'reg_lambda': 0.0011890435548874692}. Best is trial 33 with value: 2910.993768755679.
# [I 2026-02-07 11:19:07,943] Trial 45 finished with value: 2925.0173701830327 and parameters: {'n_estimators': 1116, 'boosting': 'gbdt', 'max_depth': 10, 'num_leaves': 121, 'learning_rate': 0.005240296980759719, 'feature_fraction': 0.9941980902581963, 'bagging_fraction': 0.8022178153522527, 'bagging_freq': 9, 'min_data_in_leaf': 10, 'reg_alpha': 0.19774648527609354, 'reg_lambda': 0.020108516978570176}. Best is trial 33 with value: 2910.993768755679.
# [I 2026-02-07 11:19:10,990] Trial 46 finished with value: 2952.2571073747818 and parameters: {'n_estimators': 1033, 'boosting': 'gbdt', 'max_depth': 10, 'num_leaves': 121, 'learning_rate': 0.005489335552361239, 'feature_fraction': 0.9969177746178148, 'bagging_fraction': 0.8029298546833717, 'bagging_freq': 9, 'min_data_in_leaf': 14, 'reg_alpha': 0.18568995344451808, 'reg_lambda': 0.025650039516855693}. Best is trial 33 with value: 2910.993768755679.
# [I 2026-02-07 11:19:15,361] Trial 47 finished with value: 2953.2163008606294 and parameters: {'n_estimators': 1080, 'boosting': 'gbdt', 'max_depth': 10, 'num_leaves': 103, 'learning_rate': 0.0028654544340488064, 'feature_fraction': 0.9804015858026347, 'bagging_fraction': 0.8369741952494535, 'bagging_freq': 11, 'min_data_in_leaf': 12, 'reg_alpha': 0.039166764302377664, 'reg_lambda': 0.013502161720545006}. Best is trial 33 with value: 2910.993768755679.
# [I 2026-02-07 11:19:17,220] Trial 48 finished with value: 3297.123920754873 and parameters: {'n_estimators': 887, 'boosting': 'gbdt', 'max_depth': 3, 'num_leaves': 116, 'learning_rate': 0.015719337350852618, 'feature_fraction': 0.9336622485619156, 'bagging_fraction': 0.8513283985934299, 'bagging_freq': 10, 'min_data_in_leaf': 26, 'reg_alpha': 1.1768247300341086, 'reg_lambda': 0.0018363160314926884}. Best is trial 33 with value: 2910.993768755679.
# [I 2026-02-07 11:19:29,389] Trial 49 finished with value: 8880.772218356704 and parameters: {'n_estimators': 1246, 'boosting': 'dart', 'max_depth': 9, 'num_leaves': 98, 'learning_rate': 0.0035084624888950043, 'feature_fraction': 0.9827364418374288, 'bagging_fraction': 0.7910639962427615, 'bagging_freq': 6, 'min_data_in_leaf': 10, 'reg_alpha': 0.17986253409110636, 'reg_lambda': 0.0028420950593763487}. Best is trial 33 with value: 2910.993768755679.

# %%
params = study.best_params
params
# Out:
# {'n_estimators': 1167,
#  'boosting': 'gbdt',
#  'max_depth': 8,
#  'num_leaves': 82,
#  'learning_rate': 0.02301646339802857,
#  'feature_fraction': 0.9576264130599703,
#  'bagging_fraction': 0.742267771513603,
#  'bagging_freq': 4,
#  'min_data_in_leaf': 7,
#  'reg_alpha': 9.625193154936303,
#  'reg_lambda': 1.6344037702121245e-05}

# %%
model = lgb.LGBMRegressor(**params)
model.fit(X_train, y_train)
model.predict(X_test)
# Out:
# array([30337.35751981, 28726.42149512, 28474.54564257, 15857.54084675,
#        23031.02481155, 28407.19780426, 24481.82815116, 24335.77439376,
#        28137.33681682, 28035.61907719, 21940.14850001, 27926.93428032,
#        16412.95505215, 15075.06259074, 32545.04473625, 27176.47518729,
#        27781.01796006, 29865.20221029, 28289.6502155 , 25263.52691123,
#        39081.83499677, 15734.86583126, 21917.23349072, 32964.64837332,
#        38300.17547063, 26092.84208726, 24956.64967223, 27151.82401503,
#        13367.73867933, 27886.74813182, 25780.05501775, 25414.34754955,
#        16103.17586142, 24185.43507813, 18601.1140582 , 32937.08772745,
#        23204.31776918, 22558.45049799, 19490.71434307, 28149.30113728,
#        24749.99741854, 23146.26240736, 23964.32953431, 23250.92545736,
#        20269.13060678, 25016.13875917, 27496.11468965, 26586.81988735,
#        16603.32618576, 24655.32301462, 23412.27797102, 20312.02300609,
#        27063.45501959, 14537.07860172, 29943.66915298, 23961.84259029,
#        23334.68782335, 24060.46005895, 25996.36273405, 29458.46236034,
#        23499.60813594, 19016.45713093, 25111.55483771, 24574.54500799,
#        30088.71351054, 28307.5992604 , 37354.27881167, 13882.90395141,
#        27759.02547697, 28297.07533353, 35791.45188107, 23106.31635391,
#        25873.06919805, 18866.43491727, 13969.06697801, 13824.14398348,
#        26369.52019149, 24447.77946092, 21003.60345122, 12790.13804951,
#        17224.45330992, 35439.99507532, 25352.73598515, 18580.45466839,
#        23626.64086804, 26029.22290458, 24871.08580081, 28671.73412514,
#        31550.99649568, 15835.14373679, 28247.7464755 , 34931.57141048,
#        27562.37009901, 29581.44260624, 22959.28093205, 25326.22882357,
#        24515.94024585, 13936.13912164, 29128.59876767, 29655.89754725,
#        23851.05807816, 17271.05516017, 28033.03227813, 16455.27001255,
#        29149.93691975, 28119.34462768, 20894.88109897, 13812.75000555,
#        24866.46615067, 25521.3333992 , 30009.13471058, 22399.34906258,
#        17769.04516622, 29732.62389599, 30454.43432205, 22904.07501013,
#        24231.67944764, 23844.04414547, 13911.40291399, 24469.50399165,
#        33711.53475624, 29904.76738886, 26071.82807674, 35186.8920128 ,
#        28857.76391137, 27153.38192737, 27525.30714356, 33325.11938893,
#        22573.82388678, 36194.17978677, 23276.15492096, 14348.09784698,
#        27558.26555395, 22354.30286656, 31975.8016261 , 28682.33043751,
#        27605.33007835, 23321.27758402, 28628.87700807, 22003.72786138,
#        23890.33652627, 22817.10782133, 29913.33108379, 30521.21712805,
#        23502.66672995, 26741.12021768, 32029.74946585, 22886.77023132,
#        34098.19675151, 30978.47828143, 16317.270675  , 22701.54024541,
#        14959.23905536, 22592.72673435, 14733.4104936 , 27523.64177847,
#        21938.9504435 , 23889.302245  , 31433.92268955, 23653.71538268,
#        29420.13206643, 26862.9975829 , 25601.18630625, 29695.93168682,
#        23343.07104341, 27318.99236284, 21805.01406178, 19305.3847801 ,
#        15066.9005557 , 28068.67147244, 21956.83974084, 14841.45715713,
#        29084.80004614, 26147.07043965, 20875.92732818, 16559.36864623,
#        16949.50655158, 14903.60553168, 15410.71434289, 26416.30533578,
#        28335.64254144, 15238.9609029 , 15212.96254894, 13916.36686261,
#        28097.91933566, 15064.89810031, 27983.43262312, 23856.55044738,
#        30110.36876796, 28151.12969036, 29384.65944418, 23324.60095142,
#        22669.88241462, 34756.46824685, 29253.63023824, 14209.47422693,
#        26654.25569694, 15438.71000011, 14897.04642748, 22773.21892425,
#        28777.39703895, 22841.56610754, 12454.54001063, 27453.77706429,
#        23335.33430193, 33176.91487313, 13448.1678707 , 21565.3689981 ,
#        27592.77183724, 29120.1580555 , 33804.15832444, 22847.7898301 ,
#        28161.3846782 , 26523.75144785, 27946.02833531, 35645.16896865,
#        27381.32741728, 23149.75179013, 22960.13923278, 29501.54689016,
#        25639.7972116 , 16898.67951699, 27888.56770866, 29205.45227288,
#        26837.09725017, 13546.5948178 , 29978.91355148, 23965.82712132,
#        23725.58813459, 35188.85205873, 28962.00260799, 21102.20402868,
#        28481.44540096, 21984.608726  , 14999.30102527, 21890.36558163,
#        25557.67095709, 24416.84069374, 31292.43761459, 24799.69753001,
#        29465.20591508, 22869.77623242, 32288.49927811, 18338.70788591,
#        22151.59326849, 14527.90528195, 27979.88823343])

# %%
lgb_regressor = lgb.train(params, lgb.Dataset(X_train, label = y_train))
y_pred = lgb_regressor.predict(X_test)
y_pred
# Out:
# array([30337.35751981, 28726.42149512, 28474.54564257, 15857.54084675,
#        23031.02481155, 28407.19780426, 24481.82815116, 24335.77439376,
#        28137.33681682, 28035.61907719, 21940.14850001, 27926.93428032,
#        16412.95505215, 15075.06259074, 32545.04473625, 27176.47518729,
#        27781.01796006, 29865.20221029, 28289.6502155 , 25263.52691123,
#        39081.83499677, 15734.86583126, 21917.23349072, 32964.64837332,
#        38300.17547063, 26092.84208726, 24956.64967223, 27151.82401503,
#        13367.73867933, 27886.74813182, 25780.05501775, 25414.34754955,
#        16103.17586142, 24185.43507813, 18601.1140582 , 32937.08772745,
#        23204.31776918, 22558.45049799, 19490.71434307, 28149.30113728,
#        24749.99741854, 23146.26240736, 23964.32953431, 23250.92545736,
#        20269.13060678, 25016.13875917, 27496.11468965, 26586.81988735,
#        16603.32618576, 24655.32301462, 23412.27797102, 20312.02300609,
#        27063.45501959, 14537.07860172, 29943.66915298, 23961.84259029,
#        23334.68782335, 24060.46005895, 25996.36273405, 29458.46236034,
#        23499.60813594, 19016.45713093, 25111.55483771, 24574.54500799,
#        30088.71351054, 28307.5992604 , 37354.27881167, 13882.90395141,
#        27759.02547697, 28297.07533353, 35791.45188107, 23106.31635391,
#        25873.06919805, 18866.43491727, 13969.06697801, 13824.14398348,
#        26369.52019149, 24447.77946092, 21003.60345122, 12790.13804951,
#        17224.45330992, 35439.99507532, 25352.73598515, 18580.45466839,
#        23626.64086804, 26029.22290458, 24871.08580081, 28671.73412514,
#        31550.99649568, 15835.14373679, 28247.7464755 , 34931.57141048,
#        27562.37009901, 29581.44260624, 22959.28093205, 25326.22882357,
#        24515.94024585, 13936.13912164, 29128.59876767, 29655.89754725,
#        23851.05807816, 17271.05516017, 28033.03227813, 16455.27001255,
#        29149.93691975, 28119.34462768, 20894.88109897, 13812.75000555,
#        24866.46615067, 25521.3333992 , 30009.13471058, 22399.34906258,
#        17769.04516622, 29732.62389599, 30454.43432205, 22904.07501013,
#        24231.67944764, 23844.04414547, 13911.40291399, 24469.50399165,
#        33711.53475624, 29904.76738886, 26071.82807674, 35186.8920128 ,
#        28857.76391137, 27153.38192737, 27525.30714356, 33325.11938893,
#        22573.82388678, 36194.17978677, 23276.15492096, 14348.09784698,
#        27558.26555395, 22354.30286656, 31975.8016261 , 28682.33043751,
#        27605.33007835, 23321.27758402, 28628.87700807, 22003.72786138,
#        23890.33652627, 22817.10782133, 29913.33108379, 30521.21712805,
#        23502.66672995, 26741.12021768, 32029.74946585, 22886.77023132,
#        34098.19675151, 30978.47828143, 16317.270675  , 22701.54024541,
#        14959.23905536, 22592.72673435, 14733.4104936 , 27523.64177847,
#        21938.9504435 , 23889.302245  , 31433.92268955, 23653.71538268,
#        29420.13206643, 26862.9975829 , 25601.18630625, 29695.93168682,
#        23343.07104341, 27318.99236284, 21805.01406178, 19305.3847801 ,
#        15066.9005557 , 28068.67147244, 21956.83974084, 14841.45715713,
#        29084.80004614, 26147.07043965, 20875.92732818, 16559.36864623,
#        16949.50655158, 14903.60553168, 15410.71434289, 26416.30533578,
#        28335.64254144, 15238.9609029 , 15212.96254894, 13916.36686261,
#        28097.91933566, 15064.89810031, 27983.43262312, 23856.55044738,
#        30110.36876796, 28151.12969036, 29384.65944418, 23324.60095142,
#        22669.88241462, 34756.46824685, 29253.63023824, 14209.47422693,
#        26654.25569694, 15438.71000011, 14897.04642748, 22773.21892425,
#        28777.39703895, 22841.56610754, 12454.54001063, 27453.77706429,
#        23335.33430193, 33176.91487313, 13448.1678707 , 21565.3689981 ,
#        27592.77183724, 29120.1580555 , 33804.15832444, 22847.7898301 ,
#        28161.3846782 , 26523.75144785, 27946.02833531, 35645.16896865,
#        27381.32741728, 23149.75179013, 22960.13923278, 29501.54689016,
#        25639.7972116 , 16898.67951699, 27888.56770866, 29205.45227288,
#        26837.09725017, 13546.5948178 , 29978.91355148, 23965.82712132,
#        23725.58813459, 35188.85205873, 28962.00260799, 21102.20402868,
#        28481.44540096, 21984.608726  , 14999.30102527, 21890.36558163,
#        25557.67095709, 24416.84069374, 31292.43761459, 24799.69753001,
#        29465.20591508, 22869.77623242, 32288.49927811, 18338.70788591,
#        22151.59326849, 14527.90528195, 27979.88823343])

# %% [markdown]
# ## 📉 Evaluating Model Performance

# %% [markdown]
# ### Evaluation metrics for LightGBM Regressor : R2 Score, Adjusted R2, Root Mean Squared Error, Mean, Absolute Error

# %%
def adj_r2_score(r_squared,n,d):
    # n is no. of sample
    # d is no. of features
    # r_squared is standard R²
    adj_r2 = 1 - (((1-r_squared)*(n-1))/(n-d-1))
    return adj_r2

# %%
r2_score = r2_score(y_test,y_pred)
adjusted_r2 = adj_r2_score(r2_score,len(y_test), X_test.shape[1])
rmse = root_mean_squared_error(y_test,y_pred)
mae = mean_absolute_error(y_test,y_pred)

# %% [markdown]
# **Log final model**

# %%
with mlflow.start_run(run_name = "best LGBM Model") as run:
    mlflow.log_params(params)
    mlflow.log_metrics({"RMSE": rmse,"MAE":mae,"R2":r2_score,"Adjusted R2": adjusted_r2})
    mlflow.sklearn.log_model(model, name="best model")

# %%
metrics = pd.DataFrame({'metric':['R2 Score', 'Adjusted R2','Root Mean Squared Error', 'Mean Absoulte Error'], 
                        'values':[r2_score, adjusted_r2, rmse, mae]})
metrics
# Out:
#                     metric       values
# 0                 R2 Score     0.807016
# 1              Adjusted R2     0.797982
# 2  Root Mean Squared Error  2901.236562
# 3      Mean Absoulte Error  1625.888148

# %% [markdown]
# ### Prediction Intervals for LightGBM Model

# %% [markdown]
# **Computing Prediction Intervals**

# %%
X_fit,X_cal, y_fit, y_cal = train_test_split(X_train, y_train, test_size = 0.2, random_state = 42)

# %%
model = lgb.LGBMRegressor(**params)
model.fit(X_fit,y_fit)
# Out:
# LGBMRegressor(bagging_fraction=0.742267771513603, bagging_freq=4,
#               boosting='gbdt', feature_fraction=0.9576264130599703,
#               learning_rate=0.02301646339802857, max_depth=8,
#               min_data_in_leaf=7, n_estimators=1167, num_leaves=82,
#               reg_alpha=9.625193154936303, reg_lambda=1.6344037702121245e-05)

# %%
y_cal_pred = model.predict(X_cal)
residual  = np.abs(y_cal, y_cal_pred)

# %%
alpha = 0.10
q = np.quantile(residual, 1 - alpha)
pi_low = y_pred - q
pi_high = y_pred + q

# %%
coverage = np.mean((y_test >= pi_low) & (y_test <= pi_high))
coverage
# Out:
# np.float64(1.0)

# %% [markdown]
# **Visualizing Prediction Interval**

# %%
outside = (y_test < pi_low )| (y_test > pi_high)
df_plot = pd.DataFrame({
    'Predicted': y_pred,
    'Actual' : y_test,
    'Inside_PI': ~outside
})

df_plot
# Out:
#         Predicted  Actual  Inside_PI
# 613  30337.357520   31000       True
# 451  28726.421495   31000       True
# 731  28474.545643   29000       True
# 436  15857.540847   15000       True
# 275  23031.024812   23000       True
# ..            ...     ...        ...
# 597  32288.499278   29000       True
# 204  18338.707886   39000       True
# 514  22151.593268   23000       True
# 628  14527.905282   15000       True
# 945  27979.888233   29000       True
#
# [247 rows x 3 columns]

# %%
x_inside = df_plot[df_plot['Inside_PI']==True]['Predicted']
y_inside = df_plot.loc[df_plot['Inside_PI']==True]['Actual']
x_outside = df_plot[~df_plot['Inside_PI']]['Predicted']
y_outside = df_plot[~df_plot['Inside_PI']]['Actual']

# %%
# Reference diagonal line

min_val = min(df_plot['Actual'].min(), df_plot['Predicted'].min())
max_val = max(df_plot['Actual'].max(), df_plot['Predicted'].max())

fig = go.Figure()

# Points Inside the prediction interval

fig.add_trace(go.Scatter(
    x = x_inside,
    y = y_inside,
    mode = 'markers',
    name = 'Inside PI',
    marker = dict(size = 8, opacity = 0.6)
    
))

# Points outside the prediction Interval

fig.add_trace(go.Scatter(
    x = x_outside,
    y = y_outside,
    mode = 'markers',
    name = 'Outside PI',
    marker = dict(size = 8, color = 'red')
    
))

# Prediction Line

fig.add_trace(go.Scatter(
    x = [min_val, max_val],
    y = [min_val, max_val],
    mode = 'lines',
    name = 'perfect prediction',
    line = dict(dash = 'dash', color = 'grey')
))

fig.update_layout(
    title = 'Prediction Interval Coverage',
    xaxis_title = 'Predicted',
    yaxis_title = 'Actual',
    template = 'plotly_white',
    width = 800,
    height = 600
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="d8e0ec65-16f8-4f79-a86d-4da20f7f3b1b" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d8e0ec65-16f8-4f79-a86d-4da20f7f3b1b")) {                    Plotly.newPlot(                        "d8e0ec65-16f8-4f79-a86d-4da20f7f3b1b",                        [{"marker":{"opacity":0.6,"size":8},"mode":"markers","name":"Inside PI","x":{"dtype":"f8","bdata":"GMGa4Vag3UALrMb5mg3cQOjOzuuizttAeGB3OsX4zkDJM4OWwX3WQMY206jMvdtAXbhtAHXo10A63aqP8cPXQIwhaI5VettAnPD1nudg20ANLQaBCW3VQMuqP8u7RdtA4Q+THz0H0EDAJPkCiHHNQIZq9dxCyN9AVvR3aR6K2kAO8UEmQSHbQO9qA\u002fFMKt1AjnQhnWmg20Bg3um44avYQAgmS7g6FeNAP\u002f+O0267zkDJE4PxTmfVQDtleb+UGOBAdpR0nYWz4kD++MHkNXvZQBnROpQpX9hAo4upvPSD2kAvXQuN3hvKQP9NZOGvO9tAVytphQMt2UCUdEA+ltHYQJKKoIKWc89AZ\u002fBR2Fue10ANxrpMRyrSQOPKqc4iFeBA5YVUVhSp1kDGhvXUnAfWQAX9y7etCNNAcFDVRVN920ARkbTVfyvYQNhBSMuQmtZAqxEXFxVn10BagrE6u7TWQLSL3FtIy9NAyydu4Qhu2EBDQRNXB9raQADHCHm09tlAOz864NQ20EAehUWs1BPYQODyRsoR3dZAYIjueAHW00AGegof3W3aQGQAnw+KZMxAoANn0+o93UBK1f\u002fsdWbXQLU4TAWsydZAoBqbcR1\u002f10Bv4gg3F2PZQKjPT5edxNxAFgGz6+by1kDnFaJBHZLSQMwHdoLjhdhASjFp4aL\u002f10AAGCiqLWLdQH9KSFrmpNtAg3MG7Eg94kB1\u002f620cx3LQCQlaqHBG9tARLxD0kSi20AaSc917nnhQLF9JD+UkNZAqKe9bURE2UBSPa\u002fVm2zSQFRMvJKISMtAkvcMbhIAy0AAQtFKYcDZQNgRsOLx39dAE93xnuaC1EAML5urEfvIQFqbBwMd0tBAMzGo1\u002f9N4UAbdWEaL8LYQNdtSRkdJdJAXWb7A6kS10CykRFETmvZQFaswn3FSdhAtgXo++7\u002f20CMzJXGv8\u002feQLuQ92WS7c5AHy5Bxu+V20DMof5Icg7hQBa9s6+X6tpAPRupU1zj3EBtacr60WvWQAOZC6WOu9hAXOr8LPzw10DH67zOETjLQA2jNVImctxA9ARqcfn13EDcco23w0rXQPGCvofD3dBAX0rYEEJg20DFu+JH0RHQQI4\u002ffvZ7d9xAZ0RhDtZ120Av8+xjuGfUQNiKLgBg+spAxJtp1Z1I2ECpmGlWVezYQNUkGZ9ITt1Aj5EKV9bf1UDe1gDkQlrRQIRy6e0nCd1AWbfuy5u93UBzSPfMBF7WQPj2EXzrqddAtIBH0wJJ10BMj6+SsyvLQNs1ZkFg5ddAox25HPF14EBGLeYcMTTdQCyXNf\u002f0ddlAQmxei1wu4UCtiOzjcC7cQPZ6f3FYhNpAZ3o9qFPh2kCRugjSo0XgQIihj7p0C9ZAMzDQwEWs4UBqnTnqCbvWQCT9P4YMBsxAqAPW\u002fpDp2kAicCpik9TVQD6L103zOd9AYWLjJZUC3ED+7gAgVfXaQGzF78NRxtZAb3TmIDj120DO40eV7nzVQNF+pYmVVNdA\u002fG+L5kZI1kA\u002fC3owVTbdQHgRbeVNzt1APhy0q6rz1kATfKWxRx3aQK2ZP\u002fdvR99AJUp4S7FZ1kBM0slLRqbgQCO6KZyeQN5ApXZ6paLez0Bed2GTYivWQH66XZmeN81AOMzQgi4Q1kCn7g2LtMbMQFcG5hLp4NpAPfUQ1Lxs1UARaPtXU1TXQAV3WA17st5AzWrUyG0Z10BXvcZzCLvcQGTxZdi\u002fO9pACgxx7EsA2UDHv8Gg+\u002f\u002fcQJqj+YvEy9ZADm3fgr+t2kCuYGPmQEvVQI6zPKBY2tJA1L9oRXNtzUAdi2f5KmnbQPlbUL41cdVA3esfhLr8zEDSuvQzM2fcQPtQFYLEiNlABU5YWfti1EDNWOaX1yvQQMZOV2tgjdBAneAPgs0bzUAkgZZvWxnOQEsVn4oTzNlAhR5mH+mr20A\u002fyd3+esPNQCu8zTR7ts1AvKNa9S4uy0BBPGXWenDbQPRr8\u002fRybM1A4OEYsNtT20Dbp4c6I0zXQDLp5JmXZ91AIs\u002fYTMh920DVWFU0KrLcQEX2\u002fHUmx9ZAmi97eXgj1kDgzuD7jvjgQAPJ0lVokdxAY9p3s7zAy0Aer1ZdkAfaQHuWSOFaJ85AruNV8YUYzUBq2NoCTj3WQCwTFmlZGtxAHSAbO2RO1kCRhBEfRVPIQFjfa7txz9pA2OwzZdXJ1kAwBqRGHTPgQGN7yXwVRMpAtzGqnVcP1UAQCshlMfLaQMLSlB0KcNxAHGr+EIWB4EAekJOM8k\u002fWQBNMkZ5YgNtAhbS4F\u002fDm2UBs7D7QgUrbQBHyMGilZ+FAsp1n9FS92kBFVFQdcJvWQP6XMOkIbNZAzZc\u002fAGPP3ECG0IMF8wnZQD3ZNH2rgNBAMbdWVSQ820DP7QnyXIXcQIbFWDlGNdpAAlr9Ikx1ykB7pKB3ukbdQOo\u002fju90Z9dAQ0f\u002fo2Ur10DlrRBEmy7hQAO4uiqASNxAeE7ODo2b1EDpB3OBXNDbQBziXfUmeNVA3\u002fT+h6ZLzUB5gbBll2DVQFb89fBq9dhA8hntzTXY10CtneABHI\u002feQP7mVKTsN9hATG22LU3G3EDwvMqtcVXWQFYoLPQfiN9AWLYATq3o0UA7aBz45aHVQGdgR+DzX8xAxAbR2PhS20A="},"y":{"dtype":"i4","bdata":"..."},"type":"scatter"},{"marker":{"color":"red","size":8},"mode":"markers","name":"Outside PI","x":[],"y":[],"type":"scatter"},{"line":{"color":"grey","dash":"dash"},"mode":"lines","name":"perfect prediction","x":[12454.54001063321,39081.834996771126],"y":[12454.54001063321,39081.834996771126],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay"," ...

# %% [markdown]
# **Inference**
#
# - All test points lie within the 90% prediction interval, resulting in 100% empirical coverage on the test set, indicating conservative uncertainty estimates.
# - The prediction intervals are conservative, meaning they are wider than strictly necessary to guarantee coverage.
# - The model captures the general relationship between features and insurance cost, but individual predictions can still vary substantially
# - The model does not show clear systematic over-prediction or under-prediction across the test set.
# - The model prioritizes reliability over precision, which is acceptable and often preferred in insurance risk estimation.

# %%
import matplotlib.pyplot as plt
import numpy as np

idx = np.arange(len(y_test))

plt.figure(figsize=(10, 6))
plt.plot(idx, y_test.values, label="Actual", color="black")
plt.plot(idx, y_pred, label="Prediction", color="blue")
plt.fill_between(
    idx,
    pi_low,
    pi_high,
    color="blue",
    alpha=0.25,
    label="Prediction Interval (90%)"
)

plt.xlabel("Test Sample Index")
plt.ylabel("Target Value")
plt.title("Predictions with Prediction Intervals")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Feature Importance using SHAP

# %%
import shap
explainer = shap.TreeExplainer(lgb_regressor)
shap_values = explainer.shap_values(X_test)

# %%
shap.summary_plot(shap_values,X_test)

# %%
plt.figure(figsize = (20,8))
shap.summary_plot(shap_values,X_test, plot_type = 'bar')
plt.show()

# %% [markdown]
# **Model Insights**:
#
# - Age contributes the most to the model’s predictions, followed by AnyTransplants, Weight, AnyChronicDiseases, and HistoryOfCancerInFamily.
# - Features such as BMI, NumberOfMajorSurgeries, Height, BloodPressureProblems, Diabetes, and KnownAllergies contribute less to the final prediction.

# %% [markdown]
# #  📂 Saving the model

# %%
import pickle
import os
MODELS_DIR = PROJECT_ROOT / "models"
MODELS_DIR.mkdir(exist_ok=True)

model_path = MODELS_DIR / "insurance_lgbm_model.pkl"



with open(model_path,"wb") as f:
    pickle.dump(model,f)

print("Model saved at:", model_path)
print("File exists:", os.path.exists(model_path))
# Out:
# Model saved at: /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/models/insurance_lgbm_model.pkl
# File exists: True

# %%
with open(model_path, "rb") as f:
    loaded_model = pickle.load(f)

preds = loaded_model.predict(X_train.head(5))
print(preds)
# Out:
# [23011.94531382 23253.63491832 15560.275324   20694.10723414
#  25069.63398192]

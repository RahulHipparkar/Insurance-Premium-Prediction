# %% [markdown]
# # 🏆 About Project

# %% [markdown]
# ## 🎯  Objective
#
# Insurance companies need to accurately predict the cost of health insurance for individuals to set premiums appropriately. However, traditional methods of cost prediction often rely on broad actuarial tables and historical averages, which may not account for the nuanced differences among individuals. By leveraging machine learning techniques, insurers can predict more accurately the insurance costs tailored to individual profiles, leading to more competitive pricing and better risk management.
#
# **Insurance Cost Prediction need**
# The primary need for this project arises from the challenges insurers face in pricing policies accurately while remaining competitive in the market. Inaccurate predictions can lead to losses for insurers and unfairly high premiums for policyholders. By implementing a machine learning model, insurers can:
# - Enhance Precision in Pricing: Use individual data points to determine premiums that reflect actual risk more closely than generic estimates.
# - Increase Competitiveness: Offer rates that are attractive to consumers while ensuring that the pricing is sustainable for the insurer.
# - Improve Customer Satisfaction: Fair and transparent pricing based on personal health data can increase trust and satisfaction among policyholders.
# - Enable Personalized Offerings: Create customized insurance packages based on predicted costs, which can cater more directly to the needs and preferences of individuals.
# - Risk Assessment: Insurers can use the model to refine their risk assessment processes, identifying key factors that influence costs most significantly.
# - Policy Development: The insights gained from the model can inform the development of new insurance products or adjustments to existing ones.
# - Strategic Decision Making: Predictive analytics can aid in broader strategic decisions, such as entering new markets or adjusting policy terms based on risk predictions.
# - Customer Engagement: Insights from the model can be used in customer engagement initiatives, such as personalized marketing and tailored advice for policyholders.

# %% [markdown]
# ## 📚 Data Description

# %% [markdown]
# The dataset comprises the following 11 attributes:
# 1. Age: Numeric, ranging from 18 to 66 years.
# 2. Diabetes: Binary (0 or 1), where 1 indicates the presence of diabetes.
# 3. BloodPressureProblems: Binary (0 or 1), indicating the presence of blood pressure-related issues.
# 4. AnyTransplants: Binary (0 or 1), where 1 indicates the person has had a transplant.
# 5. AnyChronicDiseases: Binary (0 or 1), indicating the presence of any chronic diseases.
# 6. Height: Numeric, measured in centimeters, ranging from 145 cm to 188 cm.
# 7. Weight: Numeric, measured in kilograms, ranging from 51 kg to 132 kg.
# 8. KnownAllergies: Binary (0 or 1), where 1 indicates known allergies.
# 9. HistoryOfCancerInFamily: Binary (0 or 1), indicating a family history of cancer.
# 10. NumberOfMajorSurgeries: Numeric, counting the number of major surgeries, ranging from 0 to 3 surgeries.
# 11. PremiumPrice: Numeric, representing the premium price in currency, ranging from 15,000 to 40,000.

# %% [markdown]
# # 🚀 Let's Get Started

# %% [markdown]
# ## 📚 Importing Libraries

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objs as go
import plotly.subplots as sp
from plotly.subplots import make_subplots
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
import plotly.express as px
import warnings
import time
import datetime as dt
warnings.filterwarnings("ignore")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.1.min"</script>

# %% [markdown]
# ## 📊 Importing Dataset

# %%
from pathlib import Path
DATA_PATH = Path("..") / "data" / "insurance.csv"
df = pd.read_csv(DATA_PATH)

# %% [markdown]
# ## 🎨 Custom Color Palette

# %%
def custom_palette(custom_colors):
    customPalette=sns.set_palette(sns.color_palette(custom_colors))
    sns.palplot(sns.color_palette(custom_colors),size=0.8)
    plt.tick_params(axis='both',labelsize=0,length=0)
    return

# %%
#defining colour palette
red = ["#4f000b","#720026","#ce4257","#ff7f51","#ff9b54"]
bo = ["#6930c3","#5e60ce","#0096c7","#48cae4","#ade8f4","#ff7f51","#ff9b54","#ffbf69"]
pink = ["#aa4465","#dd2d4a","#f26a8d","#f49cbb","#ffcbf2","#e2afff","#ff86c8","#ffa3a5","#ffbf81","#e9b827","#f9e576"]
custom_palette(pink)

# %% [markdown]
# ## 📉 Basic Analysis

# %% [markdown]
# **Shape of the data**

# %%
df.shape
# Out:
# (986, 11)

# %% [markdown]
# **Inference**
#
# - Shape of the data is 986 * 11
# - Number of rows: 986
# - Number of Columns: 11

# %% [markdown]
# **First Few Rows**

# %%
df.head()
# Out:
#    Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0   45         0                      0               0                   0
# 1   60         1                      0               0                   0
# 2   36         1                      1               0                   0
# 3   52         1                      1               0                   1
# 4   38         0                      0               0                   1
#
#    Height  Weight  KnownAllergies  HistoryOfCancerInFamily  \
# 0     155      57               0                        0
# 1     180      73               0                        0
# 2     158      59               0                        0
# 3     183      93               0                        0
# 4     166      88               0                        0
#
#    NumberOfMajorSurgeries  PremiumPrice
# 0                       0         25000
# 1                       0         29000
# 2                       1         23000
# 3                       2         28000
# 4                       1         23000

# %% [markdown]
# **Columns in the dataframe**

# %%
df.columns
# Out:
# Index(['Age', 'Diabetes', 'BloodPressureProblems', 'AnyTransplants',
#        'AnyChronicDiseases', 'Height', 'Weight', 'KnownAllergies',
#        'HistoryOfCancerInFamily', 'NumberOfMajorSurgeries', 'PremiumPrice'],
#       dtype='object')

# %% [markdown]
# **Concise Summary**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      986 non-null    int64
#  1   Diabetes                 986 non-null    int64
#  2   BloodPressureProblems    986 non-null    int64
#  3   AnyTransplants           986 non-null    int64
#  4   AnyChronicDiseases       986 non-null    int64
#  5   Height                   986 non-null    int64
#  6   Weight                   986 non-null    int64
#  7   KnownAllergies           986 non-null    int64
#  8   HistoryOfCancerInFamily  986 non-null    int64
#  9   NumberOfMajorSurgeries   986 non-null    int64
#  10  PremiumPrice             986 non-null    int64
# dtypes: int64(11)
# memory usage: 84.9 KB

# %% [markdown]
# **Inference**
#
# - There are no missing values in the dataset.
# - All columns are of numeric type

# %% [markdown]
# **Descriptive Statistics**

# %%
df.describe().T
# Out:
#                          count          mean          std      min      25%  \
# Age                      986.0     41.745436    13.963371     18.0     30.0
# Diabetes                 986.0      0.419878     0.493789      0.0      0.0
# BloodPressureProblems    986.0      0.468560     0.499264      0.0      0.0
# AnyTransplants           986.0      0.055781     0.229615      0.0      0.0
# AnyChronicDiseases       986.0      0.180527     0.384821      0.0      0.0
# Height                   986.0    168.182556    10.098155    145.0    161.0
# Weight                   986.0     76.950304    14.265096     51.0     67.0
# KnownAllergies           986.0      0.215010     0.411038      0.0      0.0
# HistoryOfCancerInFamily  986.0      0.117647     0.322353      0.0      0.0
# NumberOfMajorSurgeries   986.0      0.667343     0.749205      0.0      0.0
# PremiumPrice             986.0  24336.713996  6248.184382  15000.0  21000.0
#
#                              50%      75%      max
# Age                         42.0     53.0     66.0
# Diabetes                     0.0      1.0      1.0
# BloodPressureProblems        0.0      1.0      1.0
# AnyTransplants               0.0      0.0      1.0
# AnyChronicDiseases           0.0      0.0      1.0
# Height                     168.0    176.0    188.0
# Weight                      75.0     87.0    132.0
# KnownAllergies               0.0      0.0      1.0
# HistoryOfCancerInFamily      0.0      0.0      1.0
# NumberOfMajorSurgeries       1.0      1.0      3.0
# PremiumPrice             23000.0  28000.0  40000.0

# %% [markdown]
# **Missing Values Check**

# %%
df.isnull().sum()
# Out:
# Age                        0
# Diabetes                   0
# BloodPressureProblems      0
# AnyTransplants             0
# AnyChronicDiseases         0
# Height                     0
# Weight                     0
# KnownAllergies             0
# HistoryOfCancerInFamily    0
# NumberOfMajorSurgeries     0
# PremiumPrice               0
# dtype: int64

# %% [markdown]
# **Inference**
#
# There are no missing values in the dataset

# %% [markdown]
# # 📈 Exploratory Data Analysis

# %% [markdown]
# ## 📊 Univariate Analysis

# %% [markdown]
# **Creating feature BMI using height and weight of the users**

# %% [markdown]
# The formula for Body Mass Index (BMI) is:
#
# $$ \mathrm{BMI} = \frac{\text{weight}_{\mathrm{kg}}}{\text{height}_{\mathrm{m}}^{2}} $$

# %%
df['BMI'] = df['Weight'] / ((df['Height'] / 100) ** 2)
df
# Out:
#      Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0     45         0                      0               0                   0
# 1     60         1                      0               0                   0
# 2     36         1                      1               0                   0
# 3     52         1                      1               0                   1
# 4     38         0                      0               0                   1
# ..   ...       ...                    ...             ...                 ...
# 981   18         0                      0               0                   0
# 982   64         1                      1               0                   0
# 983   56         0                      1               0                   0
# 984   47         1                      1               0                   0
# 985   21         0                      0               0                   0
#
#      Height  Weight  KnownAllergies  HistoryOfCancerInFamily  \
# 0       155      57               0                        0
# 1       180      73               0                        0
# 2       158      59               0                        0
# 3       183      93               0                        0
# 4       166      88               0                        0
# ..      ...     ...             ...                      ...
# 981     169      67               0                        0
# 982     153      70               0                        0
# 983     155      71               0                        0
# 984     158      73               1                        0
# 985     158      75               1                        0
#
#      NumberOfMajorSurgeries  PremiumPrice        BMI
# 0                         0         25000  23.725286
# 1                         0         29000  22.530864
# 2                         1         23000  23.634033
# 3                         2         28000  27.770313
# 4                         1         23000  31.934969
# ..                      ...           ...        ...
# 981                       0         15000  23.458562
# 982                       3         28000  29.903029
# 983                       1         29000  29.552549
# 984                       1         39000  29.242109
# 985                       1         15000  30.043262
#
# [986 rows x 12 columns]

# %%
sns.boxplot(data=df, x='BMI')
plt.show()

# %% [markdown]
# ##

# %% [markdown]
# ### Distribution of Age

# %%
data = df.copy()

# %%
df
# Out:
#      Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0     45         0                      0               0                   0
# 1     60         1                      0               0                   0
# 2     36         1                      1               0                   0
# 3     52         1                      1               0                   1
# 4     38         0                      0               0                   1
# ..   ...       ...                    ...             ...                 ...
# 981   18         0                      0               0                   0
# 982   64         1                      1               0                   0
# 983   56         0                      1               0                   0
# 984   47         1                      1               0                   0
# 985   21         0                      0               0                   0
#
#      Height  Weight  KnownAllergies  HistoryOfCancerInFamily  \
# 0       155      57               0                        0
# 1       180      73               0                        0
# 2       158      59               0                        0
# 3       183      93               0                        0
# 4       166      88               0                        0
# ..      ...     ...             ...                      ...
# 981     169      67               0                        0
# 982     153      70               0                        0
# 983     155      71               0                        0
# 984     158      73               1                        0
# 985     158      75               1                        0
#
#      NumberOfMajorSurgeries  PremiumPrice        BMI
# 0                         0         25000  23.725286
# 1                         0         29000  22.530864
# 2                         1         23000  23.634033
# 3                         2         28000  27.770313
# 4                         1         23000  31.934969
# ..                      ...           ...        ...
# 981                       0         15000  23.458562
# 982                       3         28000  29.903029
# 983                       1         29000  29.552549
# 984                       1         39000  29.242109
# 985                       1         15000  30.043262
#
# [986 rows x 12 columns]

# %%
data['Age'].max()
# Out:
# np.int64(66)

# %%
data['age_category'] = pd.cut(data['Age'], bins=[17,30,50,66], labels = ['young','middle age','old'])
data
# Out:
#      Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0     45         0                      0               0                   0
# 1     60         1                      0               0                   0
# 2     36         1                      1               0                   0
# 3     52         1                      1               0                   1
# 4     38         0                      0               0                   1
# ..   ...       ...                    ...             ...                 ...
# 981   18         0                      0               0                   0
# 982   64         1                      1               0                   0
# 983   56         0                      1               0                   0
# 984   47         1                      1               0                   0
# 985   21         0                      0               0                   0
#
#      Height  Weight  KnownAllergies  HistoryOfCancerInFamily  \
# 0       155      57               0                        0
# 1       180      73               0                        0
# 2       158      59               0                        0
# 3       183      93               0                        0
# 4       166      88               0                        0
# ..      ...     ...             ...                      ...
# 981     169      67               0                        0
# 982     153      70               0                        0
# 983     155      71               0                        0
# 984     158      73               1                        0
# 985     158      75               1                        0
#
#      NumberOfMajorSurgeries  PremiumPrice        BMI age_category
# 0                         0         25000  23.725286   middle age
# 1                         0         29000  22.530864          old
# 2                         1         23000  23.634033   middle age
# 3                         2         28000  27.770313          old
# 4                         1         23000  31.934969   middle age
# ..                      ...           ...        ...          ...
# 981                       0         15000  23.458562        young
# 982                       3         28000  29.903029          old
# 983                       1         29000  29.552549          old
# 984                       1         39000  29.242109   middle age
# 985                       1         15000  30.043262        young
#
# [986 rows x 13 columns]

# %%
df
# Out:
#      Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0     45         0                      0               0                   0
# 1     60         1                      0               0                   0
# 2     36         1                      1               0                   0
# 3     52         1                      1               0                   1
# 4     38         0                      0               0                   1
# ..   ...       ...                    ...             ...                 ...
# 981   18         0                      0               0                   0
# 982   64         1                      1               0                   0
# 983   56         0                      1               0                   0
# 984   47         1                      1               0                   0
# 985   21         0                      0               0                   0
#
#      Height  Weight  KnownAllergies  HistoryOfCancerInFamily  \
# 0       155      57               0                        0
# 1       180      73               0                        0
# 2       158      59               0                        0
# 3       183      93               0                        0
# 4       166      88               0                        0
# ..      ...     ...             ...                      ...
# 981     169      67               0                        0
# 982     153      70               0                        0
# 983     155      71               0                        0
# 984     158      73               1                        0
# 985     158      75               1                        0
#
#      NumberOfMajorSurgeries  PremiumPrice        BMI
# 0                         0         25000  23.725286
# 1                         0         29000  22.530864
# 2                         1         23000  23.634033
# 3                         2         28000  27.770313
# 4                         1         23000  31.934969
# ..                      ...           ...        ...
# 981                       0         15000  23.458562
# 982                       3         28000  29.903029
# 983                       1         29000  29.552549
# 984                       1         39000  29.242109
# 985                       1         15000  30.043262
#
# [986 rows x 12 columns]

# %%
colors = ['#3C4F76' , '#D1BEB0' , '#AB9F9D']
labels = data['age_category'].value_counts().index
values = data['age_category'].value_counts()

# create pie chart

pie_chart = go.Figure(go.Pie(labels = labels, values = values, ))
pie_chart.update_traces(hoverinfo = 'label+value' , textinfo = 'percent', textfont_size = 20, 
                        marker = dict(colors = colors, line = dict( color = '#000000', width=2)))

# Bar Chart

bar_chart = go.Figure(go.Bar(x = labels, y = values, marker_color = colors))

# create subplots

fig = sp.make_subplots( rows = 1, cols = 2, column_width = [0.5,0.5], specs = [[{'type' : 'bar'}, {'type' : 'pie'}]],
                      subplot_titles = ("Bar Chart", "Pie Chart"))

# Add charts to subplots

fig.add_trace(bar_chart.data[0], row=1, col=1)
fig.add_trace(pie_chart.data[0], row=1, col=2)

# Update layout
fig.update_layout(
    showlegend=False,
    title=dict(
        text="Distribution of Age",
        font=dict(size=18)
    ),
    xaxis=dict(
        title=dict(
            text="Age-Groups",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    ),
    yaxis=dict(
        title=dict(
            text="Count",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    )
)


# Show subplots
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="684a5430-6085-4db8-87f1-0f2390426606" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("684a5430-6085-4db8-87f1-0f2390426606")) {                    Plotly.newPlot(                        "684a5430-6085-4db8-87f1-0f2390426606",                        [{"marker":{"color":["#3C4F76","#D1BEB0","#AB9F9D"]},"x":["middle age","old","young"],"y":{"dtype":"i2","bdata":"rQEoAQUB"},"type":"bar","xaxis":"x","yaxis":"y"},{"hoverinfo":"label+value","labels":["middle age","old","young"],"marker":{"colors":["#3C4F76","#D1BEB0","#AB9F9D"],"line":{"color":"#000000","width":2}},"textfont":{"size":20},"textinfo":"percent","values":{"dtype":"i2","bdata":"rQEoAQUB"},"type":"pie","domain":{"x":[0.55,1.0],"y":[0.0,1.0]}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":" ...

# %% [markdown]
# ### Distribution of Height

# %%
plt.figure(figsize = (15, 6))

# Histplot
plt.subplot(1,2,1)
sns.histplot(data = data , x = 'Height', kde = True, color = '#797596')
plt.xlabel('Height')
plt.ylabel('Count')

# Boxplot
plt.subplot(1,2,2)
sns.boxplot(data = data, x = 'Height', color = '#797596')
plt.xlabel('Height')

plt.suptitle('Distribution of Height')
plt.show()

# %% [markdown]
# ### Distribution of Weight

# %%
plt.figure(figsize = (15, 6))

# Histplot
plt.subplot(1,2,1)
sns.histplot(data = data , x = 'Weight', kde = True, color = '#345995')
plt.xlabel('Weight')
plt.ylabel('Count')

# Boxplot
plt.subplot(1,2,2)
sns.boxplot(data = data, x = 'Weight', color = '#345995')
plt.xlabel('Weight')

plt.suptitle('Distribution of Weight')
plt.show()

# %% [markdown]
# ### Distribution of BMI

# %%
data['BMI']
# Out:
# 0      23.725286
# 1      22.530864
# 2      23.634033
# 3      27.770313
# 4      31.934969
#          ...
# 981    23.458562
# 982    29.903029
# 983    29.552549
# 984    29.242109
# 985    30.043262
# Name: BMI, Length: 986, dtype: float64

# %%
data['BMI_category'] = pd.cut(data['BMI'],bins = [0,18.5,24.9,29.9, float('inf')], labels = ['Underweight','Normal', 'Overweight', 'Obese'])
data['BMI_category']
# Out:
# 0          Normal
# 1          Normal
# 2          Normal
# 3      Overweight
# 4           Obese
#           ...
# 981        Normal
# 982         Obese
# 983    Overweight
# 984    Overweight
# 985         Obese
# Name: BMI_category, Length: 986, dtype: category
# Categories (4, object): ['Underweight' < 'Normal' < 'Overweight' < 'Obese']

# %%
# colors = ['#f6f5f5', '#fe346e', '#512b58', '#2c003e','#636efa']
#colors  = ['#E0B1CB','#BE95C4','#9F86C0','#5E548E','#231942']
colors = ['gold', 'mediumturquoise', 'darkorange', 'lightgreen']
labels = data['BMI_category'].value_counts().index
values = data['BMI_category'].value_counts()

# create pie chart

pie_chart = go.Figure(go.Pie(labels = labels, values = values,pull = [0.05,0.05,0.03,0.03] ))
pie_chart.update_traces(hoverinfo = 'label+value' , textinfo = 'percent', textfont_size = 20, 
                        marker = dict(colors = [colors[0], colors[1],colors[2],colors[3]], line = dict( color = '#000000', width=2)))

# Bar Chart

bar_chart = go.Figure(go.Bar(x = labels, y = values, marker_color = [colors[0], colors[1],colors[2],colors[3]]))

# create subplots

fig = sp.make_subplots( rows = 1, cols = 2, column_width = [0.5,0.5], specs = [[{'type' : 'bar'}, {'type' : 'pie'}]],
                      subplot_titles = ("Bar Chart", "Pie Chart"))

# Add charts to subplots

fig.add_trace(bar_chart.data[0], row=1, col=1)
fig.add_trace(pie_chart.data[0], row=1, col=2)

# Update layout
fig.update_layout(
    showlegend=False,
    title=dict(
        text="Distribution of BMI",
        font=dict(size=18)
    ),
    xaxis=dict(
        title=dict(
            text="BMI-Groups",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    ),
    yaxis=dict(
        title=dict(
            text="Count",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    )
)


# Show subplots
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="cf81161e-ccda-4078-97ba-33f30aa50846" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("cf81161e-ccda-4078-97ba-33f30aa50846")) {                    Plotly.newPlot(                        "cf81161e-ccda-4078-97ba-33f30aa50846",                        [{"marker":{"color":["gold","mediumturquoise","darkorange","lightgreen"]},"x":["Overweight","Normal","Obese","Underweight"],"y":{"dtype":"i2","bdata":"QQE7ATcBJwA="},"type":"bar","xaxis":"x","yaxis":"y"},{"hoverinfo":"label+value","labels":["Overweight","Normal","Obese","Underweight"],"marker":{"colors":["gold","mediumturquoise","darkorange","lightgreen"],"line":{"color":"#000000","width":2}},"pull":[0.05,0.05,0.03,0.03],"textfont":{"size":20},"textinfo":"percent","values":{"dtype":"i2","bdata":"QQE7ATcBJwA="},"type":"pie","domain":{"x":[0.55,1.0],"y":[0.0,1.0]}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[ ...

# %% [markdown]
# ### Distribution of 'BloodPressureProblems'

# %%
data['BloodPressureProblems'].value_counts()
# Out:
# BloodPressureProblems
# 0    524
# 1    462
# Name: count, dtype: int64

# %%
colors = ['#D0CDD7' , '#ACB0BD']
labels = ['No','Yes']
values = data['BloodPressureProblems'].value_counts()

# create pie chart

pie_chart = go.Figure(go.Pie(labels = labels, values = values, ))
pie_chart.update_traces(hoverinfo = 'label+value' , textinfo = 'percent', textfont_size = 20, 
                        marker = dict(colors = colors, line = dict( color = '#000000', width=2)))

# Bar Chart

bar_chart = go.Figure(go.Bar(x = labels, y = values, marker_color = colors))

# create subplots

fig = sp.make_subplots( rows = 1, cols = 2, column_width = [0.5,0.5], specs = [[{'type' : 'bar'}, {'type' : 'pie'}]],
                      subplot_titles = ("Bar Chart", "Pie Chart"))

# Add charts to subplots

fig.add_trace(bar_chart.data[0], row=1, col=1)
fig.add_trace(pie_chart.data[0], row=1, col=2)

# Update layout
fig.update_layout(
    showlegend=False,
    title=dict(
        text="Distribution of Blood Pressure Problems",
        font=dict(size=18)
    ),
    xaxis=dict(
        title=dict(
            text="Blood Pressure Problems",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    ),
    yaxis=dict(
        title=dict(
            text="Count",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    )
)


# Show subplots
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="7127106d-abda-4ed4-9281-d3bc64821354" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("7127106d-abda-4ed4-9281-d3bc64821354")) {                    Plotly.newPlot(                        "7127106d-abda-4ed4-9281-d3bc64821354",                        [{"marker":{"color":["#D0CDD7","#ACB0BD"]},"x":["No","Yes"],"y":{"dtype":"i2","bdata":"DALOAQ=="},"type":"bar","xaxis":"x","yaxis":"y"},{"hoverinfo":"label+value","labels":["No","Yes"],"marker":{"colors":["#D0CDD7","#ACB0BD"],"line":{"color":"#000000","width":2}},"textfont":{"size":20},"textinfo":"percent","values":{"dtype":"i2","bdata":"DALOAQ=="},"type":"pie","domain":{"x":[0.55,1.0],"y":[0.0,1.0]}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"t ...

# %% [markdown]
# ### Distribution of transplants

# %%
data['AnyTransplants'].value_counts()
# Out:
# AnyTransplants
# 0    931
# 1     55
# Name: count, dtype: int64

# %%
colors = ['#D3C0CD' , '#B19994']
labels = ['No','Yes']
values = data['AnyTransplants'].value_counts()

# create pie chart

pie_chart = go.Figure(go.Pie(labels = labels, values = values, ))
pie_chart.update_traces(hoverinfo = 'label+value' , textinfo = 'percent', textfont_size = 20, 
                        marker = dict(colors = colors, line = dict( color = '#000000', width=2)))

# Bar Chart

bar_chart = go.Figure(go.Bar(x = labels, y = values, marker_color = colors))

# create subplots

fig = sp.make_subplots( rows = 1, cols = 2, column_width = [0.5,0.5], specs = [[{'type' : 'bar'}, {'type' : 'pie'}]],
                      subplot_titles = ("Bar Chart", "Pie Chart"))

# Add charts to subplots

fig.add_trace(bar_chart.data[0], row=1, col=1)
fig.add_trace(pie_chart.data[0], row=1, col=2)

# Update layout
fig.update_layout(
    showlegend=False,
    title=dict(
        text="Distribution of Transplants",
        font=dict(size=18)
    ),
    xaxis=dict(
        title=dict(
            text="No. of Transplants",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    ),
    yaxis=dict(
        title=dict(
            text="Count",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    )
)

# Show subplots
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="d6c4f05e-9544-4ec8-a88b-c5ecfc38c62e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d6c4f05e-9544-4ec8-a88b-c5ecfc38c62e")) {                    Plotly.newPlot(                        "d6c4f05e-9544-4ec8-a88b-c5ecfc38c62e",                        [{"marker":{"color":["#D3C0CD","#B19994"]},"x":["No","Yes"],"y":{"dtype":"i2","bdata":"owM3AA=="},"type":"bar","xaxis":"x","yaxis":"y"},{"hoverinfo":"label+value","labels":["No","Yes"],"marker":{"colors":["#D3C0CD","#B19994"],"line":{"color":"#000000","width":2}},"textfont":{"size":20},"textinfo":"percent","values":{"dtype":"i2","bdata":"owM3AA=="},"type":"pie","domain":{"x":[0.55,1.0],"y":[0.0,1.0]}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"t ...

# %% [markdown]
# ### Distribution of Chronic Diseases

# %%
data
# Out:
#      Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0     45         0                      0               0                   0
# 1     60         1                      0               0                   0
# 2     36         1                      1               0                   0
# 3     52         1                      1               0                   1
# 4     38         0                      0               0                   1
# ..   ...       ...                    ...             ...                 ...
# 981   18         0                      0               0                   0
# 982   64         1                      1               0                   0
# 983   56         0                      1               0                   0
# 984   47         1                      1               0                   0
# 985   21         0                      0               0                   0
#
#      Height  Weight  KnownAllergies  HistoryOfCancerInFamily  \
# 0       155      57               0                        0
# 1       180      73               0                        0
# 2       158      59               0                        0
# 3       183      93               0                        0
# 4       166      88               0                        0
# ..      ...     ...             ...                      ...
# 981     169      67               0                        0
# 982     153      70               0                        0
# 983     155      71               0                        0
# 984     158      73               1                        0
# 985     158      75               1                        0
#
#      NumberOfMajorSurgeries  PremiumPrice        BMI age_category BMI_category
# 0                         0         25000  23.725286   middle age       Normal
# 1                         0         29000  22.530864          old       Normal
# 2                         1         23000  23.634033   middle age       Normal
# 3                         2         28000  27.770313          old   Overweight
# 4                         1         23000  31.934969   middle age        Obese
# ..                      ...           ...        ...          ...          ...
# 981                       0         15000  23.458562        young       Normal
# 982                       3         28000  29.903029          old        Obese
# 983                       1         29000  29.552549          old   Overweight
# 984                       1         39000  29.242109   middle age   Overweight
# 985                       1         15000  30.043262        young        Obese
#
# [986 rows x 14 columns]

# %%
data['AnyChronicDiseases'].value_counts()
# Out:
# AnyChronicDiseases
# 0    808
# 1    178
# Name: count, dtype: int64

# %%
custom_palette(bo)

# %%
colors = [bo[3] , bo[7]]
labels = ['No','Yes']
values = data['AnyChronicDiseases'].value_counts()

# create pie chart

pie_chart = go.Figure(go.Pie(labels = labels, values = values, ))
pie_chart.update_traces(hoverinfo = 'label+value' , textinfo = 'percent', textfont_size = 20, 
                        marker = dict(colors = colors, line = dict( color = '#000000', width=2)))

# Bar Chart

bar_chart = go.Figure(go.Bar(x = labels, y = values, marker_color = colors))

# create subplots

fig = sp.make_subplots( rows = 1, cols = 2, column_width = [0.5,0.5], specs = [[{'type' : 'bar'}, {'type' : 'pie'}]],
                      subplot_titles = ("Bar Chart", "Pie Chart"))

# Add charts to subplots

fig.add_trace(bar_chart.data[0], row=1, col=1)
fig.add_trace(pie_chart.data[0], row=1, col=2)

# Update layout
fig.update_layout(
    showlegend=False,
    title=dict(
        text="Distribution of Chronic Diseases",
        font=dict(size=18)
    ),
    xaxis=dict(
        title=dict(
            text="Chronic Diseases",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    ),
    yaxis=dict(
        title=dict(
            text="Count",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    )
)

# Show subplots
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="ffb9084f-6ad5-496b-b38e-7ec519cb2f3a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("ffb9084f-6ad5-496b-b38e-7ec519cb2f3a")) {                    Plotly.newPlot(                        "ffb9084f-6ad5-496b-b38e-7ec519cb2f3a",                        [{"marker":{"color":["#48cae4","#ffbf69"]},"x":["No","Yes"],"y":{"dtype":"i2","bdata":"KAOyAA=="},"type":"bar","xaxis":"x","yaxis":"y"},{"hoverinfo":"label+value","labels":["No","Yes"],"marker":{"colors":["#48cae4","#ffbf69"],"line":{"color":"#000000","width":2}},"textfont":{"size":20},"textinfo":"percent","values":{"dtype":"i2","bdata":"KAOyAA=="},"type":"pie","domain":{"x":[0.55,1.0],"y":[0.0,1.0]}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"t ...

# %% [markdown]
# ### Distribution of Allergies

# %%
data['KnownAllergies'].value_counts()
# Out:
# KnownAllergies
# 0    774
# 1    212
# Name: count, dtype: int64

# %%
# colors = ['#A167A5','#D3BCCC']
colors = ['#716969', '#BCABAE']
labels = ['No','Yes']
values = data['KnownAllergies'].value_counts()

# create pie chart

pie_chart = go.Figure(go.Pie(labels = labels, values = values, ))
pie_chart.update_traces(hoverinfo = 'label+value' , textinfo = 'percent', textfont_size = 20, 
                        marker = dict(colors = colors, line = dict( color = '#000000', width=2)))

# Bar Chart

bar_chart = go.Figure(go.Bar(x = labels, y = values, marker_color = colors))

# create subplots

fig = sp.make_subplots( rows = 1, cols = 2, column_width = [0.5,0.5], specs = [[{'type' : 'bar'}, {'type' : 'pie'}]],
                      subplot_titles = ("Bar Chart", "Pie Chart"))

# Add charts to subplots

fig.add_trace(bar_chart.data[0], row=1, col=1)
fig.add_trace(pie_chart.data[0], row=1, col=2)

# Update layout
fig.update_layout(
    showlegend=False,
    title=dict(
        text="Distribution of Known Allergies",
        font=dict(size=18)
    ),
    xaxis=dict(
        title=dict(
            text="Allergies",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    ),
    yaxis=dict(
        title=dict(
            text="Count",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    )
)

# Show subplots
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="35e4b604-3058-40ed-b629-e1b2b9912a44" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("35e4b604-3058-40ed-b629-e1b2b9912a44")) {                    Plotly.newPlot(                        "35e4b604-3058-40ed-b629-e1b2b9912a44",                        [{"marker":{"color":["#716969","#BCABAE"]},"x":["No","Yes"],"y":{"dtype":"i2","bdata":"BgPUAA=="},"type":"bar","xaxis":"x","yaxis":"y"},{"hoverinfo":"label+value","labels":["No","Yes"],"marker":{"colors":["#716969","#BCABAE"],"line":{"color":"#000000","width":2}},"textfont":{"size":20},"textinfo":"percent","values":{"dtype":"i2","bdata":"BgPUAA=="},"type":"pie","domain":{"x":[0.55,1.0],"y":[0.0,1.0]}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"t ...

# %% [markdown]
# ### Distribution of Cancer History

# %%
data['HistoryOfCancerInFamily'].value_counts()
# Out:
# HistoryOfCancerInFamily
# 0    870
# 1    116
# Name: count, dtype: int64

# %%
colors=['#485696','#F9C784']
# labels = data['HistoryOfCancerInFamily'].value_counts().index
labels = ['No', 'Yes']
values = data['HistoryOfCancerInFamily'].value_counts()

# create pie chart

pie_chart = go.Figure(go.Pie(labels = labels, values = values, ))
pie_chart.update_traces(hoverinfo = 'label+value' , textinfo = 'percent', textfont_size = 20, 
                        marker = dict(colors = colors, line = dict( color = '#000000', width=2)))

# Bar Chart

bar_chart = go.Figure(go.Bar(x = labels, y = values, marker_color = colors))

# create subplots

fig = sp.make_subplots( rows = 1, cols = 2, column_width = [0.5,0.5], specs = [[{'type' : 'bar'}, {'type' : 'pie'}]],
                      subplot_titles = ("Bar Chart", "Pie Chart"))

# Add charts to subplots

fig.add_trace(bar_chart.data[0], row=1, col=1)
fig.add_trace(pie_chart.data[0], row=1, col=2)

# Update layout
fig.update_layout(
    showlegend=False,
    title=dict(
        text="Distribution of Cancer History",
        font=dict(size=18)
    ),
    xaxis=dict(
        title=dict(
            text="Cancer History",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    ),
    yaxis=dict(
        title=dict(
            text="Count",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    )
)

# Show subplots
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="30d8653b-fb97-4f01-9ec6-63bfee043a65" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("30d8653b-fb97-4f01-9ec6-63bfee043a65")) {                    Plotly.newPlot(                        "30d8653b-fb97-4f01-9ec6-63bfee043a65",                        [{"marker":{"color":["#485696","#F9C784"]},"x":["No","Yes"],"y":{"dtype":"i2","bdata":"ZgN0AA=="},"type":"bar","xaxis":"x","yaxis":"y"},{"hoverinfo":"label+value","labels":["No","Yes"],"marker":{"colors":["#485696","#F9C784"],"line":{"color":"#000000","width":2}},"textfont":{"size":20},"textinfo":"percent","values":{"dtype":"i2","bdata":"ZgN0AA=="},"type":"pie","domain":{"x":[0.55,1.0],"y":[0.0,1.0]}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"t ...

# %% [markdown]
# ### Distribution of No. Of Surgeries

# %%
data['NumberOfMajorSurgeries'].value_counts()
# Out:
# NumberOfMajorSurgeries
# 0    479
# 1    372
# 2    119
# 3     16
# Name: count, dtype: int64

# %%
colors = ['#006BA6','#C1B372','#FFBC42','#D81159']
labels = data['NumberOfMajorSurgeries'].value_counts().index

values = data['NumberOfMajorSurgeries'].value_counts()

# create pie chart

pie_chart = go.Figure(go.Pie(labels = labels, values = values, ))
pie_chart.update_traces(hoverinfo = 'label+value' , textinfo = 'percent', textfont_size = 20, 
                        marker = dict(colors = colors, line = dict( color = '#000000', width=2)))

# Bar Chart

bar_chart = go.Figure(go.Bar(x = labels, y = values, marker_color = colors))

# create subplots

fig = sp.make_subplots( rows = 1, cols = 2, column_width = [0.5,0.5], specs = [[{'type' : 'bar'}, {'type' : 'pie'}]],
                      subplot_titles = ("Bar Chart", "Pie Chart"))

# Add charts to subplots

fig.add_trace(bar_chart.data[0], row=1, col=1)
fig.add_trace(pie_chart.data[0], row=1, col=2)

# Update layout
fig.update_layout(
    showlegend=False,
    title=dict(
        text="Distribution of Major Surgeries",
        font=dict(size=18)
    ),
    xaxis=dict(
        title=dict(
            text="No. of Major Surgeries",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    ),
    yaxis=dict(
        title=dict(
            text="Count",
            font=dict(size=16)
        ),
        tickfont=dict(size=14)
    )
)

# Show subplots
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="9bace89c-8f1a-4955-a441-e11b2fddf598" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("9bace89c-8f1a-4955-a441-e11b2fddf598")) {                    Plotly.newPlot(                        "9bace89c-8f1a-4955-a441-e11b2fddf598",                        [{"marker":{"color":["#006BA6","#C1B372","#FFBC42","#D81159"]},"x":{"dtype":"i1","bdata":"AAECAw=="},"y":{"dtype":"i2","bdata":"3wF0AXcAEAA="},"type":"bar","xaxis":"x","yaxis":"y"},{"hoverinfo":"label+value","labels":{"dtype":"i1","bdata":"AAECAw=="},"marker":{"colors":["#006BA6","#C1B372","#FFBC42","#D81159"],"line":{"color":"#000000","width":2}},"textfont":{"size":20},"textinfo":"percent","values":{"dtype":"i2","bdata":"3wF0AXcAEAA="},"type":"pie","domain":{"x":[0.55,1.0],"y":[0.0,1.0]}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type ...

# %% [markdown]
# ### Distribution of Target Variable

# %%
plt.figure(figsize = (15, 6))

# Histplot
plt.subplot(1,2,1)
sns.histplot(data = data , x = 'PremiumPrice', kde = True, color = '#998DA0')
plt.xlabel('Premium Price')
plt.ylabel('Count')

# Boxplot
plt.subplot(1,2,2)
sns.boxplot(data = data, x = 'PremiumPrice', color = '#998DA0')
plt.xlabel('Premium Price')

plt.suptitle('Distribution of Premium Price')
plt.show()

# %%
#BCA0BC

# %% [markdown]
# ## 📉 Bivariate Analysis

# %% [markdown]
# ### Distribution of premium price in age-category

# %%
plt.figure(figsize = (12,6))
sns.boxplot(data = data , y = 'PremiumPrice', x = 'age_category')
plt.xlabel('Age Category')
plt.ylabel('Premium Price')
plt.title('Distrbution of Premium Price in Age category')
plt.show()

# %% [markdown]
# ### Distribtion of Premium Price in BMI Categroy

# %%
plt.figure(figsize = (12,6))
sns.boxplot(data = data , y = 'PremiumPrice', x = 'BMI_category', palette = pink)
plt.xlabel('BMI Category')
plt.ylabel('Premium Price')
plt.title('Distrbution of Premium Price in BMI category')
plt.show()

# %% [markdown]
# ### Distribution of Premium Price in 'BloodPressureProblems', 'AnyTransplants', 'AnyChronicDiseases', 'KnownAllergies',	'HistoryOfCancerInFamily' and	'NumberOfMajorSurgeries'

# %%
cols = ['BloodPressureProblems', 'AnyTransplants', 'AnyChronicDiseases', 'KnownAllergies', 'HistoryOfCancerInFamily','NumberOfMajorSurgeries']
plt.figure(figsize =(20,12))
for i in range(len(cols)):
    plt.subplot(3,3,i+1)
    sns.violinplot(data = data , x = cols[i], y = 'PremiumPrice', palette =  red[1:])
    plt.xlabel(cols[i], fontsize =14)
    plt.ylabel('Premium Price', fontsize = 14)
plt.tight_layout()
plt.show()

# %%
custom_palette(red)

# %% [markdown]
# ### Heatmap and Correlation

# %%
plt.figure(figsize=(15,12))
sns.heatmap(df.corr(),annot=True,cmap='rocket',fmt='.2f')
plt.show()

# %% [markdown]
# # ⚒ Data Preprocessing

# %% [markdown]
# ## 👯 Checking Duplicates

# %%
print(df[df.duplicated()])
# Out:
# Empty DataFrame
# Columns: [Age, Diabetes, BloodPressureProblems, AnyTransplants, AnyChronicDiseases, Height, Weight, KnownAllergies, HistoryOfCancerInFamily, NumberOfMajorSurgeries, PremiumPrice, BMI]
# Index: []

# %% [markdown]
# ## 👾 Checking Outliers

# %%
df.boxplot(rot=45, figsize=(30,15), fontsize = 25)
plt.show()

# %% [markdown]
# **Inference**
#
# The dataset contains very few outliers, and given its relatively small size, we have chosen not to remove any outliers to preserve the integrity of the data.

# %% [markdown]
# # 🛠️ Data Preparation

# %% [markdown]
# ## ✂️ Splitting data into train and test data

# %%
X = df.drop(columns=['PremiumPrice'])
y = df['PremiumPrice']

# %%
X
# Out:
#      Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0     45         0                      0               0                   0
# 1     60         1                      0               0                   0
# 2     36         1                      1               0                   0
# 3     52         1                      1               0                   1
# 4     38         0                      0               0                   1
# ..   ...       ...                    ...             ...                 ...
# 981   18         0                      0               0                   0
# 982   64         1                      1               0                   0
# 983   56         0                      1               0                   0
# 984   47         1                      1               0                   0
# 985   21         0                      0               0                   0
#
#      Height  Weight  KnownAllergies  HistoryOfCancerInFamily  \
# 0       155      57               0                        0
# 1       180      73               0                        0
# 2       158      59               0                        0
# 3       183      93               0                        0
# 4       166      88               0                        0
# ..      ...     ...             ...                      ...
# 981     169      67               0                        0
# 982     153      70               0                        0
# 983     155      71               0                        0
# 984     158      73               1                        0
# 985     158      75               1                        0
#
#      NumberOfMajorSurgeries        BMI
# 0                         0  23.725286
# 1                         0  22.530864
# 2                         1  23.634033
# 3                         2  27.770313
# 4                         1  31.934969
# ..                      ...        ...
# 981                       0  23.458562
# 982                       3  29.903029
# 983                       1  29.552549
# 984                       1  29.242109
# 985                       1  30.043262
#
# [986 rows x 11 columns]

# %%
y
# Out:
# 0      25000
# 1      29000
# 2      23000
# 3      28000
# 4      23000
#        ...
# 981    15000
# 982    28000
# 983    29000
# 984    39000
# 985    15000
# Name: PremiumPrice, Length: 986, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train,y_test = train_test_split(X,y, random_state = 42, test_size = 0.25)

# %%
X_train.shape
# Out:
# (739, 11)

# %%
X_test.shape
# Out:
# (247, 11)

# %% [markdown]
# ## 📏 Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = pd.DataFrame(scaler.fit_transform(X_train),columns = X_train.columns)
X_test_scaled = pd.DataFrame(scaler.fit_transform(X_test), columns = X_test.columns)

# %%
X_train_scaled
# Out:
#           Age  Diabetes  BloodPressureProblems  AnyTransplants  \
# 0    0.026630 -0.854798              -0.915592       -0.236039
# 1   -0.545865  1.169867              -0.915592       -0.236039
# 2   -0.903675  1.169867              -0.915592       -0.236039
# 3   -0.760551 -0.854798              -0.915592       -0.236039
# 4    0.312878  1.169867              -0.915592       -0.236039
# ..        ...       ...                    ...             ...
# 734  1.314745 -0.854798              -0.915592       -0.236039
# 735  0.312878 -0.854798               1.092190       -0.236039
# 736  1.386307  1.169867              -0.915592       -0.236039
# 737 -0.331180  1.169867              -0.915592       -0.236039
# 738  1.243183  1.169867               1.092190       -0.236039
#
#      AnyChronicDiseases    Height    Weight  KnownAllergies  \
# 0             -0.470625  1.677017  0.492592       -0.536150
# 1             -0.470625  0.974059 -0.688857       -0.536150
# 2             -0.470625 -1.235239 -0.202378       -0.536150
# 3             -0.470625  0.371523 -1.383828       -0.536150
# 4             -0.470625 -1.636929 -1.453325       -0.536150
# ..                  ...       ...       ...             ...
# 734           -0.470625 -1.335662 -1.314331       -0.536150
# 735            2.124835 -0.231013 -1.314331       -0.536150
# 736           -0.470625 -0.733126 -0.758354       -0.536150
# 737           -0.470625  0.572368 -0.966846        1.865151
# 738           -0.470625 -0.833548  1.048568       -0.536150
#
#      HistoryOfCancerInFamily  NumberOfMajorSurgeries       BMI
# 0                  -0.350857                0.447422 -0.486226
# 1                  -0.350857               -0.880469 -1.063956
# 2                  -0.350857               -0.880469  0.511056
# 3                  -0.350857               -0.880469 -1.383531
# 4                  -0.350857               -0.880469 -0.538135
# ..                       ...                     ...       ...
# 734                -0.350857               -0.880469 -0.554582
# 735                -0.350857                0.447422 -1.080669
# 736                -0.350857                3.103205 -0.330019
# 737                 2.850168                0.447422 -1.121397
# 738                 2.850168                0.447422  1.451486
#
# [739 rows x 11 columns]

# %%
X_test_scaled
# Out:
#           Age  Diabetes  BloodPressureProblems  AnyTransplants  \
# 0    0.568652 -0.838718              -1.012220       -0.263181
# 1   -0.222858 -0.838718              -1.012220       -0.263181
# 2    1.647983  1.192296               0.987927       -0.263181
# 3   -0.942412 -0.838718              -1.012220       -0.263181
# 4    0.424741  1.192296               0.987927       -0.263181
# ..        ...       ...                    ...             ...
# 242  0.928429 -0.838718               0.987927       -0.263181
# 243 -1.086323 -0.838718               0.987927       -0.263181
# 244 -0.222858  1.192296               0.987927       -0.263181
# 245 -1.302189  1.192296              -1.012220       -0.263181
# 246  0.928429 -0.838718              -1.012220       -0.263181
#
#      AnyChronicDiseases    Height    Weight  KnownAllergies  \
# 0             -0.465563 -0.270060  0.500480        2.062842
# 1              2.147938  1.638521 -0.293335        2.062842
# 2             -0.465563 -0.270060  0.716975       -0.484768
# 3             -0.465563  1.065947 -0.509830       -0.484768
# 4             -0.465563  0.302514  0.500480        2.062842
# ..                  ...       ...       ...             ...
# 242           -0.465563  0.397943  1.005635        2.062842
# 243           -0.465563 -0.842635  3.098421        2.062842
# 244           -0.465563  0.111656  0.067490       -0.484768
# 245           -0.465563  0.207085  0.716975       -0.484768
# 246           -0.465563 -1.033493 -0.293335       -0.484768
#
#      HistoryOfCancerInFamily  NumberOfMajorSurgeries       BMI
# 0                   2.461126                0.434670  0.549467
# 1                   2.461126                0.434670 -1.076196
# 2                  -0.406318               -0.924361  0.737546
# 3                   2.461126                0.434670 -0.987856
# 4                  -0.406318               -0.924361  0.186393
# ..                       ...                     ...       ...
# 242                -0.406318                0.434670  0.533402
# 243                 2.461126                0.434670  3.384906
# 244                -0.406318               -0.924361 -0.055431
# 245                -0.406318                0.434670  0.421424
# 246                -0.406318               -0.924361  0.338132
#
# [247 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      986 non-null    int64
#  1   Diabetes                 986 non-null    int64
#  2   BloodPressureProblems    986 non-null    int64
#  3   AnyTransplants           986 non-null    int64
#  4   AnyChronicDiseases       986 non-null    int64
#  5   Height                   986 non-null    int64
#  6   Weight                   986 non-null    int64
#  7   KnownAllergies           986 non-null    int64
#  8   HistoryOfCancerInFamily  986 non-null    int64
#  9   NumberOfMajorSurgeries   986 non-null    int64
#  10  PremiumPrice             986 non-null    int64
#  11  BMI                      986 non-null    float64
# dtypes: float64(1), int64(11)
# memory usage: 92.6 KB

# %% [markdown]
# # 🪖 Model Training and Evaluation

# %% [markdown]
# ## 💡 Training LightGBM model using optuna hyperparameter tuning and K-Fold cross validation

# %%
# !pip install mlflow
# Out:
# Requirement already satisfied: mlflow in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (3.9.0)
# Requirement already satisfied: mlflow-skinny==3.9.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (3.9.0)
# Requirement already satisfied: mlflow-tracing==3.9.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (3.9.0)
# Requirement already satisfied: Flask-CORS<7 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (6.0.2)
# Requirement already satisfied: Flask<4 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (3.1.2)
# Requirement already satisfied: alembic!=1.10.0,<2 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (1.18.3)
# Requirement already satisfied: cryptography<47,>=43.0.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (46.0.4)
# Requirement already satisfied: docker<8,>=4.0.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: graphene<4 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (3.4.3)
# Requirement already satisfied: gunicorn<24 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (23.0.0)
# Requirement already satisfied: huey<3,>=2.5.4 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (2.6.0)
# Requirement already satisfied: matplotlib<4 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (3.10.8)
# Requirement already satisfied: numpy<3 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (2.4.2)
# Requirement already satisfied: pandas<3 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (2.3.3)
# Requirement already satisfied: pyarrow<23,>=4.0.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (22.0.0)
# Requirement already satisfied: scikit-learn<2 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (1.8.0)
# Requirement already satisfied: scipy<2 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (1.17.0)
# Requirement already satisfied: skops<1 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (0.13.0)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow) (2.0.46)
# Requirement already satisfied: cachetools<7,>=5.0.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (6.2.6)
# Requirement already satisfied: click<9,>=7.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (8.3.1)
# Requirement already satisfied: cloudpickle<4 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (3.1.2)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (0.85.0)
# Requirement already satisfied: fastapi<1 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (0.128.4)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (3.1.46)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (8.7.1)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (1.39.1)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (1.39.1)
# Requirement already satisfied: packaging<26 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (25.0)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (6.33.5)
# Requirement already satisfied: pydantic<3,>=2.0.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (2.12.5)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (1.2.1)
# Requirement already satisfied: pyyaml<7,>=5.1 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (6.0.3)
# Requirement already satisfied: requests<3,>=2.17.3 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (2.32.5)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (0.5.5)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (4.15.0)
# Requirement already satisfied: uvicorn<1 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.9.0->mlflow) (0.40.0)
# Requirement already satisfied: Mako in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.10)
# Requirement already satisfied: cffi>=2.0.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from cryptography<47,>=43.0.0->mlflow) (2.0.0)
# Requirement already satisfied: google-auth~=2.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.9.0->mlflow) (2.48.0)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from docker<8,>=4.0.0->mlflow) (2.6.3)
# Requirement already satisfied: starlette<1.0.0,>=0.40.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from fastapi<1->mlflow-skinny==3.9.0->mlflow) (0.52.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from fastapi<1->mlflow-skinny==3.9.0->mlflow) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from fastapi<1->mlflow-skinny==3.9.0->mlflow) (0.0.4)
# Requirement already satisfied: blinker>=1.9.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from Flask<4->mlflow) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from Flask<4->mlflow) (3.1.5)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.9.0->mlflow) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.9.0->mlflow) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.9.0->mlflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.9.0->mlflow) (4.9.1)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from graphene<4->mlflow) (3.2.7)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: zipp>=3.20 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.9.0->mlflow) (3.23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from matplotlib<4->mlflow) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from matplotlib<4->mlflow) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from matplotlib<4->mlflow) (1.4.9)
# Requirement already satisfied: pillow>=8 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from matplotlib<4->mlflow) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from matplotlib<4->mlflow) (3.3.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.9.0->mlflow) (0.60b1)
# Requirement already satisfied: pytz>=2020.1 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from pandas<3->mlflow) (2025.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.9.0->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.9.0->mlflow) (2.41.5)
# Requirement already satisfied: six>=1.5 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.9.0->mlflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.9.0->mlflow) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.9.0->mlflow) (2026.1.4)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.9.0->mlflow) (0.6.2)
# Requirement already satisfied: joblib>=1.3.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from scikit-learn<2->mlflow) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from scikit-learn<2->mlflow) (3.6.0)
# Requirement already satisfied: prettytable>=3.9 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from skops<1->mlflow) (3.17.0)
# Requirement already satisfied: anyio<5,>=3.6.2 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from starlette<1.0.0,>=0.40.0->fastapi<1->mlflow-skinny==3.9.0->mlflow) (4.12.1)
# Requirement already satisfied: h11>=0.8 in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from uvicorn<1->mlflow-skinny==3.9.0->mlflow) (0.16.0)
# Requirement already satisfied: pycparser in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from cffi>=2.0.0->cryptography<47,>=43.0.0->mlflow) (3.0)
# Requirement already satisfied: wcwidth in /Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages (from prettytable>=3.9->skops<1->mlflow) (0.6.0)

# %%
import optuna
import mlflow # For experimental tracking
import lightgbm as lgb
from lightgbm import early_stopping
from sklearn.metrics import  root_mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import KFold

# %%
1e-1
# Out:
# 0.1

# %%
import os
mlflow.set_tracking_uri(f"file://{os.path.abspath('mlruns')}")
mlflow.set_experiment("Insurance Premium Prediction Model Experimental Tracking")
# Out:
# <Experiment: artifact_location=('file:///Users/rahulhipparkar/Desktop/MS Data Science/Projects/Machine '
#  'Learning/Insurance Premium '
#  'Prediction/Insurance-Premium-Prediction/notebooks/mlruns/880565254641232423'), creation_time=1770486336797, experiment_id='880565254641232423', last_update_time=1770486336797, lifecycle_stage='active', name='Insurance Premium Prediction Model Experimental Tracking', tags={}>

# %%
def objective(trial):
    with mlflow.start_run(nested = True, run_name = f"trial {trial.number}") as child_run:
        params = {
            'objective':'regression',
            'metric':'rmse',
            'n_estimators': trial.suggest_int('n_estimators',500,2000),
            'boosting_type': trial.suggest_categorical('boosting',['gbdt','dart']),
            'max_depth':trial.suggest_int('max_depth',3,10),
            'num_leaves': trial.suggest_int('num_leaves',4,128),
            'learning_rate':trial.suggest_loguniform('learning_rate',1e-4,1e-1),
            'feature_fraction':trial.suggest_uniform('feature_fraction',0.6,1.0),
            'bagging_fraction':trial.suggest_uniform('bagging_fraction',0.6,0.9),
            'bagging_freq':trial.suggest_int('bagging_freq',1,20),
            'min_data_in_leaf':trial.suggest_int('min_data_in_leaf', 5,30),
            'reg_alpha':trial.suggest_float('reg_alpha',1e-8,10.0,log = True),
            'reg_lambda':trial.suggest_float('reg_lambda',1e-8,10.0,log = True),
            #'device_type':'gpu',
            'random_state':42,
            'verbose':-1
            }
        # log model params
        mlflow.log_params(params)
        model = lgb.LGBMRegressor(**params)
        scores = []
        kf = KFold(n_splits = 5, shuffle = True, random_state = 42)
        for train_idx,val_idx in kf.split(X_train):
            X_tr, X_val = X_train.iloc[train_idx], X_train.iloc[val_idx]
            y_tr, y_val = y_train.iloc[train_idx], y_train.iloc[val_idx]
            model.fit(X_tr,y_tr, eval_set = [(X_val, y_val)], callbacks=[early_stopping(stopping_rounds=100, verbose=False)])
            y_pred = model.predict(X_val)
            rmse = root_mean_squared_error(y_val,y_pred)
            scores.append(rmse)
        # log tuning metric RMSE
        mlflow.log_metrics({"RMSE":np.mean(scores)})
        # Log the model file
        mlflow.sklearn.log_model(model, name="model")
        # Make it easy to retrieve the best-performing child run later
        trial.set_user_attr("run_id", child_run.info.run_id)
    
        return float(np.mean(scores))

# %%
with mlflow.start_run(run_name = 'study') as run:
    
    study = optuna.create_study(direction='minimize')
    study.optimize(objective, n_trials = 50, show_progress_bar = True)
    # log model's best params, lowest rmse score and its id
    mlflow.log_params(study.best_params)
    mlflow.log_metrics({"best_error": study.best_value})
    if best_run_id := study.best_trial.user_attrs.get("run_id"):
        mlflow.log_param("best_child_run_id", best_run_id)
# Out:
# [I 2026-02-07 10:52:24,611] A new study created in memory with name: no-name-1cf9c318-93a8-4469-bc30-48f41e794ea7
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2026-02-07 10:52:28,539] Trial 0 finished with value: 5454.487173821354 and parameters: {'n_estimators': 813, 'boosting': 'gbdt', 'max_depth': 10, 'num_leaves': 93, 'learning_rate': 0.0002919179359908484, 'feature_fraction': 0.7823375288096366, 'bagging_fraction': 0.6062039552277416, 'bagging_freq': 11, 'min_data_in_leaf': 24, 'reg_alpha': 0.0009230122364363412, 'reg_lambda': 8.849404891389027e-05}. Best is trial 0 with value: 5454.487173821354.
# [I 2026-02-07 10:52:32,148] Trial 1 finished with value: 3023.0869322390076 and parameters: {'n_estimators': 564, 'boosting': 'gbdt', 'max_depth': 7, 'num_leaves': 48, 'learning_rate': 0.008703689090901492, 'feature_fraction': 0.8332637277946146, 'bagging_fraction': 0.7922864862948075, 'bagging_freq': 2, 'min_data_in_leaf': 9, 'reg_alpha': 4.128953805621567e-06, 'reg_lambda': 8.332577390314775e-05}. Best is trial 1 with value: 3023.0869322390076.
# [I 2026-02-07 10:52:42,670] Trial 2 finished with value: 8655.828354546476 and parameters: {'n_estimators': 1730, 'boosting': 'dart', 'max_depth': 10, 'num_leaves': 128, 'learning_rate': 0.0026191233851777336, 'feature_fraction': 0.8079080391591258, 'bagging_fraction': 0.6099213787127138, 'bagging_freq': 15, 'min_data_in_leaf': 29, 'reg_alpha': 7.007399498534713e-08, 'reg_lambda': 7.333439414427895e-08}. Best is trial 1 with value: 3023.0869322390076.
# [I 2026-02-07 10:52:46,399] Trial 3 finished with value: 17347.08996388104 and parameters: {'n_estimators': 766, 'boosting': 'dart', 'max_depth': 3, 'num_leaves': 118, 'learning_rate': 0.0011698526941403943, 'feature_fraction': 0.7360145404903765, 'bagging_fraction': 0.8855438678914401, 'bagging_freq': 20, 'min_data_in_leaf': 5, 'reg_alpha': 0.0004780593793992462, 'reg_lambda': 0.15012192431251062}. Best is trial 1 with value: 3023.0869322390076.
# [I 2026-02-07 10:52:59,149] Trial 4 finished with value: 3763.419879982769 and parameters: {'n_estimators': 1806, 'boosting': 'dart', 'max_depth': 6, 'num_leaves': 128, 'learning_rate': 0.012439874283988687, 'feature_fraction': 0.7681209743891015, 'bagging_fraction': 0.6602066698571011, 'bagging_freq': 8, 'min_data_in_leaf': 19, 'reg_alpha': 0.00042433031108013685, 'reg_lambda': 0.00139661483191224}. Best is trial 1 with value: 3023.0869322390076.
# [I 2026-02-07 10:53:15,370] Trial 5 finished with value: 13642.832817407409 and parameters: {'n_estimators': 1511, 'boosting': 'dart', 'max_depth': 10, 'num_leaves': 77, 'learning_rate': 0.0014000618550702854, 'feature_fraction': 0.8680427774791316, 'bagging_fraction': 0.7998506241508035, 'bagging_freq': 10, 'min_data_in_leaf': 10, 'reg_alpha': 0.00018606675149126167, 'reg_lambda': 1.1215045441131237e-06}. Best is trial 1 with value: 3023.0869322390076.
# [I 2026-02-07 10:53:20,820] Trial 6 finished with value: 5699.699097648928 and parameters: {'n_estimators': 1143, 'boosting': 'dart', 'max_depth': 3, 'num_leaves': 45, 'learning_rate': 0.00759361995808426, 'feature_fraction': 0.821038361604864, 'bagging_fraction': 0.7428227439899856, 'bagging_freq': 16, 'min_data_in_leaf': 23, 'reg_alpha': 0.03910881973234056, 'reg_lambda': 9.665810731354097e-08}. Best is trial 1 with value: 3023.0869322390076.
# [I 2026-02-07 10:53:23,673] Trial 7 finished with value: 2994.651990672818 and parameters: {'n_estimators': 1589, 'boosting': 'gbdt', 'max_depth': 9, 'num_leaves': 60, 'learning_rate': 0.009519133936840306, 'feature_fraction': 0.8765516203976041, 'bagging_fraction': 0.6283628458201901, 'bagging_freq': 1, 'min_data_in_leaf': 9, 'reg_alpha': 0.000415941043303361, 'reg_lambda': 4.722971751914903e-05}. Best is trial 7 with value: 2994.651990672818.
# [I 2026-02-07 10:53:26,940] Trial 8 finished with value: 3239.2672700912444 and parameters: {'n_estimators': 1721, 'boosting': 'gbdt', 'max_depth': 4, 'num_leaves': 70, 'learning_rate': 0.002904023459933294, 'feature_fraction': 0.6112667345661486, 'bagging_fraction': 0.8186316120933599, 'bagging_freq': 4, 'min_data_in_leaf': 19, 'reg_alpha': 0.004798920867732269, 'reg_lambda': 1.90479945538471e-06}. Best is trial 7 with value: 2994.651990672818.
# [I 2026-02-07 10:53:29,409] Trial 9 finished with value: 3118.957529626666 and parameters: {'n_estimators': 1067, 'boosting': 'gbdt', 'max_depth': 10, 'num_leaves': 25, 'learning_rate': 0.015463767779490763, 'feature_fraction': 0.7594437748715402, 'bagging_fraction': 0.880249048713574, 'bagging_freq': 4, 'min_data_in_leaf': 19, 'reg_alpha': 0.0035748996681920866, 'reg_lambda': 0.0007354650838950191}. Best is trial 7 with value: 2994.651990672818.
# [I 2026-02-07 10:53:31,069] Trial 10 finished with value: 3165.740401768623 and parameters: {'n_estimators': 2000, 'boosting': 'gbdt', 'max_depth': 8, 'num_leaves': 4, 'learning_rate': 0.06297445138145152, 'feature_fraction': 0.9768948333765677, 'bagging_fraction': 0.6958967211611063, 'bagging_freq': 1, 'min_data_in_leaf': 11, 'reg_alpha': 3.2506199737852235, 'reg_lambda': 5.222264145338112}. Best is trial 7 with value: 2994.651990672818.
# [I 2026-02-07 10:53:32,978] Trial 11 finished with value: 2962.56706917035 and parameters: {'n_estimators': 561, 'boosting': 'gbdt', 'max_depth': 7, 'num_leaves': 51, 'learning_rate': 0.052568774527502374, 'feature_fraction': 0.9147989090613943, 'bagging_fraction': 0.7664853406830894, 'bagging_freq': 2, 'min_data_in_leaf': 11, 'reg_alpha': 1.9428103263878545e-06, 'reg_lambda': 3.887115412283109e-05}. Best is trial 11 with value: 2962.56706917035.
# [I 2026-02-07 10:53:34,941] Trial 12 finished with value: 2981.41200415203 and parameters: {'n_estimators': 1393, 'boosting': 'gbdt', 'max_depth': 8, 'num_leaves': 48, 'learning_rate': 0.08579729255235802, 'feature_fraction': 0.9265636867356096, 'bagging_fraction': 0.7317065716953745, 'bagging_freq': 6, 'min_data_in_leaf': 14, 'reg_alpha': 2.445357054059428e-06, 'reg_lambda': 8.299347631666324e-06}. Best is trial 11 with value: 2962.56706917035.
# [I 2026-02-07 10:53:36,892] Trial 13 finished with value: 2985.6021196274814 and parameters: {'n_estimators': 1372, 'boosting': 'gbdt', 'max_depth': 6, 'num_leaves': 31, 'learning_rate': 0.09862536670135397, 'feature_fraction': 0.9745431590979774, 'bagging_fraction': 0.7348091751110539, 'bagging_freq': 6, 'min_data_in_leaf': 14, 'reg_alpha': 6.630588871108925e-07, 'reg_lambda': 0.020432982886816147}. Best is trial 11 with value: 2962.56706917035.
# [I 2026-02-07 10:53:38,807] Trial 14 finished with value: 3018.1771850542777 and parameters: {'n_estimators': 1267, 'boosting': 'gbdt', 'max_depth': 7, 'num_leaves': 87, 'learning_rate': 0.04224688569096105, 'feature_fraction': 0.9240416890182603, 'bagging_fraction': 0.6988049847173888, 'bagging_freq': 6, 'min_data_in_leaf': 14, 'reg_alpha': 5.88054798133338e-06, 'reg_lambda': 3.335470939399685e-06}. Best is trial 11 with value: 2962.56706917035.
# [I 2026-02-07 10:53:40,694] Trial 15 finished with value: 2986.336407978605 and parameters: {'n_estimators': 935, 'boosting': 'gbdt', 'max_depth': 5, 'num_leaves': 26, 'learning_rate': 0.03169065340708248, 'feature_fraction': 0.9114408133079105, 'bagging_fraction': 0.7747301179610904, 'bagging_freq': 5, 'min_data_in_leaf': 5, 'reg_alpha': 2.7392363945671805e-08, 'reg_lambda': 8.169922892055213e-06}. Best is trial 11 with value: 2962.56706917035.
# [I 2026-02-07 10:53:42,727] Trial 16 finished with value: 2962.1066687702305 and parameters: {'n_estimators': 530, 'boosting': 'gbdt', 'max_depth': 8, 'num_leaves': 53, 'learning_rate': 0.0276503754638601, 'feature_fraction': 0.9995588302028722, 'bagging_fraction': 0.8495792072816598, 'bagging_freq': 9, 'min_data_in_leaf': 14, 'reg_alpha': 1.169115886192371e-05, 'reg_lambda': 1.2680088916845095e-08}. Best is trial 16 with value: 2962.1066687702305.
# [I 2026-02-07 10:53:44,715] Trial 17 finished with value: 2985.477850761864 and parameters: {'n_estimators': 521, 'boosting': 'gbdt', 'max_depth': 8, 'num_leaves': 100, 'learning_rate': 0.026471163719008192, 'feature_fraction': 0.9967122229278014, 'bagging_fraction': 0.83399203814869, 'bagging_freq': 13, 'min_data_in_leaf': 16, 'reg_alpha': 3.048707708425787e-07, 'reg_lambda': 1.5464065150527723e-08}. Best is trial 16 with value: 2962.1066687702305.
# [I 2026-02-07 10:53:47,093] Trial 18 finished with value: 5820.8568498504055 and parameters: {'n_estimators': 705, 'boosting': 'gbdt', 'max_depth': 5, 'num_leaves': 61, 'learning_rate': 0.00014953955070082115, 'feature_fraction': 0.6970008404461341, 'bagging_fraction': 0.8536651256141586, 'bagging_freq': 9, 'min_data_in_leaf': 23, 'reg_alpha': 1.5303589217070675e-05, 'reg_lambda': 0.015766226881413516}. Best is trial 16 with value: 2962.1066687702305.
# [I 2026-02-07 10:53:49,009] Trial 19 finished with value: 3006.825671073928 and parameters: {'n_estimators': 639, 'boosting': 'gbdt', 'max_depth': 9, 'num_leaves': 11, 'learning_rate': 0.025605083185727556, 'feature_fraction': 0.9475275736964516, 'bagging_fraction': 0.7681142658595564, 'bagging_freq': 20, 'min_data_in_leaf': 12, 'reg_alpha': 2.938329316084434e-05, 'reg_lambda': 2.4430063160681064e-07}. Best is trial 16 with value: 2962.1066687702305.
# [I 2026-02-07 10:53:52,221] Trial 20 finished with value: 2978.7683016174897 and parameters: {'n_estimators': 899, 'boosting': 'gbdt', 'max_depth': 7, 'num_leaves': 43, 'learning_rate': 0.005976089150466459, 'feature_fraction': 0.8701112158376467, 'bagging_fraction': 0.8561628799411021, 'bagging_freq': 12, 'min_data_in_leaf': 7, 'reg_alpha': 4.9638763439474603e-05, 'reg_lambda': 2.929444245284591}. Best is trial 16 with value: 2962.1066687702305.
# [I 2026-02-07 10:53:54,430] Trial 21 finished with value: 2972.256854590208 and parameters: {'n_estimators': 933, 'boosting': 'gbdt', 'max_depth': 7, 'num_leaves': 38, 'learning_rate': 0.01823314096748407, 'feature_fraction': 0.8796129252614232, 'bagging_fraction': 0.8578866570618148, 'bagging_freq': 12, 'min_data_in_leaf': 8, 'reg_alpha': 5.255260407752565e-05, 'reg_lambda': 2.134870510630635}. Best is trial 16 with value: 2962.1066687702305.
# [I 2026-02-07 10:53:56,302] Trial 22 finished with value: 2959.2430107688706 and parameters: {'n_estimators': 515, 'boosting': 'gbdt', 'max_depth': 6, 'num_leaves': 56, 'learning_rate': 0.046979823101018725, 'feature_fraction': 0.8920460767248083, 'bagging_fraction': 0.8969245248039837, 'bagging_freq': 14, 'min_data_in_leaf': 7, 'reg_alpha': 1.2092807615106827e-06, 'reg_lambda': 0.3182641237631228}. Best is trial 22 with value: 2959.2430107688706.
# [I 2026-02-07 10:53:58,052] Trial 23 finished with value: 2997.079291059041 and parameters: {'n_estimators': 525, 'boosting': 'gbdt', 'max_depth': 5, 'num_leaves': 57, 'learning_rate': 0.05013612938217686, 'feature_fraction': 0.9566255417074981, 'bagging_fraction': 0.8911836313226222, 'bagging_freq': 17, 'min_data_in_leaf': 12, 'reg_alpha': 2.356700118745803e-07, 'reg_lambda': 0.00933376797170604}. Best is trial 22 with value: 2959.2430107688706.
# [I 2026-02-07 10:53:59,882] Trial 24 finished with value: 2972.622718964694 and parameters: {'n_estimators': 673, 'boosting': 'gbdt', 'max_depth': 6, 'num_leaves': 77, 'learning_rate': 0.05132236950180414, 'feature_fraction': 0.9964462319255272, 'bagging_fraction': 0.8271942170682471, 'bagging_freq': 15, 'min_data_in_leaf': 7, 'reg_alpha': 1.2018647385146541e-06, 'reg_lambda': 0.8410015370683241}. Best is trial 22 with value: 2959.2430107688706.
# [I 2026-02-07 10:54:02,340] Trial 25 finished with value: 3147.701472723179 and parameters: {'n_estimators': 503, 'boosting': 'gbdt', 'max_depth': 8, 'num_leaves': 57, 'learning_rate': 0.0046824923949401465, 'feature_fraction': 0.9074513557864202, 'bagging_fraction': 0.8966243397812983, 'bagging_freq': 18, 'min_data_in_leaf': 16, 'reg_alpha': 9.262457177545066e-08, 'reg_lambda': 0.06938360426155847}. Best is trial 22 with value: 2959.2430107688706.
# [I 2026-02-07 10:54:10,209] Trial 26 finished with value: 3359.9147531871577 and parameters: {'n_estimators': 814, 'boosting': 'dart', 'max_depth': 9, 'num_leaves': 70, 'learning_rate': 0.02304182947407212, 'feature_fraction': 0.8415158537122961, 'bagging_fraction': 0.8692440583740545, 'bagging_freq': 8, 'min_data_in_leaf': 12, 'reg_alpha': 1.2462447840443815e-08, 'reg_lambda': 0.0015746644810851864}. Best is trial 22 with value: 2959.2430107688706.
# [I 2026-02-07 10:54:12,063] Trial 27 finished with value: 3019.207165104665 and parameters: {'n_estimators': 648, 'boosting': 'gbdt', 'max_depth': 6, 'num_leaves': 19, 'learning_rate': 0.038941687451521316, 'feature_fraction': 0.9323196829943269, 'bagging_fraction': 0.8356529876446628, 'bagging_freq': 14, 'min_data_in_leaf': 16, 'reg_alpha': 9.674215779363528e-06, 'reg_lambda': 0.27312418100106406}. Best is trial 22 with value: 2959.2430107688706.
# [I 2026-02-07 10:54:13,741] Trial 28 finished with value: 3034.534091192373 and parameters: {'n_estimators': 1072, 'boosting': 'gbdt', 'max_depth': 4, 'num_leaves': 37, 'learning_rate': 0.07263089832954418, 'feature_fraction': 0.8918428634859139, 'bagging_fraction': 0.8036440036686802, 'bagging_freq': 3, 'min_data_in_leaf': 6, 'reg_alpha': 1.1663037068795248e-06, 'reg_lambda': 1.2673224353141314e-08}. Best is trial 22 with value: 2959.2430107688706.
# [I 2026-02-07 10:54:16,976] Trial 29 finished with value: 3941.5096930326044 and parameters: {'n_estimators': 787, 'boosting': 'gbdt', 'max_depth': 7, 'num_leaves': 93, 'learning_rate': 0.0009682006544766165, 'feature_fraction': 0.9578119479000895, 'bagging_fraction': 0.7061713397520928, 'bagging_freq': 11, 'min_data_in_leaf': 10, 'reg_alpha': 0.22368438111735142, 'reg_lambda': 1.6231836157224874e-05}. Best is trial 22 with value: 2959.2430107688706.
# [I 2026-02-07 10:54:19,752] Trial 30 finished with value: 5070.928302860112 and parameters: {'n_estimators': 603, 'boosting': 'gbdt', 'max_depth': 8, 'num_leaves': 53, 'learning_rate': 0.0007205348392054234, 'feature_fraction': 0.6714027933729918, 'bagging_fraction': 0.7655978251368235, 'bagging_freq': 9, 'min_data_in_leaf': 13, 'reg_alpha': 2.3265568347361292e-07, 'reg_lambda': 0.0004204220254966407}. Best is trial 22 with value: 2959.2430107688706.
# [I 2026-02-07 10:54:22,120] Trial 31 finished with value: 2990.034180011676 and parameters: {'n_estimators': 906, 'boosting': 'gbdt', 'max_depth': 7, 'num_leaves': 33, 'learning_rate': 0.017275652226637562, 'feature_fraction': 0.8536959282485698, 'bagging_fraction': 0.8568088827031982, 'bagging_freq': 12, 'min_data_in_leaf': 8, 'reg_alpha': 7.736235386578885e-05, 'reg_lambda': 0.8753762680137787}. Best is trial 22 with value: 2959.2430107688706.
# [I 2026-02-07 10:54:24,180] Trial 32 finished with value: 2985.8453522924347 and parameters: {'n_estimators': 722, 'boosting': 'gbdt', 'max_depth': 6, 'num_leaves': 37, 'learning_rate': 0.01819828185888377, 'feature_fraction': 0.896931563284351, 'bagging_fraction': 0.8615050050171743, 'bagging_freq': 13, 'min_data_in_leaf': 10, 'reg_alpha': 6.558321703688701e-06, 'reg_lambda': 6.887086932662296}. Best is trial 22 with value: 2959.2430107688706.
# [I 2026-02-07 10:54:26,731] Trial 33 finished with value: 2998.803523358872 and parameters: {'n_estimators': 856, 'boosting': 'gbdt', 'max_depth': 7, 'num_leaves': 49, 'learning_rate': 0.011569773814444923, 'feature_fraction': 0.7864839563305904, 'bagging_fraction': 0.8991590469535791, 'bagging_freq': 14, 'min_data_in_leaf': 7, 'reg_alpha': 0.00010050571439092757, 'reg_lambda': 9.279381605634888e-05}. Best is trial 22 with value: 2959.2430107688706.
# [I 2026-02-07 10:54:28,699] Trial 34 finished with value: 3001.957075282768 and parameters: {'n_estimators': 994, 'boosting': 'gbdt', 'max_depth': 7, 'num_leaves': 41, 'learning_rate': 0.037863131623367366, 'feature_fraction': 0.8283383070686694, 'bagging_fraction': 0.8397667371139163, 'bagging_freq': 18, 'min_data_in_leaf': 9, 'reg_alpha': 0.0015868699143331481, 'reg_lambda': 0.9397813100400214}. Best is trial 22 with value: 2959.2430107688706.
# [I 2026-02-07 10:54:32,623] Trial 35 finished with value: 12436.486046038142 and parameters: {'n_estimators': 594, 'boosting': 'dart', 'max_depth': 9, 'num_leaves': 65, 'learning_rate': 0.004954902139204143, 'feature_fraction': 0.8095260083175895, 'bagging_fraction': 0.8131264605507608, 'bagging_freq': 10, 'min_data_in_leaf': 28, 'reg_alpha': 3.27195721258865e-06, 'reg_lambda': 0.10428227761073605}. Best is trial 22 with value: 2959.2430107688706.
# [I 2026-02-07 10:54:35,096] Trial 36 finished with value: 3061.0048624910623 and parameters: {'n_estimators': 750, 'boosting': 'gbdt', 'max_depth': 8, 'num_leaves': 77, 'learning_rate': 0.06067053312927536, 'feature_fraction': 0.8810860269230877, 'bagging_fraction': 0.7837857238327404, 'bagging_freq': 12, 'min_data_in_leaf': 5, 'reg_alpha': 1.7552174910231786e-05, 'reg_lambda': 2.8603187330928555e-07}. Best is trial 22 with value: 2959.2430107688706.
# [I 2026-02-07 10:54:40,507] Trial 37 finished with value: 5690.177550038834 and parameters: {'n_estimators': 576, 'boosting': 'dart', 'max_depth': 6, 'num_leaves': 51, 'learning_rate': 0.017469374455148224, 'feature_fraction': 0.8455948052558987, 'bagging_fraction': 0.8794489393561277, 'bagging_freq': 8, 'min_data_in_leaf': 8, 'reg_alpha': 1.59999135605236e-06, 'reg_lambda': 0.005812635698512445}. Best is trial 22 with value: 2959.2430107688706.
# [I 2026-02-07 10:54:42,389] Trial 38 finished with value: 3015.707611569447 and parameters: {'n_estimators': 1161, 'boosting': 'gbdt', 'max_depth': 5, 'num_leaves': 17, 'learning_rate': 0.02885624951235183, 'feature_fraction': 0.9404479593945407, 'bagging_fraction': 0.6660690754252235, 'bagging_freq': 16, 'min_data_in_leaf': 11, 'reg_alpha': 7.419904514273685e-08, 'reg_lambda': 4.2015143837140144e-08}. Best is trial 22 with value: 2959.2430107688706.
# [I 2026-02-07 10:54:52,120] Trial 39 finished with value: 5200.765373549489 and parameters: {'n_estimators': 987, 'boosting': 'dart', 'max_depth': 7, 'num_leaves': 67, 'learning_rate': 0.008997702188199508, 'feature_fraction': 0.9737777661548166, 'bagging_fraction': 0.8719832189606219, 'bagging_freq': 14, 'min_data_in_leaf': 9, 'reg_alpha': 0.0002788680059911847, 'reg_lambda': 0.002792864471721823}. Best is trial 22 with value: 2959.2430107688706.
# [I 2026-02-07 10:54:55,101] Trial 40 finished with value: 3504.994723693453 and parameters: {'n_estimators': 826, 'boosting': 'gbdt', 'max_depth': 6, 'num_leaves': 110, 'learning_rate': 0.0018884617780434247, 'feature_fraction': 0.857983780068991, 'bagging_fraction': 0.8466354455760714, 'bagging_freq': 2, 'min_data_in_leaf': 17, 'reg_alpha': 0.0012583849813654954, 'reg_lambda': 0.00014324740942477177}. Best is trial 22 with value: 2959.2430107688706.
# [I 2026-02-07 10:54:57,046] Trial 41 finished with value: 2962.3369547996617 and parameters: {'n_estimators': 676, 'boosting': 'gbdt', 'max_depth': 6, 'num_leaves': 78, 'learning_rate': 0.04928718158695713, 'feature_fraction': 0.9944127221057512, 'bagging_fraction': 0.8221379225289928, 'bagging_freq': 15, 'min_data_in_leaf': 7, 'reg_alpha': 7.16994711486672e-07, 'reg_lambda': 0.7815423013005184}. Best is trial 22 with value: 2959.2430107688706.
# [I 2026-02-07 10:54:58,774] Trial 42 finished with value: 3030.0985490815374 and parameters: {'n_estimators': 672, 'boosting': 'gbdt', 'max_depth': 5, 'num_leaves': 79, 'learning_rate': 0.07231938980185487, 'feature_fraction': 0.9843661533836379, 'bagging_fraction': 0.7950372353502219, 'bagging_freq': 15, 'min_data_in_leaf': 8, 'reg_alpha': 5.267142399573426e-07, 'reg_lambda': 0.3418786942053211}. Best is trial 22 with value: 2959.2430107688706.
# [I 2026-02-07 10:55:00,766] Trial 43 finished with value: 3025.604243548613 and parameters: {'n_estimators': 572, 'boosting': 'gbdt', 'max_depth': 7, 'num_leaves': 85, 'learning_rate': 0.0486588234066331, 'feature_fraction': 0.9598322750591501, 'bagging_fraction': 0.8163098596739713, 'bagging_freq': 13, 'min_data_in_leaf': 5, 'reg_alpha': 3.386588505531649e-06, 'reg_lambda': 0.05040754844154253}. Best is trial 22 with value: 2959.2430107688706.
# [I 2026-02-07 10:55:02,601] Trial 44 finished with value: 3039.1801465407957 and parameters: {'n_estimators': 503, 'boosting': 'gbdt', 'max_depth': 6, 'num_leaves': 62, 'learning_rate': 0.09171291133950792, 'feature_fraction': 0.9114927697757392, 'bagging_fraction': 0.7528782529784184, 'bagging_freq': 11, 'min_data_in_leaf': 10, 'reg_alpha': 3.077697860097673e-05, 'reg_lambda': 2.867421208491345}. Best is trial 22 with value: 2959.2430107688706.
# [I 2026-02-07 10:55:04,555] Trial 45 finished with value: 3067.6412781860345 and parameters: {'n_estimators': 747, 'boosting': 'gbdt', 'max_depth': 4, 'num_leaves': 55, 'learning_rate': 0.0131035140249741, 'feature_fraction': 0.9977475879413145, 'bagging_fraction': 0.8803808714969582, 'bagging_freq': 16, 'min_data_in_leaf': 6, 'reg_alpha': 0.00012147845484205175, 'reg_lambda': 1.9227408011594749}. Best is trial 22 with value: 2959.2430107688706.
# [I 2026-02-07 10:55:06,532] Trial 46 finished with value: 2987.657660426513 and parameters: {'n_estimators': 621, 'boosting': 'gbdt', 'max_depth': 8, 'num_leaves': 71, 'learning_rate': 0.033423858349955746, 'feature_fraction': 0.8871343223362267, 'bagging_fraction': 0.8252575057725031, 'bagging_freq': 18, 'min_data_in_leaf': 14, 'reg_alpha': 6.288266802527688e-07, 'reg_lambda': 0.2790085996108458}. Best is trial 22 with value: 2959.2430107688706.
# [I 2026-02-07 10:55:09,947] Trial 47 finished with value: 23405.57110736471 and parameters: {'n_estimators': 570, 'boosting': 'dart', 'max_depth': 7, 'num_leaves': 45, 'learning_rate': 0.02166508746870473, 'feature_fraction': 0.9279298864680845, 'bagging_fraction': 0.8014448664358035, 'bagging_freq': 7, 'min_data_in_leaf': 11, 'reg_alpha': 1.0662709518461682e-07, 'reg_lambda': 8.793251044948537}. Best is trial 22 with value: 2959.2430107688706.
# [I 2026-02-07 10:55:11,814] Trial 48 finished with value: 3053.9367923567015 and parameters: {'n_estimators': 688, 'boosting': 'gbdt', 'max_depth': 6, 'num_leaves': 29, 'learning_rate': 0.06759314625964985, 'feature_fraction': 0.7528430239075505, 'bagging_fraction': 0.8680956651825088, 'bagging_freq': 10, 'min_data_in_leaf': 9, 'reg_alpha': 7.670995050317304e-06, 'reg_lambda': 2.9644987627467587e-05}. Best is trial 22 with value: 2959.2430107688706.
# [I 2026-02-07 10:55:14,036] Trial 49 finished with value: 2951.2855013670314 and parameters: {'n_estimators': 1237, 'boosting': 'gbdt', 'max_depth': 9, 'num_leaves': 37, 'learning_rate': 0.03693061829563707, 'feature_fraction': 0.9642601026474632, 'bagging_fraction': 0.7147478349368187, 'bagging_freq': 4, 'min_data_in_leaf': 6, 'reg_alpha': 2.741124103406159e-06, 'reg_lambda': 5.5177210209575e-07}. Best is trial 49 with value: 2951.2855013670314.

# %%
params = study.best_params
params
# Out:
# {'n_estimators': 1237,
#  'boosting': 'gbdt',
#  'max_depth': 9,
#  'num_leaves': 37,
#  'learning_rate': 0.03693061829563707,
#  'feature_fraction': 0.9642601026474632,
#  'bagging_fraction': 0.7147478349368187,
#  'bagging_freq': 4,
#  'min_data_in_leaf': 6,
#  'reg_alpha': 2.741124103406159e-06,
#  'reg_lambda': 5.5177210209575e-07}

# %%
model = lgb.LGBMRegressor(**params)
model.fit(X_train, y_train)
model.predict(X_test)
# Out:
# array([30458.98532916, 28330.72695362, 28654.09067276, 15862.01254241,
#        23383.38463549, 28327.05165849, 25386.47134499, 24159.61055453,
#        28040.51135013, 27794.55783645, 21744.66948224, 28279.52592868,
#        15039.82748794, 16856.87663595, 31750.55848676, 26814.41946571,
#        27888.47307932, 30647.73663684, 28102.90095222, 25781.31116941,
#        38813.39368474, 14857.49922553, 22698.04701869, 33340.39825351,
#        39179.08088045, 25726.08131435, 25588.209883  , 27208.19939344,
#        14390.08959965, 29347.23629999, 26632.38047858, 25065.15887479,
#        15856.53926694, 24401.99568099, 20959.48775408, 32867.80047879,
#        22941.24222746, 22746.29252031, 19222.03128209, 28168.35546202,
#        24869.36828331, 22959.65613721, 23697.72616724, 23055.3565003 ,
#        19407.78052249, 25011.00620021, 26935.67626648, 26075.11020366,
#        16319.98658566, 23667.51055682, 23746.57264579, 20591.91610251,
#        26810.50410261, 14612.23380536, 30055.91244994, 23625.40642666,
#        23573.14340368, 23748.03827565, 26768.26583332, 29436.90041072,
#        23601.93089556, 21068.95114984, 25290.53706824, 24671.46660836,
#        30925.00148935, 27895.13092352, 38011.18177061, 12879.88383458,
#        28040.43773897, 27583.45718368, 36621.39125999, 22684.30588713,
#        26479.36124619, 18154.6462989 , 13876.64595404, 14567.3867633 ,
#        25883.34922958, 23972.03183481, 20550.0933437 , 13446.77401742,
#        18523.23906061, 35083.17650231, 25070.46071796, 17450.96813855,
#        23226.96126791, 26319.74761822, 24275.2363662 , 30043.80676398,
#        32630.29413307, 17016.01388642, 28314.27315334, 34114.40636909,
#        27321.08583617, 29099.51568987, 22655.40031035, 26353.30537107,
#        24039.15728224, 14654.96491843, 29105.62804393, 29612.80445736,
#        24102.50544096, 17295.56626835, 28152.08831755, 16253.42949422,
#        29489.97892588, 28665.00907804, 21691.88363819, 12023.2817827 ,
#        24244.97049196, 27475.28302466, 30202.43860343, 23243.71605051,
#        18669.32671711, 29165.49005882, 31148.31699691, 23240.84494816,
#        24294.48899258, 23361.35958126, 15322.81910583, 24493.63992233,
#        32835.70925824, 30861.98409196, 26205.84796257, 36880.39821425,
#        29441.5415741 , 27563.71579223, 27688.70204952, 33073.51364038,
#        22519.54465346, 36346.6595483 , 23183.02065935, 13688.35638066,
#        27142.1493968 , 22753.39873386, 33323.33928125, 28032.78137389,
#        27446.77021466, 22787.94776076, 28129.24549278, 22626.25683625,
#        24677.88257927, 22727.49239513, 29822.36073547, 30539.79656833,
#        23420.64176542, 26163.46312991, 32416.2915919 , 23647.83477021,
#        35169.30231162, 31943.68198735, 16906.64237612, 23606.08887892,
#        15801.7992689 , 22458.07248984, 14121.81201271, 27870.9177223 ,
#        21033.44516903, 23336.69592996, 32472.63715769, 23339.55886324,
#        28832.77365094, 27177.33530518, 25770.34386561, 29727.39623693,
#        24238.04141856, 27744.18314006, 21400.37433892, 19491.05495357,
#        15658.89048876, 27647.82114551, 21892.14435364, 15094.54844115,
#        29279.34517189, 27625.72361426, 19836.62431764, 17016.11181124,
#        16458.01017764, 14811.06666956, 15476.1842057 , 25299.09441763,
#        28245.74015602, 15022.89151592, 13945.33507008, 14091.66413276,
#        27075.71189147, 15556.93869835, 26857.0207715 , 23501.95547443,
#        29923.145421  , 28346.45775273, 29933.35602632, 23222.57750931,
#        23004.17418105, 34734.39602708, 29466.11174347, 14381.71708242,
#        27566.82690277, 15561.4599832 , 14726.95317705, 23207.35488389,
#        27320.62086749, 22851.72686136, 14146.31403499, 25070.68004324,
#        23168.36677478, 34161.96676689, 14142.22249275, 21940.4717055 ,
#        27792.43647961, 29358.9870175 , 33714.73716372, 21771.67383091,
#        28872.44312987, 26459.95055685, 28278.74153106, 37252.97156317,
#        28051.02217208, 23181.87704844, 23577.41398173, 29776.25707793,
#        25659.44595923, 15390.55030177, 27425.22837042, 28960.69184331,
#        27302.22030721, 13879.76787987, 29605.59414164, 23291.57537466,
#        23551.06135181, 36549.21909517, 29281.78124918, 20503.37687443,
#        28589.65484056, 22278.71811881, 14016.90224505, 21746.7787435 ,
#        25457.76530989, 24897.36399644, 30997.57686782, 24381.81250988,
#        29589.87480954, 23702.84713141, 31648.89152567, 19583.15305485,
#        22013.71210751, 15025.21445451, 27632.92500647])

# %%
lgb_regressor = lgb.train(params, lgb.Dataset(X_train, label = y_train))
y_pred = lgb_regressor.predict(X_test)
y_pred
# Out:
# array([30458.98532916, 28330.72695362, 28654.09067276, 15862.01254241,
#        23383.38463549, 28327.05165849, 25386.47134499, 24159.61055453,
#        28040.51135013, 27794.55783645, 21744.66948224, 28279.52592868,
#        15039.82748794, 16856.87663595, 31750.55848676, 26814.41946571,
#        27888.47307932, 30647.73663684, 28102.90095222, 25781.31116941,
#        38813.39368474, 14857.49922553, 22698.04701869, 33340.39825351,
#        39179.08088045, 25726.08131435, 25588.209883  , 27208.19939344,
#        14390.08959965, 29347.23629999, 26632.38047858, 25065.15887479,
#        15856.53926694, 24401.99568099, 20959.48775408, 32867.80047879,
#        22941.24222746, 22746.29252031, 19222.03128209, 28168.35546202,
#        24869.36828331, 22959.65613721, 23697.72616724, 23055.3565003 ,
#        19407.78052249, 25011.00620021, 26935.67626648, 26075.11020366,
#        16319.98658566, 23667.51055682, 23746.57264579, 20591.91610251,
#        26810.50410261, 14612.23380536, 30055.91244994, 23625.40642666,
#        23573.14340368, 23748.03827565, 26768.26583332, 29436.90041072,
#        23601.93089556, 21068.95114984, 25290.53706824, 24671.46660836,
#        30925.00148935, 27895.13092352, 38011.18177061, 12879.88383458,
#        28040.43773897, 27583.45718368, 36621.39125999, 22684.30588713,
#        26479.36124619, 18154.6462989 , 13876.64595404, 14567.3867633 ,
#        25883.34922958, 23972.03183481, 20550.0933437 , 13446.77401742,
#        18523.23906061, 35083.17650231, 25070.46071796, 17450.96813855,
#        23226.96126791, 26319.74761822, 24275.2363662 , 30043.80676398,
#        32630.29413307, 17016.01388642, 28314.27315334, 34114.40636909,
#        27321.08583617, 29099.51568987, 22655.40031035, 26353.30537107,
#        24039.15728224, 14654.96491843, 29105.62804393, 29612.80445736,
#        24102.50544096, 17295.56626835, 28152.08831755, 16253.42949422,
#        29489.97892588, 28665.00907804, 21691.88363819, 12023.2817827 ,
#        24244.97049196, 27475.28302466, 30202.43860343, 23243.71605051,
#        18669.32671711, 29165.49005882, 31148.31699691, 23240.84494816,
#        24294.48899258, 23361.35958126, 15322.81910583, 24493.63992233,
#        32835.70925824, 30861.98409196, 26205.84796257, 36880.39821425,
#        29441.5415741 , 27563.71579223, 27688.70204952, 33073.51364038,
#        22519.54465346, 36346.6595483 , 23183.02065935, 13688.35638066,
#        27142.1493968 , 22753.39873386, 33323.33928125, 28032.78137389,
#        27446.77021466, 22787.94776076, 28129.24549278, 22626.25683625,
#        24677.88257927, 22727.49239513, 29822.36073547, 30539.79656833,
#        23420.64176542, 26163.46312991, 32416.2915919 , 23647.83477021,
#        35169.30231162, 31943.68198735, 16906.64237612, 23606.08887892,
#        15801.7992689 , 22458.07248984, 14121.81201271, 27870.9177223 ,
#        21033.44516903, 23336.69592996, 32472.63715769, 23339.55886324,
#        28832.77365094, 27177.33530518, 25770.34386561, 29727.39623693,
#        24238.04141856, 27744.18314006, 21400.37433892, 19491.05495357,
#        15658.89048876, 27647.82114551, 21892.14435364, 15094.54844115,
#        29279.34517189, 27625.72361426, 19836.62431764, 17016.11181124,
#        16458.01017764, 14811.06666956, 15476.1842057 , 25299.09441763,
#        28245.74015602, 15022.89151592, 13945.33507008, 14091.66413276,
#        27075.71189147, 15556.93869835, 26857.0207715 , 23501.95547443,
#        29923.145421  , 28346.45775273, 29933.35602632, 23222.57750931,
#        23004.17418105, 34734.39602708, 29466.11174347, 14381.71708242,
#        27566.82690277, 15561.4599832 , 14726.95317705, 23207.35488389,
#        27320.62086749, 22851.72686136, 14146.31403499, 25070.68004324,
#        23168.36677478, 34161.96676689, 14142.22249275, 21940.4717055 ,
#        27792.43647961, 29358.9870175 , 33714.73716372, 21771.67383091,
#        28872.44312987, 26459.95055685, 28278.74153106, 37252.97156317,
#        28051.02217208, 23181.87704844, 23577.41398173, 29776.25707793,
#        25659.44595923, 15390.55030177, 27425.22837042, 28960.69184331,
#        27302.22030721, 13879.76787987, 29605.59414164, 23291.57537466,
#        23551.06135181, 36549.21909517, 29281.78124918, 20503.37687443,
#        28589.65484056, 22278.71811881, 14016.90224505, 21746.7787435 ,
#        25457.76530989, 24897.36399644, 30997.57686782, 24381.81250988,
#        29589.87480954, 23702.84713141, 31648.89152567, 19583.15305485,
#        22013.71210751, 15025.21445451, 27632.92500647])

# %% [markdown]
# ## 📉 Evaluating Model Performance

# %% [markdown]
# ### Evaluation metrics for LightGBM Regressor : R2 Score, Adjusted R2, Root Mean Squared Error, Mean, Absolute Error

# %%
def adj_r2_score(r_squared,n,d):
    # n is no. of sample
    # d is no. of features
    # r_squared is standard R²
    adj_r2 = 1 - (((1-r_squared)*(n-1))/(n-d-1))
    return adj_r2

# %%
r2_score = r2_score(y_test,y_pred)
adjusted_r2 = adj_r2_score(r2_score,len(y_test), X_test.shape[1])
rmse = root_mean_squared_error(y_test,y_pred)
mae = mean_absolute_error(y_test,y_pred)

# %% [markdown]
# **Log final model**

# %%
with mlflow.start_run(run_name = "best LGBM Model") as run:
    mlflow.log_params(params)
    mlflow.log_metrics({"RMSE": rmse,"MAE":mae,"R2":r2_score,"Adjusted R2": adjusted_r2})
    mlflow.sklearn.log_model(model, name="best model")

# %%
metrics = pd.DataFrame({'metric':['R2 Score', 'Adjusted R2','Root Mean Squared Error', 'Mean Absoulte Error'], 
                        'values':[r2_score, adjusted_r2, rmse, mae]})
metrics
# Out:
#                     metric       values
# 0                 R2 Score     0.802264
# 1              Adjusted R2     0.793008
# 2  Root Mean Squared Error  2936.739077
# 3      Mean Absoulte Error  1643.938846

# %% [markdown]
# ### Prediction Intervals for LightGBM Model

# %% [markdown]
# **Computing Prediction Intervals**

# %%
X_fit,X_cal, y_fit, y_cal = train_test_split(X_train, y_train, test_size = 0.2, random_state = 42)

# %%
model = lgb.LGBMRegressor(**params)
model.fit(X_fit,y_fit)
# Out:
# LGBMRegressor(bagging_fraction=0.7147478349368187, bagging_freq=4,
#               boosting='gbdt', feature_fraction=0.9642601026474632,
#               learning_rate=0.03693061829563707, max_depth=9,
#               min_data_in_leaf=6, n_estimators=1237, num_leaves=37,
#               reg_alpha=2.741124103406159e-06, reg_lambda=5.5177210209575e-07)

# %%
y_cal_pred = model.predict(X_cal)
residual  = np.abs(y_cal, y_cal_pred)

# %%
alpha = 0.10
q = np.quantile(residual, 1 - alpha)
pi_low = y_pred - q
pi_high = y_pred + q

# %%
coverage = np.mean((y_test >= pi_low) & (y_test <= pi_high))
coverage
# Out:
# np.float64(1.0)

# %% [markdown]
# **Visualizing Prediction Interval**

# %%
outside = (y_test < pi_low )| (y_test > pi_high)
df_plot = pd.DataFrame({
    'Predicted': y_pred,
    'Actual' : y_test,
    'Inside_PI': ~outside
})

df_plot
# Out:
#         Predicted  Actual  Inside_PI
# 613  30458.985329   31000       True
# 451  28330.726954   31000       True
# 731  28654.090673   29000       True
# 436  15862.012542   15000       True
# 275  23383.384635   23000       True
# ..            ...     ...        ...
# 597  31648.891526   29000       True
# 204  19583.153055   39000       True
# 514  22013.712108   23000       True
# 628  15025.214455   15000       True
# 945  27632.925006   29000       True
#
# [247 rows x 3 columns]

# %%
x_inside = df_plot[df_plot['Inside_PI']==True]['Predicted']
y_inside = df_plot.loc[df_plot['Inside_PI']==True]['Actual']
x_outside = df_plot[~df_plot['Inside_PI']]['Predicted']
y_outside = df_plot[~df_plot['Inside_PI']]['Actual']

# %%
# Reference diagonal line

min_val = min(df_plot['Actual'].min(), df_plot['Predicted'].min())
max_val = max(df_plot['Actual'].max(), df_plot['Predicted'].max())

fig = go.Figure()

# Points Inside the prediction interval

fig.add_trace(go.Scatter(
    x = x_inside,
    y = y_inside,
    mode = 'markers',
    name = 'Inside PI',
    marker = dict(size = 8, opacity = 0.6)
    
))

# Points outside the prediction Interval

fig.add_trace(go.Scatter(
    x = x_outside,
    y = y_outside,
    mode = 'markers',
    name = 'Outside PI',
    marker = dict(size = 8, color = 'red')
    
))

# Prediction Line

fig.add_trace(go.Scatter(
    x = [min_val, max_val],
    y = [min_val, max_val],
    mode = 'lines',
    name = 'perfect prediction',
    line = dict(dash = 'dash', color = 'grey')
))

fig.update_layout(
    title = 'Prediction Interval Coverage',
    xaxis_title = 'Predicted',
    yaxis_title = 'Actual',
    template = 'plotly_white',
    width = 800,
    height = 600
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="6f8d2540-08da-422e-a8fa-144bfa577345" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("6f8d2540-08da-422e-a8fa-144bfa577345")) {                    Plotly.newPlot(                        "6f8d2540-08da-422e-a8fa-144bfa577345",                        [{"marker":{"opacity":0.6,"size":8},"mode":"markers","name":"Inside PI","x":{"dtype":"f8","bdata":"EguiD7++3UC\\u002fZQEIbuW4N\u002fdhAIbjcwgyS2kBOXwB4CxvMQIf6iR\u002fPqNxAktnCWRgC2kAeMAErSnrYQBL5sgZF+M5AHsA8uX\\u002fQt3v2kB1rTOFrOHhQPmep5MTJ9ZASlmoHtfb2UD\u002fEfZcqbrRQAE4n65SGstAc6x1gbFzzEAvA8dZ1kbZQOjhlAkCaddAmtZX+YUR1ECHvQATY0PKQCPaxEzPFtJAPy3opWUh4UCIK2d8nXvYQH9p+\u002fW9CtFAFtVphb2u1kCaGPrY77PZQBSxnyDPtNdAF2QFovNW3UCqgBPTkt3fQJvag+MAntBA4SpYe5Gm20CPv\u002fkATajgQEYAV35FrtpATxUQAeFq3EBsS6+e2R\u002fWQJUUM4tTvNlAg4jpEMp510DXf3KCe5\u002fMQLUt3zFobNxA1bs6fDPr3ECJBSVZoInXQOmcvT3k49BARaL+pgV+20AEo6r5tr7PQHu9uKZ+zNxAygy8lED+20DPNoeN+C7VQNaldBGke8dAqVOKHD6t10BwdxMd0tTaQLgdFBKcft1AkX\u002fF0+2y1kDM3e7oVDvSQIyoH11fe9xAsmatSRRr3kB0caETNrLWQKCMp0ufuddA\u002fx9hA1fQ1kDawHXYaO3NQDPKfPRo69dAnlM+snYI4EDP21z7fiPeQLPRBEV2l9lAJc4rvgwC4kBsZyapYsDcQDE4is\u002ft6tpALyFh7iwK20D\u002f871vMCbgQCszmtvi\u002fdVAtgoFG1W\u002f4UDllXtSwaPWQCCu4Z0tvMpAf5q3j4mB2kDhCtuEWTjWQMpYZNtqReBAfaUHAjJg20BAczJLsc3aQCS8HKj8QNZAnFQntk9420AhTAFwkBjWQCDELXx4GdhAH9tmg98x1kCjNUoWlx\u002fdQMW++fry0t1AUkOvEinf1kDanuuj3YzZQNUUcakSqN9AowPgbPUX10CobYmsKSzhQI1ErqXrMd9AML2wHKmC0ECYODGwhQ3XQFWFcU7m3M5Afm2so4Tu1UAaVgjw55TLQAZP9ru6N9tAHECmfVyK1EAhzx2KLMrWQJwHMccott9ANldqxOPK1kDKN3+DMSjcQMrgo3VVitpA2OjkAZYq2UA6H\u002fJb2QfdQNUDmqaCq9dAVBaRuAsY20CjPiv1F+bUQJH5W4TDCNNA6CSJ+3GVzkBr6KWN9P\\u002fnrtOvaQKm6uuC6ZM5A7Kq0AXrDzEAm52q21qnWQCX7SrwnrtpAAIHlhO5Q1kAwZkwyKKHLQHQS1IWre9hAy+48eReg1kCLH8HvPq7gQO16pHocn8tAJUFsMB5t1UCML0jvGyTbQGF0Syu\u002fq9xAB2DYlld24EBRqwsg60LVQBNkPVwcMtxAs2fs1fzW2UBBsz51r53bQDCjCxefMOJAX3BEa8Fk20Cgxo8heKPWQPs5rX5aBtdA7QD3cxAU3UBImZiK3A7ZQIjcSXBGD85As\u002fSenU7I2kDmJylHLEjcQHVugxmOqdpAGj\u002fjSeIby0BQpWoGZuncQEw\u002f8NLkvtZAiyUw7cP\u002f1kBT39MCp9jhQEaO\u002fP9xmNxA3+m1HtgF1EBsXujoaevbQKacqPWtwdVAAQPEfHNgy0DW9+7WsTzVQAVZ1vpw3NhAcbi3S1dQ2EAcBmfrZEXeQOxxKQB0z9dAjyXh\u002fHfl3EDdqmY3tiXXQMWuwQ456N5Av5Cmy8kf00DGZSuTbX\u002fVQMHWPnObWM1Ai1ZOMzv82kA="},"y":{"dtype":"i4","bdata":"..."},"type":"scatter"},{"marker":{"color":"red","size":8},"mode":"markers","name":"Outside PI","x":[],"y":[],"type":"scatter"},{"line":{"color":"grey","dash":"dash"},"mode":"lines","name":"perfect prediction","x":[12023.281782704329,39179.0808804516],"y":[12023.281782704329,39179.0808804516],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"so ...

# %% [markdown]
# **Inference**
#
# - All test points lie within the 90% prediction interval, resulting in 100% empirical coverage on the test set, indicating conservative uncertainty estimates.
# - The prediction intervals are conservative, meaning they are wider than strictly necessary to guarantee coverage.
# - The model captures the general relationship between features and insurance cost, but individual predictions can still vary substantially
# - The model does not show clear systematic over-prediction or under-prediction across the test set.
# - The model prioritizes reliability over precision, which is acceptable and often preferred in insurance risk estimation.

# %%
import matplotlib.pyplot as plt
import numpy as np

idx = np.arange(len(y_test))

plt.figure(figsize=(10, 6))
plt.plot(idx, y_test.values, label="Actual", color="black")
plt.plot(idx, y_pred, label="Prediction", color="blue")
plt.fill_between(
    idx,
    pi_low,
    pi_high,
    color="blue",
    alpha=0.25,
    label="Prediction Interval (90%)"
)

plt.xlabel("Test Sample Index")
plt.ylabel("Target Value")
plt.title("Predictions with Prediction Intervals")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Feature Importance using SHAP

# %%
import shap
explainer = shap.TreeExplainer(lgb_regressor)
shap_values = explainer.shap_values(X_test)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[206], line 1
# ----> 1 import shap
#       2 explainer = shap.TreeExplainer(lgb_regressor)
#       3 shap_values = explainer.shap_values(X_test)
#
# File ~/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages/shap/__init__.py:1
# ----> 1 from ._explanation import Cohorts, Explanation
#       3 # explainers
#       4 from .explainers import other
#
# File ~/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages/shap/_explanation.py:17
#      14 import sklearn
#      15 from slicer import Alias, Obj, Slicer
# ---> 17 from .utils._clustering import hclust_ordering
#      18 from .utils._exceptions import DimensionError
#      19 from .utils._general import OpChain
#
# File ~/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages/shap/utils/__init__.py:1
# ----> 1 from ._clustering import (
#       2     delta_minimization_order,
#       3     hclust,
#       4     hclust_ordering,
#       5     partition_tree,
#       6     partition_tree_shuffle,
#       7 )
#       8 from ._general import (
#       9     OpChain,
#      10     approximate_interactions,
#    (...)     20     suppress_stderr,
#      21 )
#      22 from ._masked_model import MaskedModel, make_masks
#
# File ~/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages/shap/utils/_clustering.py:12
#      10 import scipy.spatial
#      11 import sklearn
# ---> 12 from numba import njit
#      14 from ..utils._exceptions import DimensionError
#      15 from ._show_progress import show_progress
#
# File ~/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages/numba/__init__.py:59
#      54             msg = ("Numba requires SciPy version 1.0 or greater. Got SciPy "
#      55                    f"{scipy.__version__}.")
#      56             raise ImportError(msg)
# ---> 59 _ensure_critical_deps()
#      60 # END DO NOT MOVE
#      61 # ---------------------- WARNING WARNING WARNING ----------------------------
#      64 from ._version import get_versions
#
# File ~/Desktop/MS Data Science/Projects/Machine Learning/Insurance Premium Prediction/Insurance-Premium-Prediction/.venv/lib/python3.13/site-packages/numba/__init__.py:45, in _ensure_critical_deps()
#      42 if numpy_version > (2, 3):
#      43     msg = (f"Numba needs NumPy 2.3 or less. Got NumPy "
#      44             f"{numpy_version[0]}.{numpy_version[1]}.")
# ---> 45     raise ImportError(msg)
#      47 try:
#      48     import scipy
#
# ImportError: Numba needs NumPy 2.3 or less. Got NumPy 2.4.

# %%
shap.summary_plot(shap_values,X_test)

# %%
plt.figure(figsize = (20,8))
shap.summary_plot(shap_values,X_test, plot_type = 'bar')
plt.show()

# %% [markdown]
# **Model Insights**:
#
# - Age contributes the most to the model’s predictions, followed by AnyTransplants, Weight, AnyChronicDiseases, and HistoryOfCancerInFamily.
# - Features such as BMI, NumberOfMajorSurgeries, Height, BloodPressureProblems, Diabetes, and KnownAllergies contribute less to the final prediction.

# %% [markdown]
# #  📂 Saving the model

# %%
import pickle
import os
MODEL_DIR = "models"
MODEL_PATH = os.path.join(MODEL_DIR, "insurance_lgbm_model.pkl")

os.makedirs(MODEL_DIR, exist_ok=True)

with open(MODEL_PATH,"wb") as f:
    pickle.dump(model,f)

print("Model saved at:", MODEL_PATH)
print("File exists:", os.path.exists(MODEL_PATH))
# Out:
# Model saved at: /kaggle/working/insurance_lgbm_model.pkl
# File exists: True

# %%
with open(MODEL_PATH, "rb") as f:
    loaded_model = pickle.load(f)

preds = loaded_model.predict(X_train.head(5))
print(preds)
# Out:
# [23191.20109259 23360.87858365 15215.5126712  20823.05119223
#  25075.45637867]
